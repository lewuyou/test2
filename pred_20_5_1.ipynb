# %%
# from google.colab import drive # 挂载谷歌云盘
# drive.mount('/content/drive')
# !nvidia-smi # 显示显卡信息
# ''' 符号%代表一直生效，！代表执行完立马结束，不会生效，所以进入目录用% '''
# %cd /content/drive/MyDrive/timeSerise
# ''' 支持的 常用命令1.ls  2.wget  3.gdoint(int(int(int(w))))n  4.mkdir  5.pwd '''
# !ls
# !pip install patool
# !pip install sktime
# !pip install reformer_pytorch

# %%
from data_provider.data_creat import *
import akshare as ak
from datetime import datetime
import random
import numpy as np
import torch
from exp.exp_long_term_forecasting import Exp_Long_Term_Forecast
# from exp.exp_imputation import Exp_Imputation
# from exp.exp_short_term_forecasting import Exp_Short_Term_Forecast
# from exp.exp_anomaly_detection import Exp_Anomaly_Detection
# from exp.exp_classification import Exp_Classification
# from data_provider.data_creat import *
# import akshare as ak
from torch.utils.tensorboard import SummaryWriter
from data_provider.data_loader import Dataset_Custom
from torch.utils.data import DataLoader

# %%
class Args:
    '''基本配置'''
    # 选项：[long_term_forecast, short_term_forecast, imputation, classification, anomaly_detection]')
    task_name = 'long_term_forecast'
    model_id = 'stock_cy'
    des = '20240106' # 实验描述 20231210
    # 模型名称，选项：[Autoformer, Transformer, TimesNet]
    model = 'TimesNet'

    '''数据加载'''
    # 数据集类型,选项：[ETTh1,ETTh2,ETTm1,ETTm2,custom,m4,PSM,MSL,SMAP,SMD,SWAT,UEA]
    data = 'custom'
    test_path = 'raw_stock_cy_300798.csv'
    root_path = './dataset/Stock/'
    data_path = 'stock_cy_all_raw.csv'
    # 预测任务 M:多变量预测多变量, S:单变量预测单变量, MS:多变量预测单变量
    features = 'MS'
    # 目标列名，S或MS任务中的目标特征
    target = 'Change'
    # 时间采集粒度，选项：[s:秒, t:分钟, h:小时, d:天, b:工作日, w:周, m:月]
    freq = 'd'
    # 模型检查点的位置
    checkpoints = './checkpoints/'
    
    '''是否训练模型'''
    is_training = 0 # 设置为1则进行训练，设置为0则进行测试
    # 测试集的比例
    if is_training:
        test_ratio = [0.1,0.1] # test测试集、valid验证集的占比
        pred_once = False # 是否只预测一次，用于测试集数据
    else:
        test_ratio = [0.5,0.2]
        data_path = test_path
        pred_once = True # 是否只预测一次，用于测试集数据
    scale = False # dataset获取的源数据是否进行归一化
    back_training = False # 是否从上次训练的模型继续训练

    '''预测任务'''
    # 还原预测数据为原始数据
    inverse = scale
    # 输入序列长度,这是用于模型训练的输入序列的长度
    seq_len = 20
    # 开始标记长度,这是模型输出目标中有标签数据的长度，类似于滑动窗口的长度
    label_len = 5
    # 预测序列长度
    pred_len = 1
    # 季节模式（针对M4数据集）
    seasonal_patterns = 'Monthly'


    '''插补任务'''
    # 插补任务中数据丢失率
    mask_rate = 0.25

    '''异常检测任务'''
    # 异常检测中异常点占比
    anomaly_ratio = 0.25

    '''模型定义'''
    # 模型维度，线性层隐含神经元个数，数字越大显存用的越多
    d_model = 64
    # 前馈网络（FFN）的维度，数字越大显存用的越多
    d_ff = 256
    # TimesBlock 中傅里叶变换,频率排名前k个周期
    top_k = 5
    # Inception 中卷积核个数，用于 Inception
    num_kernels = 6
    # encoder 输入特征数
    enc_in = 16
    # decoder 输入特征数
    dec_in = enc_in
    # 输出通道数
    c_out = enc_in
    # 多头注意力机制
    n_heads = 8
    # encoder 层数，编码器层数
    e_layers = 2
    # decoder 层数，解码器层数
    d_layers = 1
    # 滑动窗口长度
    moving_avg = 20
    # 对 Q 进行采样，注意力因子数量
    factor = 3
    # 是否下采样操作 pooling，也就是对模型进行压缩
    distil = False
    # dropout 率
    dropout = 0.1
    # 时间特征嵌入方式,选项：[timeF, fixed, learned]
    embed = 'timeF'
    # 激活函数类型
    activation = 'gelu'
    # 是否输出 attention，也就是是否输出注意力权重
    output_attention = False

    '''优化'''
    # 并行核心数
    num_workers = 10
    # 实验轮数
    itr = 1
    # 训练迭代次数
    train_epochs = 500
    # batch size 大小
    batch_size = 256
    # early stopping 机制容忍次数
    patience = 3
    # 学习率
    learning_rate = 0.0001
    # 损失函数
    loss = 'MSE'
    # 学习率下降策略
    lradj = 'type1'
    # 使用混合精度训练
    use_amp = False

    '''GPU'''
    # 使用 gpu
    use_gpu = True
    gpu = 0
    # 使用多个 gpus
    use_multi_gpu = False
    # 多 gpu 的设备 id
    devices = '0,1,2,3'

    '''去平稳化投影仪参数'''
    # 投影仪的隐藏层维度（列表）
    p_hidden_dims = [128, 128]
    # 投影仪中的隐藏层数
    p_hidden_layers = 2
  
    '''股票数据获取'''
    fuquan = 'hfq'# 设置复权方式,adjust=空选择的不复权，qfq是前复权，应该用hfq后复权来进行量化分析
    period = 'daily' # 拉取时间周期{'daily', 'weekly', 'monthly'}
    start_date = '20151201'  # 20151201   20221021  下载数据的开始日期,1就是公司上市时间
    end_date = 1  # '20231220' 下载数据的结束日期,如果1则到最后一天,如果-1是昨天.
    label_n = 5 # 预测未来连续多少天的收益率
    pred_path = './dataset/Stock/pred/'
    
    # 预测目标y是否替换成1或者0
    label_ch = False  # 如果是True ，预测n天以后上涨大于变量zhangfu为1，小于为0
    zhangfu = 0.10  # 预测涨幅大于等于3%的为1，小于3%的为0
    
    # 数据修剪
    start = 103 # 删除前24行（start=25），因为macd算不出来
    end = 0 # (end = label_n if all else 0)删除最后部分需要预测天数label_n的数据，算出来是0.如果单只股票预测，那么不需要删除
    # final_data_feat =  ['index', 'Volume','Tom_Chg'] # 删除不需要列的标签
    add_zero_days = 0 # 未来数据填充0的天数
    final_data_feat =  ['index', 'Volume','Tom_Chg','Open','Low','High'] # 删除不需要列的标签

# 创建参数对象
args = Args()

# 设置随机种子以确保结果可重现
fix_seed = 2021
random.seed(fix_seed)
torch.manual_seed(fix_seed)
np.random.seed(fix_seed)

# 创建股票数据列表
stock_down = ak.stock_cy_a_spot_em() # 创业板实时数据
stock_list = stock_down[~stock_down['名称'].str.contains("退|ST") & (stock_down['流通市值'] <= 1e11) & (stock_down['总市值'] >= 45e8)] # 去除退市和ST股票
file_name_cy = 'Stock_list_cy.csv'# 保存数据，编码格式为utf-8
stock_list.to_csv(args.pred_path + file_name_cy,index=False,encoding='utf-8-sig')

# 读取股票列表
stock_list = pd.read_csv(args.pred_path + file_name_cy) # 读取股票列表
# 将股票代码的数字转换为字符串列表
stock_list = [str(code) for code in stock_list['代码'].tolist()]
random.shuffle(stock_list)
# stock_list = ['000158','300798'] # 自定义股票列表

# %% [markdown]
# ### 初始化模型参数

# %%
# 检查并设置 GPU
args.use_gpu = torch.cuda.is_available() and args.use_gpu
if args.use_gpu:
    print("使用 GPU.")
    total_cuda_devices = torch.cuda.device_count()  # 获取系统中可用的 GPU 总数
    print(f"系统中总共有 {total_cuda_devices} 个 CUDA 设备可用。")
    if args.use_multi_gpu:
        args.devices = args.devices.replace(' ', '')
        device_ids = args.devices.split(',')
        args.device_ids = [int(id_) for id_ in device_ids]
        args.gpu = args.device_ids[0]

        # 打印多 GPU 使用情况
        print(f"使用多个GPU: {args.device_ids}")
        device = torch.device(f"cuda:{args.gpu}" if args.use_gpu else "cpu")
        print(f"Primary GPU (cuda:{args.gpu}) is in use.")
    else:
        args.gpu = 0
        device = torch.device("cuda" if args.use_gpu else "cpu")
        print("使用单个 GPU.")
else:
    device = torch.device("cpu")
    print("使用 CPU.")


# 选择合适的实验类
if args.task_name == 'long_term_forecast':
    Exp = Exp_Long_Term_Forecast
# elif args.task_name == 'short_term_forecast':
#     Exp = Exp_Short_Term_Forecast
# elif args.task_name == 'imputation':
#     Exp = Exp_Imputation
# elif args.task_name == 'anomaly_detection':
#     Exp = Exp_Anomaly_Detection
# elif args.task_name == 'classification':
#     Exp = Exp_Classification
else:
    Exp = Exp_Long_Term_Forecast  # 默认情况
    
    
ii = 0
setting = '{}_{}_{}_{}_ft{}_sl{}_ll{}_pl{}_dm{}_nh{}_el{}_dl{}_df{}_fc{}_eb{}_dt{}_{}_{}'.format(
            args.task_name, # 任务名称
            args.model_id, # 模型id
            args.model, # 模型名称
            args.data, # 数据集名称
            args.features, # 预测任务
            args.seq_len, # 输入序列长度
            args.label_len, # 开始标记长度
            args.pred_len, # 预测序列长度
            args.d_model, # encoder 输入特征数
            args.n_heads, # 多头注意力机制
            args.e_layers, # encoder 层数
            args.d_layers, # decoder 层数
            args.d_ff, # FFN 层隐含神经元个数
            args.factor, # 对 Q 采样的因子数
            args.embed, # 时间特征嵌入方式
            args.distil, # 是否下采样操作 pooling
            args.des,  # 实验描述
            ii) # 实验轮数
# Out:
# 使用 GPU.
# 系统中总共有 1 个 CUDA 设备可用。
# 使用单个 GPU.

# %% [markdown]
# ### 载入模型

# %%
from models.TimesNet import Model
import torch
import os


def build_model(args):
    # 使用 Args 实例来构建 Model 实例
    model = Model(args)
    return model

def acquire_device(args):
    if args.use_gpu:
        os.environ["CUDA_VISIBLE_DEVICES"] = str(args.gpu) if not args.use_multi_gpu else args.devices
        device = torch.device(f'cuda:{args.gpu}')
        print(f'Use GPU: cuda:{args.gpu}')
    else:
        device = torch.device('cpu')
        print('Use CPU')
    return device

# 构建模型
device = acquire_device(args)
model = build_model(args).to(device)
model.load_state_dict(torch.load(os.path.join('./checkpoints/' + setting, 'checkpoint.pth'), map_location=torch.device(device)))
# Out:
# Use GPU: cuda:0
# <All keys matched successfully>

# %%
from sklearn.preprocessing import StandardScaler

all_data_raw = pd.DataFrame()  # 初始化一个空的 DataFrame 用于存储原始数据
all_data_scaled = pd.DataFrame()  # 初始化一个空的 DataFrame 用于存储标准化后的数据
processed_count = 0  # 初始化计数器
total_count = len(stock_list)  # 获取总股票数量
scaler = StandardScaler()

for i in stock_list[:]:
    NUM = i
    try:
        # 下载原始数据
        raw_data = download_data(NUM, args)
        # 更新已处理股票数量计数器
        processed_count += 1

        # 拼接数据，添加各种参数
        ad_data = add_data(raw_data, args)
        # 添加预测标签
        # ad_data = add_label(ad_data, args)
        # 删除无效数据
        final_data_raw = sub_data(ad_data.copy(), args)

        # 保留最后200行
        final_data_raw = final_data_raw.tail(200)
        if args.add_zero_days:
            add_zeros_data = add_business_days(final_data_raw, args.add_zero_days)
            # Convert the list of new rows into a DataFrame and append it to the original DataFrame
            df_new = pd.DataFrame(add_zeros_data, columns=final_data_raw.columns)
            final_data_raw = pd.concat([final_data_raw, df_new]).reset_index(drop=True)

        file_name_raw_individual = f"raw_stock_cy_{NUM}.csv"
        final_data_raw.to_csv(args.pred_path + file_name_raw_individual, index=False)
        print(f"股票代码 {NUM} 的数据保存到 {file_name_raw_individual} ，形状: {final_data_raw.shape}")
     
        # 执行预测
        flag='test'
        data_set = Dataset_Custom(
            root_path=args.pred_path,
            data_path=file_name_raw_individual,
            flag=flag,
            size=[args.seq_len, args.label_len, args.pred_len],
            features=args.features,
            target=args.target,
            scale = args.scale,
            timeenc=1,
            freq=args.freq,
            test_ratio = args.test_ratio,
            seasonal_patterns=args.seasonal_patterns,
        )
        print(flag, len(data_set))

        data_loader = DataLoader(
            data_set,
            batch_size=1,
            shuffle=False,
            num_workers=args.num_workers,
            drop_last=True)
        # 最后一笔数据预测
        preds = []
        trues = []
        model.eval()
        with torch.no_grad():
            data_loader_length = len(data_loader)
            for i, (batch_x, batch_y, batch_x_mark, batch_y_mark) in enumerate(data_loader):
                if i < data_loader_length - 1 and args.pred_once:
                    continue  # 跳过除了最后一批数据之外的所有批次
                batch_x = batch_x.float().to(device)
                batch_y = batch_y.float().to(device)

                batch_x_mark = batch_x_mark.float().to(device)
                batch_y_mark = batch_y_mark.float().to(device)

                # decoder input 
                dec_inp = torch.zeros_like(batch_y[:, -args.pred_len:, :]).float()
                dec_inp = torch.cat([batch_y[:, :args.label_len, :], dec_inp], dim=1).float().to(device)

                # 打印更多的变量
                # print("dec_inp:", dec_inp)
                outputs = model(batch_x, batch_x_mark, dec_inp, batch_y_mark)
                f_dim = -1 if args.features == 'MS' else 0
                outputs = outputs[:, -args.pred_len:, :]
                batch_y = batch_y[:, -args.pred_len:, :].to(device)
                outputs = outputs.detach().cpu().numpy() # 将outputs转换为numpy格式
                batch_y = batch_y.detach().cpu().numpy() # 将batch_y转换为numpy格式
                if data_set.scale and args.inverse: # 如果数据进行了归一化且需要逆归一化
                    shape = outputs.shape
                    outputs = data_set.inverse_transform(outputs.squeeze(0)).reshape(shape)
                    batch_y = data_set.inverse_transform(batch_y.squeeze(0)).reshape(shape)

                outputs = outputs[:, :, f_dim:]
                batch_y = batch_y[:, :, f_dim:]
                
                pred = outputs
                true = batch_y
                
                preds.append(pred)
                trues.append(true)
                
                preds = np.array(preds) # 将预测结果转换为numpy格式
                trues = np.array(trues) # 将真实结果转换为numpy格式
                print('test shape:', preds.shape, trues.shape)
                preds = preds.reshape(-1, preds.shape[-2], preds.shape[-1]) # 将预测结果转换为三维矩阵
                trues = trues.reshape(-1, trues.shape[-2], trues.shape[-1])
                print('test shape:', preds.shape, trues.shape)
        if args.use_gpu:
            torch.cuda.empty_cache()

        # 使用 flatten 方法将 preds 和 trues 转换为一维数组
        preds_flat = preds.flatten()
        trues_flat = trues.flatten()

        # 将一维数组转换为列表
        preds_list = preds_flat.tolist()
        trues_list = trues_flat.tolist()
        
        # 计算从第n天（第1天）到n+5天（第5天）的总变化
        total_preds = calculate_total_change(preds_list, 1, args.pred_len)
        total_trues = calculate_total_change(trues_list, 1, args.pred_len)
        accuracy = 1 if np.sign(total_preds) == np.sign(total_trues) else 0

        #调整
        accuracy_list = [1 if np.sign(preds_list[i]) == np.sign(trues_list[i]) else 0 for i in range(args.pred_len)]
        
        # 定义要写入的数据
        data = [NUM]
        for i in range(args.pred_len):
            data.extend([preds_list[i], trues_list[i], accuracy_list[i]])
        data.extend([total_preds, total_trues, accuracy])

        # 定义列名
        columns = ['股票代码']
        for i in range(1, args.pred_len+1):
            columns.extend(['预测{}天涨幅'.format(i), '真实{}天涨幅'.format(i), '{}天涨幅准确率'.format(i)])

        columns.extend(['预测累计涨跌幅', '真实累计涨跌幅', '累计涨跌幅准确率'])
        
        # 创建DataFrame
        df = pd.DataFrame([data], columns=columns)
        
        # 检查文件是否存在
        file_path = args.pred_path + 'result.csv'
        file_exists = os.path.isfile(file_path)
        # 如果文件不存在，则写入表头
        if not file_exists:
            df.to_csv(file_path, index=False, encoding='utf-8-sig')
        else:
            df.to_csv(file_path, mode='a', header=False, index=False, encoding='utf-8-sig')

        print(f'股票{NUM}预测结果已保存到 {file_path} 。')
        
        

    except Exception as e:
        print(f"处理股票代码 {NUM} 时出现错误: {e}")
        continue

    # 计算并打印处理进度
    progress = processed_count / total_count
    print(f"处理进度: {processed_count}/{total_count} ({progress:.2%})")
# Out:
# 处理股票代码 300166 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300603 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300296 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300776 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301153 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300294 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300505 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301267 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300161 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300351 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300066 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300183 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301387 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300768 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300127 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300602 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300532 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300661 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300315 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300981 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300408 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300426 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300688 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301500 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300369 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300900 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300504 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300034 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300772 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301332 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301015 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301172 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300346 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300068 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300384 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300133 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300913 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300525 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300377 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300671 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301363 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301377 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300318 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301368 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301149 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300292 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300072 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300638 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300118 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300376 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300463 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301487 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300869 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300596 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301236 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300567 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301048 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300698 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300397 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300679 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300676 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300360 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300047 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301206 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300997 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300194 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300212 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300014 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300613 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301095 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300735 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300882 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301191 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300775 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300035 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300001 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301348 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301316 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300308 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300617 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300101 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301358 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300232 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300191 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301486 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300331 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300244 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300123 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300226 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300821 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301085 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300180 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300357 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301177 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300809 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301102 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301488 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300533 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300401 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300199 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301559 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300762 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300134 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301263 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300435 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300057 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300783 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300793 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300624 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300099 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300685 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300494 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300481 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301200 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300457 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300953 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300443 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300497 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301239 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301511 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301091 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300663 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300219 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300026 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300856 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301439 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300145 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300894 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301307 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300672 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301509 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300316 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301127 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300131 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300045 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300942 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301060 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301382 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301293 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300791 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300579 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301017 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301550 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300278 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300634 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300941 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301050 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300893 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301310 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301566 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300039 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300327 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301219 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300403 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300548 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301030 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300343 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300256 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300741 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301109 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301035 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300203 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300725 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300025 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300979 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300985 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300024 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300751 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301103 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300796 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300589 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301278 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300709 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300982 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300098 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301205 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300558 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301061 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300606 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300468 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301051 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300438 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301393 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301371 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301078 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301325 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300109 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300520 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300286 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301297 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301217 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300607 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300423 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300261 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300769 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300737 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300803 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300274 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301155 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300432 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301238 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300255 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300083 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300972 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301101 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300812 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300628 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300726 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300054 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300458 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300033 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301211 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301251 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300415 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300601 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301018 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300566 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300263 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300418 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301261 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300969 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300055 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301087 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300618 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300459 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300551 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300718 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300724 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300888 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300523 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300660 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300378 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301215 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300224 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300482 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300373 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301408 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300341 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300456 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300485 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300208 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300077 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300747 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300910 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300354 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300570 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300593 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301389 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300850 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300383 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300677 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300763 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300352 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301308 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300129 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300182 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301327 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300529 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300872 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300020 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300081 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300608 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300197 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301337 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300975 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300755 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300866 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300337 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300766 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300827 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300088 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300604 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300860 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301260 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300007 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300151 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300293 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300527 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301315 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300474 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300687 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300782 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300847 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301096 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300552 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300394 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300841 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300079 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300795 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300284 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300395 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300815 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301262 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300304 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300251 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300655 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301558 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300143 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300748 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300475 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300320 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301207 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300580 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301421 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300619 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301311 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301179 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300402 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300978 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300177 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300413 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300339 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300110 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301165 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300470 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301047 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301123 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301413 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300848 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300699 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300217 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301525 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300846 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300446 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300017 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300303 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300502 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300633 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300048 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301383 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300442 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300307 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300146 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300770 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300093 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300516 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300379 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300696 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300797 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300140 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300188 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300094 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300223 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300158 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300999 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300236 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300302 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300729 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300322 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300653 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300429 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301376 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300002 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301367 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300258 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300342 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300276 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300248 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301303 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300170 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300592 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300406 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301333 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300887 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300862 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300288 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300471 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300820 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300271 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301339 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300595 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301162 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300433 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300428 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300722 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300382 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301180 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300324 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300364 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300896 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300389 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300049 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300174 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301391 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300043 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301039 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300757 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300005 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300798 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300455 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300065 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300674 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300779 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300662 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300206 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300347 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300037 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300287 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300777 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300073 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300204 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300788 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300355 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300113 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300705 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301171 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300492 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300627 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301366 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300027 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300811 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300450 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300507 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300569 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300861 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300388 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301507 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300682 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301116 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301291 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300348 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300229 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300487 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300792 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301301 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300185 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301117 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300825 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300629 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301089 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300765 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300008 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300545 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301328 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300536 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300032 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300363 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300222 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300042 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300075 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300119 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300416 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300581 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301516 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300257 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300842 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301498 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300761 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300951 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300857 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300136 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300973 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300396 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300252 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301058 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301071 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300759 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300790 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301221 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301517 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300319 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301216 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300207 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300587 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300285 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300353 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300253 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300031 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300571 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300659 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300738 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301029 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300968 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300691 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301370 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301168 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300590 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301381 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301269 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300814 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300802 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300019 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301508 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301456 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300990 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300976 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300873 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300510 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300723 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300630 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300531 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300919 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300116 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300712 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300398 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300181 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301312 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300909 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300142 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300138 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301345 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300576 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300586 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300267 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300957 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300454 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300366 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300639 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301195 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300009 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300114 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300225 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300080 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300390 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300070 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300171 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300833 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300053 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300925 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300678 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300291 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300358 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300855 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300328 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300657 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300568 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300323 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300806 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300122 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300702 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301246 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300503 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300476 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300441 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300444 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300666 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300085 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300620 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300480 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300168 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300708 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300184 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300205 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300773 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300102 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300041 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300332 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301526 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300130 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300681 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300541 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300740 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301268 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300082 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300201 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300036 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300684 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300573 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300115 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300393 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300144 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300058 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300858 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300451 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300559 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300003 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300128 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300233 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300409 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300260 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301069 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301286 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301330 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301266 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301090 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300012 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301175 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300349 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301004 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300598 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300087 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300496 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300298 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301510 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301031 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300693 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300926 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 301080 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300623 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300280 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
# 处理股票代码 300832 时出现错误: type object 'datetime.datetime' has no attribute 'datetime'
