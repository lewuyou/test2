# %%
# from google.colab import drive # 挂载谷歌云盘
# drive.mount('/content/drive')
# !nvidia-smi # 显示显卡信息
# ''' 符号%代表一直生效，！代表执行完立马结束，不会生效，所以进入目录用% '''
# %cd /content/drive/MyDrive/timeSerise
# ''' 支持的 常用命令1.ls  2.wget  3.gdoint(int(int(int(w))))n  4.mkdir  5.pwd '''
# !ls
# !pip install pyti
# !pip install akshare

# %%
from data_provider.data_creat import *
import akshare as ak
from datetime import datetime
import random

# %%
class Args:
    '''股票数据获取'''
    fuquan = 'hfq'# 设置复权方式,adjust=空选择的不复权，qfq是前复权，应该用hfq后复权来进行量化分析
    period = 'daily' # 拉取时间周期{'daily', 'weekly', 'monthly'}
    start_date = '20151201'  # 20151201   20221021  下载数据的开始日期,1就是公司上市时间
    end_date = '20231230'  # '20231220' 下载数据的结束日期,如果1则到最后一天,如果-1是昨天.
    root_path = './dataset/Stock/'
    
    # 添加预测目标Y
    label_n = 0 #  data['Tom_Chg'] 预测未来连续多少天的涨幅，0就是当天的涨幅。
    # 训练数据需要将end=lable_n，删除掉计算不出来的。预测数据不需要。
    end = 0 # 删除最后部分需要预测天数label_n的数据，算出来是0.
    zhangfu = 5  # data['OT']如果是非0，那么替换Y。涨幅大于等于5个点为1，小于5个点的为0
    
    # 是否合并全部股票数据
    all = True # 是否合并全部股票数据
    data_addzero = 21 # 当all = True时，用于训练的数据集分割，前面补0的长度 应该是seq_len + pred_len 长度
    
    # 数据修剪
    start = 103 # 删除前24行（start=25），因为macd算不出来
    # final_data_feat =  ['index', 'Volume','Tom_Chg'] # 删除不需要列的标签
    final_data_feat =  ['index', 'Volume','Tom_Chg','Open','Low','High'] # 删除不需要列的标签
    down_scaler = False # 是否对下载数据进行归一化
    
    # 此项用于预测数据，训练数据不需要
    add_zero_days = 0 # 未来数据填充0的天数
    pred_path = './dataset/Stock/pred/'

# 创建参数对象
args = Args()

# 创建股票数据列表
stock_down = ak.stock_cy_a_spot_em() # 创业板实时数据
stock_list = stock_down[~stock_down['名称'].str.contains("退|ST") & (stock_down['流通市值'] <= 1e11) & (stock_down['总市值'] >= 45e8)] # 去除退市和ST股票
file_name_cy = 'Stock_list_cy.csv'# 保存数据，编码格式为utf-8
stock_list.to_csv(args.root_path + file_name_cy,index=False,encoding='utf-8-sig')

# 读取股票列表
stock_list = pd.read_csv(args.root_path + file_name_cy) # 读取股票列表
# 将股票代码的数字转换为字符串列表
stock_list = [str(code) for code in stock_list['代码'].tolist()]
# 对列表随机排序
random.shuffle(stock_list)

# stock_list = ['000158','300798'] # 自定义股票列表

# %%
from sklearn.preprocessing import StandardScaler

all_data_raw = pd.DataFrame()  # 初始化一个空的 DataFrame 用于存储原始数据
all_data_scaled = pd.DataFrame()  # 初始化一个空的 DataFrame 用于存储标准化后的数据
processed_count = 0  # 初始化计数器
total_count = len(stock_list)  # 获取总股票数量
scaler = StandardScaler()

for i in stock_list[:]:
    NUM = i
    try:
        # 下载原始数据
        raw_data = download_data(NUM, args)
        # 更新已处理股票数量计数器
        processed_count += 1
        # 检查数据长度，如果小于300则跳过此次循环
        if raw_data.shape[0] < 500:
            print(f"股票代码 {NUM} 的数据长度小于300,跳过此次循环。")
            continue
        
        # 拼接数据，添加各种参数
        ad_data = add_data(raw_data, args)
        # 添加预测标签
        ad_data = add_label(ad_data, args)
        # 删除无效数据
        final_data_raw = sub_data(ad_data.copy(), args)
        final_data_scaled = final_data_raw.copy()
        
        # 未处理数据的前20行替换为0
        if args.data_addzero and not all_data_raw.empty:
            final_data_raw = add_zeros_to_data(final_data_raw, num_rows=args.data_addzero)

        # 标准化处理
        if args.down_scaler:
            non_time_columns = final_data_scaled.columns[1:-1]  # 假设时间列是第一列
            final_data_scaled[non_time_columns] = scaler.fit_transform(final_data_scaled[non_time_columns])
            # 标准化处理的数据的前20行替换为0
            if args.data_addzero and not all_data_scaled.empty:
                final_data_scaled = add_zeros_to_data(final_data_scaled, num_rows=args.data_addzero)
        
        # 如果 all 为 False, 则为每个股票单独保存数据
        if not args.all:
            file_name_raw_individual = f"raw_stock_cy_{NUM}.csv"
            final_data_raw.to_csv(args.root_path + file_name_raw_individual, index=False)

            if args.down_scaler:
                file_name_scaled_individual = f"scaled_stock_cy_{NUM}.csv"
                final_data_scaled.to_csv(args.root_path + file_name_scaled_individual, index=False)
                print(f"股票代码 {NUM} 的数据保存到 {file_name_raw_individual} ，形状: {final_data_raw.shape}")
        else:
            # 拼接未处理的数据
            all_data_raw = pd.concat([all_data_raw, final_data_raw], ignore_index=True)
            if args.down_scaler:
                # 拼接经过标准化的数据
                all_data_scaled = pd.concat([all_data_scaled, final_data_scaled], ignore_index=True)
            print(f"当前all_data的形状: {all_data_raw.shape}")

    except Exception as e:
        print(f"处理股票代码 {NUM} 时出现错误: {e}")
        continue

    # 计算并打印处理进度
    progress = processed_count / total_count
    print(f"处理进度: {processed_count}/{total_count} ({progress:.2%})")

# 如果 all 为 True, 则保存合并后的数据
if args.all:
    time = datetime.now().strftime("%Y_%m_%d_%H_%M_%S")
    file_name_raw = "stock_cy_all_raw.csv"
    all_data_raw.to_csv(args.root_path + time + file_name_raw, index=False)
    if args.down_scaler:
        file_name_scaled = "stock_cy_all_scaled.csv"
        all_data_scaled.to_csv(args.root_path + time + file_name_scaled, index=False)
    print("合并数据保存完毕。")
else:
    print("单独数据保存完毕。")
# Out:
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (512, 9)
# 添加数据以后形状： (512, 23)
# 添加label以后数据形状: (512, 25)
# 删除指定行、列后数据形状:  (409, 20)
# 当前all_data的形状: (409, 20)
# 处理进度: 1/591 (0.17%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (522, 9)
# 添加数据以后形状： (522, 23)
# 添加label以后数据形状: (522, 25)
# 删除指定行、列后数据形状:  (419, 20)
# 当前all_data的形状: (828, 20)
# 处理进度: 2/591 (0.34%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1833, 9)
# 添加数据以后形状： (1833, 23)
# 添加label以后数据形状: (1833, 25)
# 删除指定行、列后数据形状:  (1730, 20)
# 当前all_data的形状: (2558, 20)
# 处理进度: 3/591 (0.51%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1623, 9)
# 添加数据以后形状： (1623, 23)
# 添加label以后数据形状: (1623, 25)
# 删除指定行、列后数据形状:  (1520, 20)
# 当前all_data的形状: (4078, 20)
# 处理进度: 4/591 (0.68%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (610, 9)
# 添加数据以后形状： (610, 23)
# 添加label以后数据形状: (610, 25)
# 删除指定行、列后数据形状:  (507, 20)
# 当前all_data的形状: (4585, 20)
# 处理进度: 5/591 (0.85%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1718, 9)
# 添加数据以后形状： (1718, 23)
# 添加label以后数据形状: (1718, 25)
# 删除指定行、列后数据形状:  (1615, 20)
# 当前all_data的形状: (6200, 20)
# 处理进度: 6/591 (1.02%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1791, 9)
# 添加数据以后形状： (1791, 23)
# 添加label以后数据形状: (1791, 25)
# 删除指定行、列后数据形状:  (1688, 20)
# 当前all_data的形状: (7888, 20)
# 处理进度: 7/591 (1.18%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 23)
# 添加label以后数据形状: (1968, 25)
# 删除指定行、列后数据形状:  (1865, 20)
# 当前all_data的形状: (9753, 20)
# 处理进度: 8/591 (1.35%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1105, 9)
# 添加数据以后形状： (1105, 23)
# 添加label以后数据形状: (1105, 25)
# 删除指定行、列后数据形状:  (1002, 20)
# 当前all_data的形状: (10755, 20)
# 处理进度: 9/591 (1.52%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1880, 9)
# 添加数据以后形状： (1880, 23)
# 添加label以后数据形状: (1880, 25)
# 删除指定行、列后数据形状:  (1777, 20)
# 当前all_data的形状: (12532, 20)
# 处理进度: 10/591 (1.69%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1566, 9)
# 添加数据以后形状： (1566, 23)
# 添加label以后数据形状: (1566, 25)
# 删除指定行、列后数据形状:  (1463, 20)
# 当前all_data的形状: (13995, 20)
# 处理进度: 11/591 (1.86%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1937, 9)
# 添加数据以后形状： (1937, 23)
# 添加label以后数据形状: (1937, 25)
# 删除指定行、列后数据形状:  (1834, 20)
# 当前all_data的形状: (15829, 20)
# 处理进度: 12/591 (2.03%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1491, 9)
# 添加数据以后形状： (1491, 23)
# 添加label以后数据形状: (1491, 25)
# 删除指定行、列后数据形状:  (1388, 20)
# 当前all_data的形状: (17217, 20)
# 处理进度: 13/591 (2.20%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1641, 9)
# 添加数据以后形状： (1641, 23)
# 添加label以后数据形状: (1641, 25)
# 删除指定行、列后数据形状:  (1538, 20)
# 当前all_data的形状: (18755, 20)
# 处理进度: 14/591 (2.37%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1139, 9)
# 添加数据以后形状： (1139, 23)
# 添加label以后数据形状: (1139, 25)
# 删除指定行、列后数据形状:  (1036, 20)
# 当前all_data的形状: (19791, 20)
# 处理进度: 15/591 (2.54%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (469, 9)
# 股票代码 301123 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1884, 9)
# 添加数据以后形状： (1884, 23)
# 添加label以后数据形状: (1884, 25)
# 删除指定行、列后数据形状:  (1781, 20)
# 当前all_data的形状: (21572, 20)
# 处理进度: 17/591 (2.88%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (398, 9)
# 股票代码 301153 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (392, 9)
# 股票代码 301191 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (946, 9)
# 添加数据以后形状： (946, 23)
# 添加label以后数据形状: (946, 25)
# 删除指定行、列后数据形状:  (843, 20)
# 当前all_data的形状: (22415, 20)
# 处理进度: 20/591 (3.38%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (541, 9)
# 添加数据以后形状： (541, 23)
# 添加label以后数据形状: (541, 25)
# 删除指定行、列后数据形状:  (438, 20)
# 当前all_data的形状: (22853, 20)
# 处理进度: 21/591 (3.55%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1435, 9)
# 添加数据以后形状： (1435, 23)
# 添加label以后数据形状: (1435, 25)
# 删除指定行、列后数据形状:  (1332, 20)
# 当前all_data的形状: (24185, 20)
# 处理进度: 22/591 (3.72%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (101, 9)
# 股票代码 301509 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1903, 9)
# 添加数据以后形状： (1903, 23)
# 添加label以后数据形状: (1903, 25)
# 删除指定行、列后数据形状:  (1800, 20)
# 当前all_data的形状: (25985, 20)
# 处理进度: 24/591 (4.06%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1003, 9)
# 添加数据以后形状： (1003, 23)
# 添加label以后数据形状: (1003, 25)
# 删除指定行、列后数据形状:  (900, 20)
# 当前all_data的形状: (26885, 20)
# 处理进度: 25/591 (4.23%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1665, 9)
# 添加数据以后形状： (1665, 23)
# 添加label以后数据形状: (1665, 25)
# 删除指定行、列后数据形状:  (1562, 20)
# 当前all_data的形状: (28447, 20)
# 处理进度: 26/591 (4.40%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1958, 9)
# 添加数据以后形状： (1958, 23)
# 添加label以后数据形状: (1958, 25)
# 删除指定行、列后数据形状:  (1855, 20)
# 当前all_data的形状: (30302, 20)
# 处理进度: 27/591 (4.57%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1960, 9)
# 添加数据以后形状： (1960, 23)
# 添加label以后数据形状: (1960, 25)
# 删除指定行、列后数据形状:  (1857, 20)
# 当前all_data的形状: (32159, 20)
# 处理进度: 28/591 (4.74%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (660, 9)
# 添加数据以后形状： (660, 23)
# 添加label以后数据形状: (660, 25)
# 删除指定行、列后数据形状:  (557, 20)
# 当前all_data的形状: (32716, 20)
# 处理进度: 29/591 (4.91%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (575, 9)
# 添加数据以后形状： (575, 23)
# 添加label以后数据形状: (575, 25)
# 删除指定行、列后数据形状:  (472, 20)
# 当前all_data的形状: (33188, 20)
# 处理进度: 30/591 (5.08%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (500, 9)
# 添加数据以后形状： (500, 23)
# 添加label以后数据形状: (500, 25)
# 删除指定行、列后数据形状:  (397, 20)
# 当前all_data的形状: (33585, 20)
# 处理进度: 31/591 (5.25%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1955, 9)
# 添加数据以后形状： (1955, 23)
# 添加label以后数据形状: (1955, 25)
# 删除指定行、列后数据形状:  (1852, 20)
# 当前all_data的形状: (35437, 20)
# 处理进度: 32/591 (5.41%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1003, 9)
# 添加数据以后形状： (1003, 23)
# 添加label以后数据形状: (1003, 25)
# 删除指定行、列后数据形状:  (900, 20)
# 当前all_data的形状: (36337, 20)
# 处理进度: 33/591 (5.58%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (729, 9)
# 添加数据以后形状： (729, 23)
# 添加label以后数据形状: (729, 25)
# 删除指定行、列后数据形状:  (626, 20)
# 当前all_data的形状: (36963, 20)
# 处理进度: 34/591 (5.75%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1773, 9)
# 添加数据以后形状： (1773, 23)
# 添加label以后数据形状: (1773, 25)
# 删除指定行、列后数据形状:  (1670, 20)
# 当前all_data的形状: (38633, 20)
# 处理进度: 35/591 (5.92%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 23)
# 添加label以后数据形状: (1968, 25)
# 删除指定行、列后数据形状:  (1865, 20)
# 当前all_data的形状: (40498, 20)
# 处理进度: 36/591 (6.09%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1124, 9)
# 添加数据以后形状： (1124, 23)
# 添加label以后数据形状: (1124, 25)
# 删除指定行、列后数据形状:  (1021, 20)
# 当前all_data的形状: (41519, 20)
# 处理进度: 37/591 (6.26%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (502, 9)
# 添加数据以后形状： (502, 23)
# 添加label以后数据形状: (502, 25)
# 删除指定行、列后数据形状:  (399, 20)
# 当前all_data的形状: (41918, 20)
# 处理进度: 38/591 (6.43%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1658, 9)
# 添加数据以后形状： (1658, 23)
# 添加label以后数据形状: (1658, 25)
# 删除指定行、列后数据形状:  (1555, 20)
# 当前all_data的形状: (43473, 20)
# 处理进度: 39/591 (6.60%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (332, 9)
# 股票代码 301171 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1, 9)
# 股票代码 301566 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (965, 9)
# 添加数据以后形状： (965, 23)
# 添加label以后数据形状: (965, 25)
# 删除指定行、列后数据形状:  (862, 20)
# 当前all_data的形状: (44335, 20)
# 处理进度: 42/591 (7.11%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (881, 9)
# 添加数据以后形状： (881, 23)
# 添加label以后数据形状: (881, 25)
# 删除指定行、列后数据形状:  (778, 20)
# 当前all_data的形状: (45113, 20)
# 处理进度: 43/591 (7.28%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1952, 9)
# 添加数据以后形状： (1952, 23)
# 添加label以后数据形状: (1952, 25)
# 删除指定行、列后数据形状:  (1849, 20)
# 当前all_data的形状: (46962, 20)
# 处理进度: 44/591 (7.45%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (92, 9)
# 股票代码 301498 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1002, 9)
# 添加数据以后形状： (1002, 23)
# 添加label以后数据形状: (1002, 25)
# 删除指定行、列后数据形状:  (899, 20)
# 当前all_data的形状: (47861, 20)
# 处理进度: 46/591 (7.78%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1667, 9)
# 添加数据以后形状： (1667, 23)
# 添加label以后数据形状: (1667, 25)
# 删除指定行、列后数据形状:  (1564, 20)
# 当前all_data的形状: (49425, 20)
# 处理进度: 47/591 (7.95%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (287, 9)
# 股票代码 301389 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 23)
# 添加label以后数据形状: (1968, 25)
# 删除指定行、列后数据形状:  (1865, 20)
# 当前all_data的形状: (51290, 20)
# 处理进度: 49/591 (8.29%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1958, 9)
# 添加数据以后形状： (1958, 23)
# 添加label以后数据形状: (1958, 25)
# 删除指定行、列后数据形状:  (1855, 20)
# 当前all_data的形状: (53145, 20)
# 处理进度: 50/591 (8.46%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (534, 9)
# 添加数据以后形状： (534, 23)
# 添加label以后数据形状: (534, 25)
# 删除指定行、列后数据形状:  (431, 20)
# 当前all_data的形状: (53576, 20)
# 处理进度: 51/591 (8.63%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (192, 9)
# 股票代码 301345 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1252, 9)
# 添加数据以后形状： (1252, 23)
# 添加label以后数据形状: (1252, 25)
# 删除指定行、列后数据形状:  (1149, 20)
# 当前all_data的形状: (54725, 20)
# 处理进度: 53/591 (8.97%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1881, 9)
# 添加数据以后形状： (1881, 23)
# 添加label以后数据形状: (1881, 25)
# 删除指定行、列后数据形状:  (1778, 20)
# 当前all_data的形状: (56503, 20)
# 处理进度: 54/591 (9.14%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (70, 9)
# 股票代码 301550 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (926, 9)
# 添加数据以后形状： (926, 23)
# 添加label以后数据形状: (926, 25)
# 删除指定行、列后数据形状:  (823, 20)
# 当前all_data的形状: (57326, 20)
# 处理进度: 56/591 (9.48%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1653, 9)
# 添加数据以后形状： (1653, 23)
# 添加label以后数据形状: (1653, 25)
# 删除指定行、列后数据形状:  (1550, 20)
# 当前all_data的形状: (58876, 20)
# 处理进度: 57/591 (9.64%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 23)
# 添加label以后数据形状: (1968, 25)
# 删除指定行、列后数据形状:  (1865, 20)
# 当前all_data的形状: (60741, 20)
# 处理进度: 58/591 (9.81%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1666, 9)
# 添加数据以后形状： (1666, 23)
# 添加label以后数据形状: (1666, 25)
# 删除指定行、列后数据形状:  (1563, 20)
# 当前all_data的形状: (62304, 20)
# 处理进度: 59/591 (9.98%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 23)
# 添加label以后数据形状: (1968, 25)
# 删除指定行、列后数据形状:  (1865, 20)
# 当前all_data的形状: (64169, 20)
# 处理进度: 60/591 (10.15%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (347, 9)
# 股票代码 301269 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1966, 9)
# 添加数据以后形状： (1966, 23)
# 添加label以后数据形状: (1966, 25)
# 删除指定行、列后数据形状:  (1863, 20)
# 当前all_data的形状: (66032, 20)
# 处理进度: 62/591 (10.49%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1865, 9)
# 添加数据以后形状： (1865, 23)
# 添加label以后数据形状: (1865, 25)
# 删除指定行、列后数据形状:  (1762, 20)
# 当前all_data的形状: (67794, 20)
# 处理进度: 63/591 (10.66%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (840, 9)
# 添加数据以后形状： (840, 23)
# 添加label以后数据形状: (840, 25)
# 删除指定行、列后数据形状:  (737, 20)
# 当前all_data的形状: (68531, 20)
# 处理进度: 64/591 (10.83%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (307, 9)
# 股票代码 301366 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1824, 9)
# 添加数据以后形状： (1824, 23)
# 添加label以后数据形状: (1824, 25)
# 删除指定行、列后数据形状:  (1721, 20)
# 当前all_data的形状: (70252, 20)
# 处理进度: 66/591 (11.17%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (728, 9)
# 添加数据以后形状： (728, 23)
# 添加label以后数据形状: (728, 25)
# 删除指定行、列后数据形状:  (625, 20)
# 当前all_data的形状: (70877, 20)
# 处理进度: 67/591 (11.34%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (724, 9)
# 添加数据以后形状： (724, 23)
# 添加label以后数据形状: (724, 25)
# 删除指定行、列后数据形状:  (621, 20)
# 当前all_data的形状: (71498, 20)
# 处理进度: 68/591 (11.51%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (644, 9)
# 添加数据以后形状： (644, 23)
# 添加label以后数据形状: (644, 25)
# 删除指定行、列后数据形状:  (541, 20)
# 当前all_data的形状: (72039, 20)
# 处理进度: 69/591 (11.68%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (838, 9)
# 添加数据以后形状： (838, 23)
# 添加label以后数据形状: (838, 25)
# 删除指定行、列后数据形状:  (735, 20)
# 当前all_data的形状: (72774, 20)
# 处理进度: 70/591 (11.84%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1651, 9)
# 添加数据以后形状： (1651, 23)
# 添加label以后数据形状: (1651, 25)
# 删除指定行、列后数据形状:  (1548, 20)
# 当前all_data的形状: (74322, 20)
# 处理进度: 71/591 (12.01%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1884, 9)
# 添加数据以后形状： (1884, 23)
# 添加label以后数据形状: (1884, 25)
# 删除指定行、列后数据形状:  (1781, 20)
# 当前all_data的形状: (76103, 20)
# 处理进度: 72/591 (12.18%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1914, 9)
# 添加数据以后形状： (1914, 23)
# 添加label以后数据形状: (1914, 25)
# 删除指定行、列后数据形状:  (1811, 20)
# 当前all_data的形状: (77914, 20)
# 处理进度: 73/591 (12.35%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (66, 9)
# 股票代码 301500 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1844, 9)
# 添加数据以后形状： (1844, 23)
# 添加label以后数据形状: (1844, 25)
# 删除指定行、列后数据形状:  (1741, 20)
# 当前all_data的形状: (79655, 20)
# 处理进度: 75/591 (12.69%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1866, 9)
# 添加数据以后形状： (1866, 23)
# 添加label以后数据形状: (1866, 25)
# 删除指定行、列后数据形状:  (1763, 20)
# 当前all_data的形状: (81418, 20)
# 处理进度: 76/591 (12.86%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (701, 9)
# 添加数据以后形状： (701, 23)
# 添加label以后数据形状: (701, 25)
# 删除指定行、列后数据形状:  (598, 20)
# 当前all_data的形状: (82016, 20)
# 处理进度: 77/591 (13.03%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (117, 9)
# 股票代码 301393 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (629, 9)
# 添加数据以后形状： (629, 23)
# 添加label以后数据形状: (629, 25)
# 删除指定行、列后数据形状:  (526, 20)
# 当前all_data的形状: (82542, 20)
# 处理进度: 79/591 (13.37%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (362, 9)
# 股票代码 301175 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1914, 9)
# 添加数据以后形状： (1914, 23)
# 添加label以后数据形状: (1914, 25)
# 删除指定行、列后数据形状:  (1811, 20)
# 当前all_data的形状: (84353, 20)
# 处理进度: 81/591 (13.71%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1825, 9)
# 添加数据以后形状： (1825, 23)
# 添加label以后数据形状: (1825, 25)
# 删除指定行、列后数据形状:  (1722, 20)
# 当前all_data的形状: (86075, 20)
# 处理进度: 82/591 (13.87%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1921, 9)
# 添加数据以后形状： (1921, 23)
# 添加label以后数据形状: (1921, 25)
# 删除指定行、列后数据形状:  (1818, 20)
# 当前all_data的形状: (87893, 20)
# 处理进度: 83/591 (14.04%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1637, 9)
# 添加数据以后形状： (1637, 23)
# 添加label以后数据形状: (1637, 25)
# 删除指定行、列后数据形状:  (1534, 20)
# 当前all_data的形状: (89427, 20)
# 处理进度: 84/591 (14.21%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 23)
# 添加label以后数据形状: (1968, 25)
# 删除指定行、列后数据形状:  (1865, 20)
# 当前all_data的形状: (91292, 20)
# 处理进度: 85/591 (14.38%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1965, 9)
# 添加数据以后形状： (1965, 23)
# 添加label以后数据形状: (1965, 25)
# 删除指定行、列后数据形状:  (1862, 20)
# 当前all_data的形状: (93154, 20)
# 处理进度: 86/591 (14.55%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1035, 9)
# 添加数据以后形状： (1035, 23)
# 添加label以后数据形状: (1035, 25)
# 删除指定行、列后数据形状:  (932, 20)
# 当前all_data的形状: (94086, 20)
# 处理进度: 87/591 (14.72%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (444, 9)
# 股票代码 301215 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1489, 9)
# 添加数据以后形状： (1489, 23)
# 添加label以后数据形状: (1489, 25)
# 删除指定行、列后数据形状:  (1386, 20)
# 当前all_data的形状: (95472, 20)
# 处理进度: 89/591 (15.06%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (653, 9)
# 添加数据以后形状： (653, 23)
# 添加label以后数据形状: (653, 25)
# 删除指定行、列后数据形状:  (550, 20)
# 当前all_data的形状: (96022, 20)
# 处理进度: 90/591 (15.23%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (496, 9)
# 股票代码 301101 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (78, 9)
# 股票代码 301507 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 23)
# 添加label以后数据形状: (1968, 25)
# 删除指定行、列后数据形状:  (1865, 20)
# 当前all_data的形状: (97887, 20)
# 处理进度: 93/591 (15.74%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (316, 9)
# 股票代码 301205 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1810, 9)
# 添加数据以后形状： (1810, 23)
# 添加label以后数据形状: (1810, 25)
# 删除指定行、列后数据形状:  (1707, 20)
# 当前all_data的形状: (99594, 20)
# 处理进度: 95/591 (16.07%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1196, 9)
# 添加数据以后形状： (1196, 23)
# 添加label以后数据形状: (1196, 25)
# 删除指定行、列后数据形状:  (1093, 20)
# 当前all_data的形状: (100687, 20)
# 处理进度: 96/591 (16.24%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (130, 9)
# 股票代码 301376 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1152, 9)
# 添加数据以后形状： (1152, 23)
# 添加label以后数据形状: (1152, 25)
# 删除指定行、列后数据形状:  (1049, 20)
# 当前all_data的形状: (101736, 20)
# 处理进度: 98/591 (16.58%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1764, 9)
# 添加数据以后形状： (1764, 23)
# 添加label以后数据形状: (1764, 25)
# 删除指定行、列后数据形状:  (1661, 20)
# 当前all_data的形状: (103397, 20)
# 处理进度: 99/591 (16.75%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1700, 9)
# 添加数据以后形状： (1700, 23)
# 添加label以后数据形状: (1700, 25)
# 删除指定行、列后数据形状:  (1597, 20)
# 当前all_data的形状: (104994, 20)
# 处理进度: 100/591 (16.92%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (271, 9)
# 股票代码 301377 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1552, 9)
# 添加数据以后形状： (1552, 23)
# 添加label以后数据形状: (1552, 25)
# 删除指定行、列后数据形状:  (1449, 20)
# 当前all_data的形状: (106443, 20)
# 处理进度: 102/591 (17.26%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1629, 9)
# 添加数据以后形状： (1629, 23)
# 添加label以后数据形状: (1629, 25)
# 删除指定行、列后数据形状:  (1526, 20)
# 当前all_data的形状: (107969, 20)
# 处理进度: 103/591 (17.43%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (815, 9)
# 添加数据以后形状： (815, 23)
# 添加label以后数据形状: (815, 25)
# 删除指定行、列后数据形状:  (712, 20)
# 当前all_data的形状: (108681, 20)
# 处理进度: 104/591 (17.60%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1608, 9)
# 添加数据以后形状： (1608, 23)
# 添加label以后数据形状: (1608, 25)
# 删除指定行、列后数据形状:  (1505, 20)
# 当前all_data的形状: (110186, 20)
# 处理进度: 105/591 (17.77%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (693, 9)
# 添加数据以后形状： (693, 23)
# 添加label以后数据形状: (693, 25)
# 删除指定行、列后数据形状:  (590, 20)
# 当前all_data的形状: (110776, 20)
# 处理进度: 106/591 (17.94%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1893, 9)
# 添加数据以后形状： (1893, 23)
# 添加label以后数据形状: (1893, 25)
# 删除指定行、列后数据形状:  (1790, 20)
# 当前all_data的形状: (112566, 20)
# 处理进度: 107/591 (18.10%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1691, 9)
# 添加数据以后形状： (1691, 23)
# 添加label以后数据形状: (1691, 25)
# 删除指定行、列后数据形状:  (1588, 20)
# 当前all_data的形状: (114154, 20)
# 处理进度: 108/591 (18.27%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1918, 9)
# 添加数据以后形状： (1918, 23)
# 添加label以后数据形状: (1918, 25)
# 删除指定行、列后数据形状:  (1815, 20)
# 当前all_data的形状: (115969, 20)
# 处理进度: 109/591 (18.44%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1909, 9)
# 添加数据以后形状： (1909, 23)
# 添加label以后数据形状: (1909, 25)
# 删除指定行、列后数据形状:  (1806, 20)
# 当前all_data的形状: (117775, 20)
# 处理进度: 110/591 (18.61%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1488, 9)
# 添加数据以后形状： (1488, 23)
# 添加label以后数据形状: (1488, 25)
# 删除指定行、列后数据形状:  (1385, 20)
# 当前all_data的形状: (119160, 20)
# 处理进度: 111/591 (18.78%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1961, 9)
# 添加数据以后形状： (1961, 23)
# 添加label以后数据形状: (1961, 25)
# 删除指定行、列后数据形状:  (1858, 20)
# 当前all_data的形状: (121018, 20)
# 处理进度: 112/591 (18.95%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1910, 9)
# 添加数据以后形状： (1910, 23)
# 添加label以后数据形状: (1910, 25)
# 删除指定行、列后数据形状:  (1807, 20)
# 当前all_data的形状: (122825, 20)
# 处理进度: 113/591 (19.12%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1399, 9)
# 添加数据以后形状： (1399, 23)
# 添加label以后数据形状: (1399, 25)
# 删除指定行、列后数据形状:  (1296, 20)
# 当前all_data的形状: (124121, 20)
# 处理进度: 114/591 (19.29%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1803, 9)
# 添加数据以后形状： (1803, 23)
# 添加label以后数据形状: (1803, 25)
# 删除指定行、列后数据形状:  (1700, 20)
# 当前all_data的形状: (125821, 20)
# 处理进度: 115/591 (19.46%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1614, 9)
# 添加数据以后形状： (1614, 23)
# 添加label以后数据形状: (1614, 25)
# 删除指定行、列后数据形状:  (1511, 20)
# 当前all_data的形状: (127332, 20)
# 处理进度: 116/591 (19.63%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 23)
# 添加label以后数据形状: (1968, 25)
# 删除指定行、列后数据形状:  (1865, 20)
# 当前all_data的形状: (129197, 20)
# 处理进度: 117/591 (19.80%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1730, 9)
# 添加数据以后形状： (1730, 23)
# 添加label以后数据形状: (1730, 25)
# 删除指定行、列后数据形状:  (1627, 20)
# 当前all_data的形状: (130824, 20)
# 处理进度: 118/591 (19.97%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 23)
# 添加label以后数据形状: (1968, 25)
# 删除指定行、列后数据形状:  (1865, 20)
# 当前all_data的形状: (132689, 20)
# 处理进度: 119/591 (20.14%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (837, 9)
# 添加数据以后形状： (837, 23)
# 添加label以后数据形状: (837, 25)
# 删除指定行、列后数据形状:  (734, 20)
# 当前all_data的形状: (133423, 20)
# 处理进度: 120/591 (20.30%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1745, 9)
# 添加数据以后形状： (1745, 23)
# 添加label以后数据形状: (1745, 25)
# 删除指定行、列后数据形状:  (1642, 20)
# 当前all_data的形状: (135065, 20)
# 处理进度: 121/591 (20.47%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 23)
# 添加label以后数据形状: (1968, 25)
# 删除指定行、列后数据形状:  (1865, 20)
# 当前all_data的形状: (136930, 20)
# 处理进度: 122/591 (20.64%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1889, 9)
# 添加数据以后形状： (1889, 23)
# 添加label以后数据形状: (1889, 25)
# 删除指定行、列后数据形状:  (1786, 20)
# 当前all_data的形状: (138716, 20)
# 处理进度: 123/591 (20.81%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1931, 9)
# 添加数据以后形状： (1931, 23)
# 添加label以后数据形状: (1931, 25)
# 删除指定行、列后数据形状:  (1828, 20)
# 当前all_data的形状: (140544, 20)
# 处理进度: 124/591 (20.98%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (243, 9)
# 股票代码 301297 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1763, 9)
# 添加数据以后形状： (1763, 23)
# 添加label以后数据形状: (1763, 25)
# 删除指定行、列后数据形状:  (1660, 20)
# 当前all_data的形状: (142204, 20)
# 处理进度: 126/591 (21.32%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1587, 9)
# 添加数据以后形状： (1587, 23)
# 添加label以后数据形状: (1587, 25)
# 删除指定行、列后数据形状:  (1484, 20)
# 当前all_data的形状: (143688, 20)
# 处理进度: 127/591 (21.49%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1887, 9)
# 添加数据以后形状： (1887, 23)
# 添加label以后数据形状: (1887, 25)
# 删除指定行、列后数据形状:  (1784, 20)
# 当前all_data的形状: (145472, 20)
# 处理进度: 128/591 (21.66%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (798, 9)
# 添加数据以后形状： (798, 23)
# 添加label以后数据形状: (798, 25)
# 删除指定行、列后数据形状:  (695, 20)
# 当前all_data的形状: (146167, 20)
# 处理进度: 129/591 (21.83%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1906, 9)
# 添加数据以后形状： (1906, 23)
# 添加label以后数据形状: (1906, 25)
# 删除指定行、列后数据形状:  (1803, 20)
# 当前all_data的形状: (147970, 20)
# 处理进度: 130/591 (22.00%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (658, 9)
# 添加数据以后形状： (658, 23)
# 添加label以后数据形状: (658, 25)
# 删除指定行、列后数据形状:  (555, 20)
# 当前all_data的形状: (148525, 20)
# 处理进度: 131/591 (22.17%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1330, 9)
# 添加数据以后形状： (1330, 23)
# 添加label以后数据形状: (1330, 25)
# 删除指定行、列后数据形状:  (1227, 20)
# 当前all_data的形状: (149752, 20)
# 处理进度: 132/591 (22.34%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1961, 9)
# 添加数据以后形状： (1961, 23)
# 添加label以后数据形状: (1961, 25)
# 删除指定行、列后数据形状:  (1858, 20)
# 当前all_data的形状: (151610, 20)
# 处理进度: 133/591 (22.50%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1834, 9)
# 添加数据以后形状： (1834, 23)
# 添加label以后数据形状: (1834, 25)
# 删除指定行、列后数据形状:  (1731, 20)
# 当前all_data的形状: (153341, 20)
# 处理进度: 134/591 (22.67%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (656, 9)
# 添加数据以后形状： (656, 23)
# 添加label以后数据形状: (656, 25)
# 删除指定行、列后数据形状:  (553, 20)
# 当前all_data的形状: (153894, 20)
# 处理进度: 135/591 (22.84%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1680, 9)
# 添加数据以后形状： (1680, 23)
# 添加label以后数据形状: (1680, 25)
# 删除指定行、列后数据形状:  (1577, 20)
# 当前all_data的形状: (155471, 20)
# 处理进度: 136/591 (23.01%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1866, 9)
# 添加数据以后形状： (1866, 23)
# 添加label以后数据形状: (1866, 25)
# 删除指定行、列后数据形状:  (1763, 20)
# 当前all_data的形状: (157234, 20)
# 处理进度: 137/591 (23.18%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (173, 9)
# 股票代码 301387 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (475, 9)
# 股票代码 301117 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1907, 9)
# 添加数据以后形状： (1907, 23)
# 添加label以后数据形状: (1907, 25)
# 删除指定行、列后数据形状:  (1804, 20)
# 当前all_data的形状: (159038, 20)
# 处理进度: 140/591 (23.69%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1967, 9)
# 添加数据以后形状： (1967, 23)
# 添加label以后数据形状: (1967, 25)
# 删除指定行、列后数据形状:  (1864, 20)
# 当前all_data的形状: (160902, 20)
# 处理进度: 141/591 (23.86%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1707, 9)
# 添加数据以后形状： (1707, 23)
# 添加label以后数据形状: (1707, 25)
# 删除指定行、列后数据形状:  (1604, 20)
# 当前all_data的形状: (162506, 20)
# 处理进度: 142/591 (24.03%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 23)
# 添加label以后数据形状: (1968, 25)
# 删除指定行、列后数据形状:  (1865, 20)
# 当前all_data的形状: (164371, 20)
# 处理进度: 143/591 (24.20%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1693, 9)
# 添加数据以后形状： (1693, 23)
# 添加label以后数据形状: (1693, 25)
# 删除指定行、列后数据形状:  (1590, 20)
# 当前all_data的形状: (165961, 20)
# 处理进度: 144/591 (24.37%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1870, 9)
# 添加数据以后形状： (1870, 23)
# 添加label以后数据形状: (1870, 25)
# 删除指定行、列后数据形状:  (1767, 20)
# 当前all_data的形状: (167728, 20)
# 处理进度: 145/591 (24.53%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1752, 9)
# 添加数据以后形状： (1752, 23)
# 添加label以后数据形状: (1752, 25)
# 删除指定行、列后数据形状:  (1649, 20)
# 当前all_data的形状: (169377, 20)
# 处理进度: 146/591 (24.70%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1501, 9)
# 添加数据以后形状： (1501, 23)
# 添加label以后数据形状: (1501, 25)
# 删除指定行、列后数据形状:  (1398, 20)
# 当前all_data的形状: (170775, 20)
# 处理进度: 147/591 (24.87%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1939, 9)
# 添加数据以后形状： (1939, 23)
# 添加label以后数据形状: (1939, 25)
# 删除指定行、列后数据形状:  (1836, 20)
# 当前all_data的形状: (172611, 20)
# 处理进度: 148/591 (25.04%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (456, 9)
# 股票代码 301207 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (107, 9)
# 股票代码 301172 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (312, 9)
# 股票代码 301327 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1092, 9)
# 添加数据以后形状： (1092, 23)
# 添加label以后数据形状: (1092, 25)
# 删除指定行、列后数据形状:  (989, 20)
# 当前all_data的形状: (173600, 20)
# 处理进度: 152/591 (25.72%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1560, 9)
# 添加数据以后形状： (1560, 23)
# 添加label以后数据形状: (1560, 25)
# 删除指定行、列后数据形状:  (1457, 20)
# 当前all_data的形状: (175057, 20)
# 处理进度: 153/591 (25.89%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 23)
# 添加label以后数据形状: (1968, 25)
# 删除指定行、列后数据形状:  (1865, 20)
# 当前all_data的形状: (176922, 20)
# 处理进度: 154/591 (26.06%)
# 处理股票代码 300480 时出现错误: Expecting value: line 1 column 1 (char 0)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1186, 9)
# 添加数据以后形状： (1186, 23)
# 添加label以后数据形状: (1186, 25)
# 删除指定行、列后数据形状:  (1083, 20)
# 当前all_data的形状: (178005, 20)
# 处理进度: 155/591 (26.23%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (96, 9)
# 股票代码 301348 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (701, 9)
# 添加数据以后形状： (701, 23)
# 添加label以后数据形状: (701, 25)
# 删除指定行、列后数据形状:  (598, 20)
# 当前all_data的形状: (178603, 20)
# 处理进度: 157/591 (26.57%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1526, 9)
# 添加数据以后形状： (1526, 23)
# 添加label以后数据形状: (1526, 25)
# 删除指定行、列后数据形状:  (1423, 20)
# 当前all_data的形状: (180026, 20)
# 处理进度: 158/591 (26.73%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (530, 9)
# 添加数据以后形状： (530, 23)
# 添加label以后数据形状: (530, 25)
# 删除指定行、列后数据形状:  (427, 20)
# 当前all_data的形状: (180453, 20)
# 处理进度: 159/591 (26.90%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1963, 9)
# 添加数据以后形状： (1963, 23)
# 添加label以后数据形状: (1963, 25)
# 删除指定行、列后数据形状:  (1860, 20)
# 当前all_data的形状: (182313, 20)
# 处理进度: 160/591 (27.07%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1190, 9)
# 添加数据以后形状： (1190, 23)
# 添加label以后数据形状: (1190, 25)
# 删除指定行、列后数据形状:  (1087, 20)
# 当前all_data的形状: (183400, 20)
# 处理进度: 161/591 (27.24%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (613, 9)
# 添加数据以后形状： (613, 23)
# 添加label以后数据形状: (613, 25)
# 删除指定行、列后数据形状:  (510, 20)
# 当前all_data的形状: (183910, 20)
# 处理进度: 162/591 (27.41%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1890, 9)
# 添加数据以后形状： (1890, 23)
# 添加label以后数据形状: (1890, 25)
# 删除指定行、列后数据形状:  (1787, 20)
# 当前all_data的形状: (185697, 20)
# 处理进度: 163/591 (27.58%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1707, 9)
# 添加数据以后形状： (1707, 23)
# 添加label以后数据形状: (1707, 25)
# 删除指定行、列后数据形状:  (1604, 20)
# 当前all_data的形状: (187301, 20)
# 处理进度: 164/591 (27.75%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 23)
# 添加label以后数据形状: (1968, 25)
# 删除指定行、列后数据形状:  (1865, 20)
# 当前all_data的形状: (189166, 20)
# 处理进度: 165/591 (27.92%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (549, 9)
# 添加数据以后形状： (549, 23)
# 添加label以后数据形状: (549, 25)
# 删除指定行、列后数据形状:  (446, 20)
# 当前all_data的形状: (189612, 20)
# 处理进度: 166/591 (28.09%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1949, 9)
# 添加数据以后形状： (1949, 23)
# 添加label以后数据形状: (1949, 25)
# 删除指定行、列后数据形状:  (1846, 20)
# 当前all_data的形状: (191458, 20)
# 处理进度: 167/591 (28.26%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1148, 9)
# 添加数据以后形状： (1148, 23)
# 添加label以后数据形状: (1148, 25)
# 删除指定行、列后数据形状:  (1045, 20)
# 当前all_data的形状: (192503, 20)
# 处理进度: 168/591 (28.43%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (103, 9)
# 股票代码 301371 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1764, 9)
# 添加数据以后形状： (1764, 23)
# 添加label以后数据形状: (1764, 25)
# 删除指定行、列后数据形状:  (1661, 20)
# 当前all_data的形状: (194164, 20)
# 处理进度: 170/591 (28.76%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1954, 9)
# 添加数据以后形状： (1954, 23)
# 添加label以后数据形状: (1954, 25)
# 删除指定行、列后数据形状:  (1851, 20)
# 当前all_data的形状: (196015, 20)
# 处理进度: 171/591 (28.93%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (593, 9)
# 添加数据以后形状： (593, 23)
# 添加label以后数据形状: (593, 25)
# 删除指定行、列后数据形状:  (490, 20)
# 当前all_data的形状: (196505, 20)
# 处理进度: 172/591 (29.10%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1954, 9)
# 添加数据以后形状： (1954, 23)
# 添加label以后数据形状: (1954, 25)
# 删除指定行、列后数据形状:  (1851, 20)
# 当前all_data的形状: (198356, 20)
# 处理进度: 173/591 (29.27%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (835, 9)
# 添加数据以后形状： (835, 23)
# 添加label以后数据形状: (835, 25)
# 删除指定行、列后数据形状:  (732, 20)
# 当前all_data的形状: (199088, 20)
# 处理进度: 174/591 (29.44%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1562, 9)
# 添加数据以后形状： (1562, 23)
# 添加label以后数据形状: (1562, 25)
# 删除指定行、列后数据形状:  (1459, 20)
# 当前all_data的形状: (200547, 20)
# 处理进度: 175/591 (29.61%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (318, 9)
# 股票代码 301328 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1834, 9)
# 添加数据以后形状： (1834, 23)
# 添加label以后数据形状: (1834, 25)
# 删除指定行、列后数据形状:  (1731, 20)
# 当前all_data的形状: (202278, 20)
# 处理进度: 177/591 (29.95%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1343, 9)
# 添加数据以后形状： (1343, 23)
# 添加label以后数据形状: (1343, 25)
# 删除指定行、列后数据形状:  (1240, 20)
# 当前all_data的形状: (203518, 20)
# 处理进度: 178/591 (30.12%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1038, 9)
# 添加数据以后形状： (1038, 23)
# 添加label以后数据形状: (1038, 25)
# 删除指定行、列后数据形状:  (935, 20)
# 当前all_data的形状: (204453, 20)
# 处理进度: 179/591 (30.29%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (194, 9)
# 股票代码 301439 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1797, 9)
# 添加数据以后形状： (1797, 23)
# 添加label以后数据形状: (1797, 25)
# 删除指定行、列后数据形状:  (1694, 20)
# 当前all_data的形状: (206147, 20)
# 处理进度: 181/591 (30.63%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 23)
# 添加label以后数据形状: (1968, 25)
# 删除指定行、列后数据形状:  (1865, 20)
# 当前all_data的形状: (208012, 20)
# 处理进度: 182/591 (30.80%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1840, 9)
# 添加数据以后形状： (1840, 23)
# 添加label以后数据形状: (1840, 25)
# 删除指定行、列后数据形状:  (1737, 20)
# 当前all_data的形状: (209749, 20)
# 处理进度: 183/591 (30.96%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1961, 9)
# 添加数据以后形状： (1961, 23)
# 添加label以后数据形状: (1961, 25)
# 删除指定行、列后数据形状:  (1858, 20)
# 当前all_data的形状: (211607, 20)
# 处理进度: 184/591 (31.13%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1960, 9)
# 添加数据以后形状： (1960, 23)
# 添加label以后数据形状: (1960, 25)
# 删除指定行、列后数据形状:  (1857, 20)
# 当前all_data的形状: (213464, 20)
# 处理进度: 185/591 (31.30%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1789, 9)
# 添加数据以后形状： (1789, 23)
# 添加label以后数据形状: (1789, 25)
# 删除指定行、列后数据形状:  (1686, 20)
# 当前all_data的形状: (215150, 20)
# 处理进度: 186/591 (31.47%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1593, 9)
# 添加数据以后形状： (1593, 23)
# 添加label以后数据形状: (1593, 25)
# 删除指定行、列后数据形状:  (1490, 20)
# 当前all_data的形状: (216640, 20)
# 处理进度: 187/591 (31.64%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1953, 9)
# 添加数据以后形状： (1953, 23)
# 添加label以后数据形状: (1953, 25)
# 删除指定行、列后数据形状:  (1850, 20)
# 当前all_data的形状: (218490, 20)
# 处理进度: 188/591 (31.81%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 23)
# 添加label以后数据形状: (1968, 25)
# 删除指定行、列后数据形状:  (1865, 20)
# 当前all_data的形状: (220355, 20)
# 处理进度: 189/591 (31.98%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1891, 9)
# 添加数据以后形状： (1891, 23)
# 添加label以后数据形状: (1891, 25)
# 删除指定行、列后数据形状:  (1788, 20)
# 当前all_data的形状: (222143, 20)
# 处理进度: 190/591 (32.15%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1862, 9)
# 添加数据以后形状： (1862, 23)
# 添加label以后数据形状: (1862, 25)
# 删除指定行、列后数据形状:  (1759, 20)
# 当前all_data的形状: (223902, 20)
# 处理进度: 191/591 (32.32%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 23)
# 添加label以后数据形状: (1968, 25)
# 删除指定行、列后数据形状:  (1865, 20)
# 当前all_data的形状: (225767, 20)
# 处理进度: 192/591 (32.49%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1893, 9)
# 添加数据以后形状： (1893, 23)
# 添加label以后数据形状: (1893, 25)
# 删除指定行、列后数据形状:  (1790, 20)
# 当前all_data的形状: (227557, 20)
# 处理进度: 193/591 (32.66%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1868, 9)
# 添加数据以后形状： (1868, 23)
# 添加label以后数据形状: (1868, 25)
# 删除指定行、列后数据形状:  (1765, 20)
# 当前all_data的形状: (229322, 20)
# 处理进度: 194/591 (32.83%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1720, 9)
# 添加数据以后形状： (1720, 23)
# 添加label以后数据形状: (1720, 25)
# 删除指定行、列后数据形状:  (1617, 20)
# 当前all_data的形状: (230939, 20)
# 处理进度: 195/591 (32.99%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 23)
# 添加label以后数据形状: (1968, 25)
# 删除指定行、列后数据形状:  (1865, 20)
# 当前all_data的形状: (232804, 20)
# 处理进度: 196/591 (33.16%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1830, 9)
# 添加数据以后形状： (1830, 23)
# 添加label以后数据形状: (1830, 25)
# 删除指定行、列后数据形状:  (1727, 20)
# 当前all_data的形状: (234531, 20)
# 处理进度: 197/591 (33.33%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1793, 9)
# 添加数据以后形状： (1793, 23)
# 添加label以后数据形状: (1793, 25)
# 删除指定行、列后数据形状:  (1690, 20)
# 当前all_data的形状: (236221, 20)
# 处理进度: 198/591 (33.50%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (815, 9)
# 添加数据以后形状： (815, 23)
# 添加label以后数据形状: (815, 25)
# 删除指定行、列后数据形状:  (712, 20)
# 当前all_data的形状: (236933, 20)
# 处理进度: 199/591 (33.67%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1497, 9)
# 添加数据以后形状： (1497, 23)
# 添加label以后数据形状: (1497, 25)
# 删除指定行、列后数据形状:  (1394, 20)
# 当前all_data的形状: (238327, 20)
# 处理进度: 200/591 (33.84%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (997, 9)
# 添加数据以后形状： (997, 23)
# 添加label以后数据形状: (997, 25)
# 删除指定行、列后数据形状:  (894, 20)
# 当前all_data的形状: (239221, 20)
# 处理进度: 201/591 (34.01%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (119, 9)
# 股票代码 301261 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1681, 9)
# 添加数据以后形状： (1681, 23)
# 添加label以后数据形状: (1681, 25)
# 删除指定行、列后数据形状:  (1578, 20)
# 当前all_data的形状: (240799, 20)
# 处理进度: 203/591 (34.35%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (97, 9)
# 股票代码 301487 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1934, 9)
# 添加数据以后形状： (1934, 23)
# 添加label以后数据形状: (1934, 25)
# 删除指定行、列后数据形状:  (1831, 20)
# 当前all_data的形状: (242630, 20)
# 处理进度: 205/591 (34.69%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1955, 9)
# 添加数据以后形状： (1955, 23)
# 添加label以后数据形状: (1955, 25)
# 删除指定行、列后数据形状:  (1852, 20)
# 当前all_data的形状: (244482, 20)
# 处理进度: 206/591 (34.86%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (474, 9)
# 股票代码 301116 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1722, 9)
# 添加数据以后形状： (1722, 23)
# 添加label以后数据形状: (1722, 25)
# 删除指定行、列后数据形状:  (1619, 20)
# 当前all_data的形状: (246101, 20)
# 处理进度: 208/591 (35.19%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (213, 9)
# 股票代码 301303 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1870, 9)
# 添加数据以后形状： (1870, 23)
# 添加label以后数据形状: (1870, 25)
# 删除指定行、列后数据形状:  (1767, 20)
# 当前all_data的形状: (247868, 20)
# 处理进度: 210/591 (35.53%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (853, 9)
# 添加数据以后形状： (853, 23)
# 添加label以后数据形状: (853, 25)
# 删除指定行、列后数据形状:  (750, 20)
# 当前all_data的形状: (248618, 20)
# 处理进度: 211/591 (35.70%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1662, 9)
# 添加数据以后形状： (1662, 23)
# 添加label以后数据形状: (1662, 25)
# 删除指定行、列后数据形状:  (1559, 20)
# 当前all_data的形状: (250177, 20)
# 处理进度: 212/591 (35.87%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1567, 9)
# 添加数据以后形状： (1567, 23)
# 添加label以后数据形状: (1567, 25)
# 删除指定行、列后数据形状:  (1464, 20)
# 当前all_data的形状: (251641, 20)
# 处理进度: 213/591 (36.04%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1944, 9)
# 添加数据以后形状： (1944, 23)
# 添加label以后数据形状: (1944, 25)
# 删除指定行、列后数据形状:  (1841, 20)
# 当前all_data的形状: (253482, 20)
# 处理进度: 214/591 (36.21%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (746, 9)
# 添加数据以后形状： (746, 23)
# 添加label以后数据形状: (746, 25)
# 删除指定行、列后数据形状:  (643, 20)
# 当前all_data的形状: (254125, 20)
# 处理进度: 215/591 (36.38%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (130, 9)
# 股票代码 301315 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (377, 9)
# 股票代码 301238 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (571, 9)
# 添加数据以后形状： (571, 23)
# 添加label以后数据形状: (571, 25)
# 删除指定行、列后数据形状:  (468, 20)
# 当前all_data的形状: (254593, 20)
# 处理进度: 218/591 (36.89%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1959, 9)
# 添加数据以后形状： (1959, 23)
# 添加label以后数据形状: (1959, 25)
# 删除指定行、列后数据形状:  (1856, 20)
# 当前all_data的形状: (256449, 20)
# 处理进度: 219/591 (37.06%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1549, 9)
# 添加数据以后形状： (1549, 23)
# 添加label以后数据形状: (1549, 25)
# 删除指定行、列后数据形状:  (1446, 20)
# 当前all_data的形状: (257895, 20)
# 处理进度: 220/591 (37.23%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1963, 9)
# 添加数据以后形状： (1963, 23)
# 添加label以后数据形状: (1963, 25)
# 删除指定行、列后数据形状:  (1860, 20)
# 当前all_data的形状: (259755, 20)
# 处理进度: 221/591 (37.39%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1967, 9)
# 添加数据以后形状： (1967, 23)
# 添加label以后数据形状: (1967, 25)
# 删除指定行、列后数据形状:  (1864, 20)
# 当前all_data的形状: (261619, 20)
# 处理进度: 222/591 (37.56%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1538, 9)
# 添加数据以后形状： (1538, 23)
# 添加label以后数据形状: (1538, 25)
# 删除指定行、列后数据形状:  (1435, 20)
# 当前all_data的形状: (263054, 20)
# 处理进度: 223/591 (37.73%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1127, 9)
# 添加数据以后形状： (1127, 23)
# 添加label以后数据形状: (1127, 25)
# 删除指定行、列后数据形状:  (1024, 20)
# 当前all_data的形状: (264078, 20)
# 处理进度: 224/591 (37.90%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1791, 9)
# 添加数据以后形状： (1791, 23)
# 添加label以后数据形状: (1791, 25)
# 删除指定行、列后数据形状:  (1688, 20)
# 当前all_data的形状: (265766, 20)
# 处理进度: 225/591 (38.07%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1896, 9)
# 添加数据以后形状： (1896, 23)
# 添加label以后数据形状: (1896, 25)
# 删除指定行、列后数据形状:  (1793, 20)
# 当前all_data的形状: (267559, 20)
# 处理进度: 226/591 (38.24%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (345, 9)
# 股票代码 301333 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (343, 9)
# 股票代码 301278 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1123, 9)
# 添加数据以后形状： (1123, 23)
# 添加label以后数据形状: (1123, 25)
# 删除指定行、列后数据形状:  (1020, 20)
# 当前all_data的形状: (268579, 20)
# 处理进度: 229/591 (38.75%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1958, 9)
# 添加数据以后形状： (1958, 23)
# 添加label以后数据形状: (1958, 25)
# 删除指定行、列后数据形状:  (1855, 20)
# 当前all_data的形状: (270434, 20)
# 处理进度: 230/591 (38.92%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1512, 9)
# 添加数据以后形状： (1512, 23)
# 添加label以后数据形状: (1512, 25)
# 删除指定行、列后数据形状:  (1409, 20)
# 当前all_data的形状: (271843, 20)
# 处理进度: 231/591 (39.09%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (734, 9)
# 添加数据以后形状： (734, 23)
# 添加label以后数据形状: (734, 25)
# 删除指定行、列后数据形状:  (631, 20)
# 当前all_data的形状: (272474, 20)
# 处理进度: 232/591 (39.26%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1880, 9)
# 添加数据以后形状： (1880, 23)
# 添加label以后数据形状: (1880, 25)
# 删除指定行、列后数据形状:  (1777, 20)
# 当前all_data的形状: (274251, 20)
# 处理进度: 233/591 (39.42%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1967, 9)
# 添加数据以后形状： (1967, 23)
# 添加label以后数据形状: (1967, 25)
# 删除指定行、列后数据形状:  (1864, 20)
# 当前all_data的形状: (276115, 20)
# 处理进度: 234/591 (39.59%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (220, 9)
# 股票代码 301358 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (21, 9)
# 股票代码 301508 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1944, 9)
# 添加数据以后形状： (1944, 23)
# 添加label以后数据形状: (1944, 25)
# 删除指定行、列后数据形状:  (1841, 20)
# 当前all_data的形状: (277956, 20)
# 处理进度: 237/591 (40.10%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 23)
# 添加label以后数据形状: (1968, 25)
# 删除指定行、列后数据形状:  (1865, 20)
# 当前all_data的形状: (279821, 20)
# 处理进度: 238/591 (40.27%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (985, 9)
# 添加数据以后形状： (985, 23)
# 添加label以后数据形状: (985, 25)
# 删除指定行、列后数据形状:  (882, 20)
# 当前all_data的形状: (280703, 20)
# 处理进度: 239/591 (40.44%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (773, 9)
# 添加数据以后形状： (773, 23)
# 添加label以后数据形状: (773, 25)
# 删除指定行、列后数据形状:  (670, 20)
# 当前all_data的形状: (281373, 20)
# 处理进度: 240/591 (40.61%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1835, 9)
# 添加数据以后形状： (1835, 23)
# 添加label以后数据形状: (1835, 25)
# 删除指定行、列后数据形状:  (1732, 20)
# 当前all_data的形状: (283105, 20)
# 处理进度: 241/591 (40.78%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1755, 9)
# 添加数据以后形状： (1755, 23)
# 添加label以后数据形状: (1755, 25)
# 删除指定行、列后数据形状:  (1652, 20)
# 当前all_data的形状: (284757, 20)
# 处理进度: 242/591 (40.95%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1679, 9)
# 添加数据以后形状： (1679, 23)
# 添加label以后数据形状: (1679, 25)
# 删除指定行、列后数据形状:  (1576, 20)
# 当前all_data的形状: (286333, 20)
# 处理进度: 243/591 (41.12%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (163, 9)
# 股票代码 301293 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1853, 9)
# 添加数据以后形状： (1853, 23)
# 添加label以后数据形状: (1853, 25)
# 删除指定行、列后数据形状:  (1750, 20)
# 当前all_data的形状: (288083, 20)
# 处理进度: 245/591 (41.46%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (429, 9)
# 股票代码 301216 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 23)
# 添加label以后数据形状: (1968, 25)
# 删除指定行、列后数据形状:  (1865, 20)
# 当前all_data的形状: (289948, 20)
# 处理进度: 247/591 (41.79%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1946, 9)
# 添加数据以后形状： (1946, 23)
# 添加label以后数据形状: (1946, 25)
# 删除指定行、列后数据形状:  (1843, 20)
# 当前all_data的形状: (291791, 20)
# 处理进度: 248/591 (41.96%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1553, 9)
# 添加数据以后形状： (1553, 23)
# 添加label以后数据形状: (1553, 25)
# 删除指定行、列后数据形状:  (1450, 20)
# 当前all_data的形状: (293241, 20)
# 处理进度: 249/591 (42.13%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1578, 9)
# 添加数据以后形状： (1578, 23)
# 添加label以后数据形状: (1578, 25)
# 删除指定行、列后数据形状:  (1475, 20)
# 当前all_data的形状: (294716, 20)
# 处理进度: 250/591 (42.30%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1168, 9)
# 添加数据以后形状： (1168, 23)
# 添加label以后数据形状: (1168, 25)
# 删除指定行、列后数据形状:  (1065, 20)
# 当前all_data的形状: (295781, 20)
# 处理进度: 251/591 (42.47%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1965, 9)
# 添加数据以后形状： (1965, 23)
# 添加label以后数据形状: (1965, 25)
# 删除指定行、列后数据形状:  (1862, 20)
# 当前all_data的形状: (297643, 20)
# 处理进度: 252/591 (42.64%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1963, 9)
# 添加数据以后形状： (1963, 23)
# 添加label以后数据形状: (1963, 25)
# 删除指定行、列后数据形状:  (1860, 20)
# 当前all_data的形状: (299503, 20)
# 处理进度: 253/591 (42.81%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1962, 9)
# 添加数据以后形状： (1962, 23)
# 添加label以后数据形状: (1962, 25)
# 删除指定行、列后数据形状:  (1859, 20)
# 当前all_data的形状: (301362, 20)
# 处理进度: 254/591 (42.98%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1646, 9)
# 添加数据以后形状： (1646, 23)
# 添加label以后数据形状: (1646, 25)
# 删除指定行、列后数据形状:  (1543, 20)
# 当前all_data的形状: (302905, 20)
# 处理进度: 255/591 (43.15%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (815, 9)
# 添加数据以后形状： (815, 23)
# 添加label以后数据形状: (815, 25)
# 删除指定行、列后数据形状:  (712, 20)
# 当前all_data的形状: (303617, 20)
# 处理进度: 256/591 (43.32%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1869, 9)
# 添加数据以后形状： (1869, 23)
# 添加label以后数据形状: (1869, 25)
# 删除指定行、列后数据形状:  (1766, 20)
# 当前all_data的形状: (305383, 20)
# 处理进度: 257/591 (43.49%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1884, 9)
# 添加数据以后形状： (1884, 23)
# 添加label以后数据形状: (1884, 25)
# 删除指定行、列后数据形状:  (1781, 20)
# 当前all_data的形状: (307164, 20)
# 处理进度: 258/591 (43.65%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1143, 9)
# 添加数据以后形状： (1143, 23)
# 添加label以后数据形状: (1143, 25)
# 删除指定行、列后数据形状:  (1040, 20)
# 当前all_data的形状: (308204, 20)
# 处理进度: 259/591 (43.82%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (117, 9)
# 股票代码 301370 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (299, 9)
# 股票代码 301316 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1953, 9)
# 添加数据以后形状： (1953, 23)
# 添加label以后数据形状: (1953, 25)
# 删除指定行、列后数据形状:  (1850, 20)
# 当前all_data的形状: (310054, 20)
# 处理进度: 262/591 (44.33%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1486, 9)
# 添加数据以后形状： (1486, 23)
# 添加label以后数据形状: (1486, 25)
# 删除指定行、列后数据形状:  (1383, 20)
# 当前all_data的形状: (311437, 20)
# 处理进度: 263/591 (44.50%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (650, 9)
# 添加数据以后形状： (650, 23)
# 添加label以后数据形状: (650, 25)
# 删除指定行、列后数据形状:  (547, 20)
# 当前all_data的形状: (311984, 20)
# 处理进度: 264/591 (44.67%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 23)
# 添加label以后数据形状: (1968, 25)
# 删除指定行、列后数据形状:  (1865, 20)
# 当前all_data的形状: (313849, 20)
# 处理进度: 265/591 (44.84%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1309, 9)
# 添加数据以后形状： (1309, 23)
# 添加label以后数据形状: (1309, 25)
# 删除指定行、列后数据形状:  (1206, 20)
# 当前all_data的形状: (315055, 20)
# 处理进度: 266/591 (45.01%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1960, 9)
# 添加数据以后形状： (1960, 23)
# 添加label以后数据形状: (1960, 25)
# 删除指定行、列后数据形状:  (1857, 20)
# 当前all_data的形状: (316912, 20)
# 处理进度: 267/591 (45.18%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (653, 9)
# 添加数据以后形状： (653, 23)
# 添加label以后数据形状: (653, 25)
# 删除指定行、列后数据形状:  (550, 20)
# 当前all_data的形状: (317462, 20)
# 处理进度: 268/591 (45.35%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1458, 9)
# 添加数据以后形状： (1458, 23)
# 添加label以后数据形状: (1458, 25)
# 删除指定行、列后数据形状:  (1355, 20)
# 当前all_data的形状: (318817, 20)
# 处理进度: 269/591 (45.52%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (533, 9)
# 添加数据以后形状： (533, 23)
# 添加label以后数据形状: (533, 25)
# 删除指定行、列后数据形状:  (430, 20)
# 当前all_data的形状: (319247, 20)
# 处理进度: 270/591 (45.69%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1966, 9)
# 添加数据以后形状： (1966, 23)
# 添加label以后数据形状: (1966, 25)
# 删除指定行、列后数据形状:  (1863, 20)
# 当前all_data的形状: (321110, 20)
# 处理进度: 271/591 (45.85%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1850, 9)
# 添加数据以后形状： (1850, 23)
# 添加label以后数据形状: (1850, 25)
# 删除指定行、列后数据形状:  (1747, 20)
# 当前all_data的形状: (322857, 20)
# 处理进度: 272/591 (46.02%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (148, 9)
# 股票代码 301337 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1963, 9)
# 添加数据以后形状： (1963, 23)
# 添加label以后数据形状: (1963, 25)
# 删除指定行、列后数据形状:  (1860, 20)
# 当前all_data的形状: (324717, 20)
# 处理进度: 274/591 (46.36%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1945, 9)
# 添加数据以后形状： (1945, 23)
# 添加label以后数据形状: (1945, 25)
# 删除指定行、列后数据形状:  (1842, 20)
# 当前all_data的形状: (326559, 20)
# 处理进度: 275/591 (46.53%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1764, 9)
# 添加数据以后形状： (1764, 23)
# 添加label以后数据形状: (1764, 25)
# 删除指定行、列后数据形状:  (1661, 20)
# 当前all_data的形状: (328220, 20)
# 处理进度: 276/591 (46.70%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1862, 9)
# 添加数据以后形状： (1862, 23)
# 添加label以后数据形状: (1862, 25)
# 删除指定行、列后数据形状:  (1759, 20)
# 当前all_data的形状: (329979, 20)
# 处理进度: 277/591 (46.87%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1580, 9)
# 添加数据以后形状： (1580, 23)
# 添加label以后数据形状: (1580, 25)
# 删除指定行、列后数据形状:  (1477, 20)
# 当前all_data的形状: (331456, 20)
# 处理进度: 278/591 (47.04%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (557, 9)
# 添加数据以后形状： (557, 23)
# 添加label以后数据形状: (557, 25)
# 删除指定行、列后数据形状:  (454, 20)
# 当前all_data的形状: (331910, 20)
# 处理进度: 279/591 (47.21%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 23)
# 添加label以后数据形状: (1968, 25)
# 删除指定行、列后数据形状:  (1865, 20)
# 当前all_data的形状: (333775, 20)
# 处理进度: 280/591 (47.38%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1931, 9)
# 添加数据以后形状： (1931, 23)
# 添加label以后数据形状: (1931, 25)
# 删除指定行、列后数据形状:  (1828, 20)
# 当前all_data的形状: (335603, 20)
# 处理进度: 281/591 (47.55%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (850, 9)
# 添加数据以后形状： (850, 23)
# 添加label以后数据形状: (850, 25)
# 删除指定行、列后数据形状:  (747, 20)
# 当前all_data的形状: (336350, 20)
# 处理进度: 282/591 (47.72%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (815, 9)
# 添加数据以后形状： (815, 23)
# 添加label以后数据形状: (815, 25)
# 删除指定行、列后数据形状:  (712, 20)
# 当前all_data的形状: (337062, 20)
# 处理进度: 283/591 (47.88%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1947, 9)
# 添加数据以后形状： (1947, 23)
# 添加label以后数据形状: (1947, 25)
# 删除指定行、列后数据形状:  (1844, 20)
# 当前all_data的形状: (338906, 20)
# 处理进度: 284/591 (48.05%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1741, 9)
# 添加数据以后形状： (1741, 23)
# 添加label以后数据形状: (1741, 25)
# 删除指定行、列后数据形状:  (1638, 20)
# 当前all_data的形状: (340544, 20)
# 处理进度: 285/591 (48.22%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1920, 9)
# 添加数据以后形状： (1920, 23)
# 添加label以后数据形状: (1920, 25)
# 删除指定行、列后数据形状:  (1817, 20)
# 当前all_data的形状: (342361, 20)
# 处理进度: 286/591 (48.39%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1746, 9)
# 添加数据以后形状： (1746, 23)
# 添加label以后数据形状: (1746, 25)
# 删除指定行、列后数据形状:  (1643, 20)
# 当前all_data的形状: (344004, 20)
# 处理进度: 287/591 (48.56%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1949, 9)
# 添加数据以后形状： (1949, 23)
# 添加label以后数据形状: (1949, 25)
# 删除指定行、列后数据形状:  (1846, 20)
# 当前all_data的形状: (345850, 20)
# 处理进度: 288/591 (48.73%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (594, 9)
# 添加数据以后形状： (594, 23)
# 添加label以后数据形状: (594, 25)
# 删除指定行、列后数据形状:  (491, 20)
# 当前all_data的形状: (346341, 20)
# 处理进度: 289/591 (48.90%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1960, 9)
# 添加数据以后形状： (1960, 23)
# 添加label以后数据形状: (1960, 25)
# 删除指定行、列后数据形状:  (1857, 20)
# 当前all_data的形状: (348198, 20)
# 处理进度: 290/591 (49.07%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (410, 9)
# 股票代码 301109 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1539, 9)
# 添加数据以后形状： (1539, 23)
# 添加label以后数据形状: (1539, 25)
# 删除指定行、列后数据形状:  (1436, 20)
# 当前all_data的形状: (349634, 20)
# 处理进度: 292/591 (49.41%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1667, 9)
# 添加数据以后形状： (1667, 23)
# 添加label以后数据形状: (1667, 25)
# 删除指定行、列后数据形状:  (1564, 20)
# 当前all_data的形状: (351198, 20)
# 处理进度: 293/591 (49.58%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1817, 9)
# 添加数据以后形状： (1817, 23)
# 添加label以后数据形状: (1817, 25)
# 删除指定行、列后数据形状:  (1714, 20)
# 当前all_data的形状: (352912, 20)
# 处理进度: 294/591 (49.75%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1444, 9)
# 添加数据以后形状： (1444, 23)
# 添加label以后数据形状: (1444, 25)
# 删除指定行、列后数据形状:  (1341, 20)
# 当前all_data的形状: (354253, 20)
# 处理进度: 295/591 (49.92%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (77, 9)
# 股票代码 301251 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1901, 9)
# 添加数据以后形状： (1901, 23)
# 添加label以后数据形状: (1901, 25)
# 删除指定行、列后数据形状:  (1798, 20)
# 当前all_data的形状: (356051, 20)
# 处理进度: 297/591 (50.25%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1510, 9)
# 添加数据以后形状： (1510, 23)
# 添加label以后数据形状: (1510, 25)
# 删除指定行、列后数据形状:  (1407, 20)
# 当前all_data的形状: (357458, 20)
# 处理进度: 298/591 (50.42%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1948, 9)
# 添加数据以后形状： (1948, 23)
# 添加label以后数据形状: (1948, 25)
# 删除指定行、列后数据形状:  (1845, 20)
# 当前all_data的形状: (359303, 20)
# 处理进度: 299/591 (50.59%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 23)
# 添加label以后数据形状: (1968, 25)
# 删除指定行、列后数据形状:  (1865, 20)
# 当前all_data的形状: (361168, 20)
# 处理进度: 300/591 (50.76%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (282, 9)
# 股票代码 301267 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1963, 9)
# 添加数据以后形状： (1963, 23)
# 添加label以后数据形状: (1963, 25)
# 删除指定行、列后数据形状:  (1860, 20)
# 当前all_data的形状: (363028, 20)
# 处理进度: 302/591 (51.10%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1684, 9)
# 添加数据以后形状： (1684, 23)
# 添加label以后数据形状: (1684, 25)
# 删除指定行、列后数据形状:  (1581, 20)
# 当前all_data的形状: (364609, 20)
# 处理进度: 303/591 (51.27%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1478, 9)
# 添加数据以后形状： (1478, 23)
# 添加label以后数据形状: (1478, 25)
# 删除指定行、列后数据形状:  (1375, 20)
# 当前all_data的形状: (365984, 20)
# 处理进度: 304/591 (51.44%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (835, 9)
# 添加数据以后形状： (835, 23)
# 添加label以后数据形状: (835, 25)
# 删除指定行、列后数据形状:  (732, 20)
# 当前all_data的形状: (366716, 20)
# 处理进度: 305/591 (51.61%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1958, 9)
# 添加数据以后形状： (1958, 23)
# 添加label以后数据形状: (1958, 25)
# 删除指定行、列后数据形状:  (1855, 20)
# 当前all_data的形状: (368571, 20)
# 处理进度: 306/591 (51.78%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1546, 9)
# 添加数据以后形状： (1546, 23)
# 添加label以后数据形状: (1546, 25)
# 删除指定行、列后数据形状:  (1443, 20)
# 当前all_data的形状: (370014, 20)
# 处理进度: 307/591 (51.95%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1878, 9)
# 添加数据以后形状： (1878, 23)
# 添加label以后数据形状: (1878, 25)
# 删除指定行、列后数据形状:  (1775, 20)
# 当前all_data的形状: (371789, 20)
# 处理进度: 308/591 (52.12%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (847, 9)
# 添加数据以后形状： (847, 23)
# 添加label以后数据形状: (847, 25)
# 删除指定行、列后数据形状:  (744, 20)
# 当前all_data的形状: (372533, 20)
# 处理进度: 309/591 (52.28%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1964, 9)
# 添加数据以后形状： (1964, 23)
# 添加label以后数据形状: (1964, 25)
# 删除指定行、列后数据形状:  (1861, 20)
# 当前all_data的形状: (374394, 20)
# ...
# 处理进度: 483/591 (81.73%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1922, 9)
# 添加数据以后形状： (1922, 23)
# 添加label以后数据形状: (1922, 25)
# 删除指定行、列后数据形状:  (1819, 20)
# 当前all_data的形状: (593989, 20)
# 处理进度: 484/591 (81.90%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1599, 9)
# 添加数据以后形状： (1599, 23)
# 添加label以后数据形状: (1599, 25)
# 删除指定行、列后数据形状:  (1496, 20)
# 当前all_data的形状: (595485, 20)
# 处理进度: 485/591 (82.06%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1950, 9)
# 添加数据以后形状： (1950, 23)
# 添加label以后数据形状: (1950, 25)
# 删除指定行、列后数据形状:  (1847, 20)
# 当前all_data的形状: (597332, 20)
# 处理进度: 486/591 (82.23%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1958, 9)
# 添加数据以后形状： (1958, 23)
# 添加label以后数据形状: (1958, 25)
# 删除指定行、列后数据形状:  (1855, 20)
# 当前all_data的形状: (599187, 20)
# 处理进度: 487/591 (82.40%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (492, 9)
# 股票代码 301221 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1865, 9)
# 添加数据以后形状： (1865, 23)
# 添加label以后数据形状: (1865, 25)
# 删除指定行、列后数据形状:  (1762, 20)
# 当前all_data的形状: (600949, 20)
# 处理进度: 489/591 (82.74%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1430, 9)
# 添加数据以后形状： (1430, 23)
# 添加label以后数据形状: (1430, 25)
# 删除指定行、列后数据形状:  (1327, 20)
# 当前all_data的形状: (602276, 20)
# 处理进度: 490/591 (82.91%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (607, 9)
# 添加数据以后形状： (607, 23)
# 添加label以后数据形状: (607, 25)
# 删除指定行、列后数据形状:  (504, 20)
# 当前all_data的形状: (602780, 20)
# 处理进度: 491/591 (83.08%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1890, 9)
# 添加数据以后形状： (1890, 23)
# 添加label以后数据形状: (1890, 25)
# 删除指定行、列后数据形状:  (1787, 20)
# 当前all_data的形状: (604567, 20)
# 处理进度: 492/591 (83.25%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (346, 9)
# 股票代码 301195 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1250, 9)
# 添加数据以后形状： (1250, 23)
# 添加label以后数据形状: (1250, 25)
# 删除指定行、列后数据形状:  (1147, 20)
# 当前all_data的形状: (605714, 20)
# 处理进度: 494/591 (83.59%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1538, 9)
# 添加数据以后形状： (1538, 23)
# 添加label以后数据形状: (1538, 25)
# 删除指定行、列后数据形状:  (1435, 20)
# 当前all_data的形状: (607149, 20)
# 处理进度: 495/591 (83.76%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1820, 9)
# 添加数据以后形状： (1820, 23)
# 添加label以后数据形状: (1820, 25)
# 删除指定行、列后数据形状:  (1717, 20)
# 当前all_data的形状: (608866, 20)
# 处理进度: 496/591 (83.93%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1944, 9)
# 添加数据以后形状： (1944, 23)
# 添加label以后数据形状: (1944, 25)
# 删除指定行、列后数据形状:  (1841, 20)
# 当前all_data的形状: (610707, 20)
# 处理进度: 497/591 (84.09%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1940, 9)
# 添加数据以后形状： (1940, 23)
# 添加label以后数据形状: (1940, 25)
# 删除指定行、列后数据形状:  (1837, 20)
# 当前all_data的形状: (612544, 20)
# 处理进度: 498/591 (84.26%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1460, 9)
# 添加数据以后形状： (1460, 23)
# 添加label以后数据形状: (1460, 25)
# 删除指定行、列后数据形状:  (1357, 20)
# 当前all_data的形状: (613901, 20)
# 处理进度: 499/591 (84.43%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1132, 9)
# 添加数据以后形状： (1132, 23)
# 添加label以后数据形状: (1132, 25)
# 删除指定行、列后数据形状:  (1029, 20)
# 当前all_data的形状: (614930, 20)
# 处理进度: 500/591 (84.60%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 23)
# 添加label以后数据形状: (1968, 25)
# 删除指定行、列后数据形状:  (1865, 20)
# 当前all_data的形状: (616795, 20)
# 处理进度: 501/591 (84.77%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (590, 9)
# 添加数据以后形状： (590, 23)
# 添加label以后数据形状: (590, 25)
# 删除指定行、列后数据形状:  (487, 20)
# 当前all_data的形状: (617282, 20)
# 处理进度: 502/591 (84.94%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1853, 9)
# 添加数据以后形状： (1853, 23)
# 添加label以后数据形状: (1853, 25)
# 删除指定行、列后数据形状:  (1750, 20)
# 当前all_data的形状: (619032, 20)
# 处理进度: 503/591 (85.11%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (568, 9)
# 添加数据以后形状： (568, 23)
# 添加label以后数据形状: (568, 25)
# 删除指定行、列后数据形状:  (465, 20)
# 当前all_data的形状: (619497, 20)
# 处理进度: 504/591 (85.28%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1821, 9)
# 添加数据以后形状： (1821, 23)
# 添加label以后数据形状: (1821, 25)
# 删除指定行、列后数据形状:  (1718, 20)
# 当前all_data的形状: (621215, 20)
# 处理进度: 505/591 (85.45%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (802, 9)
# 添加数据以后形状： (802, 23)
# 添加label以后数据形状: (802, 25)
# 删除指定行、列后数据形状:  (699, 20)
# 当前all_data的形状: (621914, 20)
# 处理进度: 506/591 (85.62%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1899, 9)
# 添加数据以后形状： (1899, 23)
# 添加label以后数据形状: (1899, 25)
# 删除指定行、列后数据形状:  (1796, 20)
# 当前all_data的形状: (623710, 20)
# 处理进度: 507/591 (85.79%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1962, 9)
# 添加数据以后形状： (1962, 23)
# 添加label以后数据形状: (1962, 25)
# 删除指定行、列后数据形状:  (1859, 20)
# 当前all_data的形状: (625569, 20)
# 处理进度: 508/591 (85.96%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1019, 9)
# 添加数据以后形状： (1019, 23)
# 添加label以后数据形状: (1019, 25)
# 删除指定行、列后数据形状:  (916, 20)
# 当前all_data的形状: (626485, 20)
# 处理进度: 509/591 (86.13%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (206, 9)
# 股票代码 301408 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 23)
# 添加label以后数据形状: (1968, 25)
# 删除指定行、列后数据形状:  (1865, 20)
# 当前all_data的形状: (628350, 20)
# 处理进度: 511/591 (86.46%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1963, 9)
# 添加数据以后形状： (1963, 23)
# 添加label以后数据形状: (1963, 25)
# 删除指定行、列后数据形状:  (1860, 20)
# 当前all_data的形状: (630210, 20)
# 处理进度: 512/591 (86.63%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1939, 9)
# 添加数据以后形状： (1939, 23)
# 添加label以后数据形状: (1939, 25)
# 删除指定行、列后数据形状:  (1836, 20)
# 当前all_data的形状: (632046, 20)
# 处理进度: 513/591 (86.80%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (559, 9)
# 添加数据以后形状： (559, 23)
# 添加label以后数据形状: (559, 25)
# 删除指定行、列后数据形状:  (456, 20)
# 当前all_data的形状: (632502, 20)
# 处理进度: 514/591 (86.97%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 23)
# 添加label以后数据形状: (1968, 25)
# 删除指定行、列后数据形状:  (1865, 20)
# 当前all_data的形状: (634367, 20)
# 处理进度: 515/591 (87.14%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1861, 9)
# 添加数据以后形状： (1861, 23)
# 添加label以后数据形状: (1861, 25)
# 删除指定行、列后数据形状:  (1758, 20)
# 当前all_data的形状: (636125, 20)
# 处理进度: 516/591 (87.31%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (365, 9)
# 股票代码 301239 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1279, 9)
# 添加数据以后形状： (1279, 23)
# 添加label以后数据形状: (1279, 25)
# 删除指定行、列后数据形状:  (1176, 20)
# 当前all_data的形状: (637301, 20)
# 处理进度: 518/591 (87.65%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1779, 9)
# 添加数据以后形状： (1779, 23)
# 添加label以后数据形状: (1779, 25)
# 删除指定行、列后数据形状:  (1676, 20)
# 当前all_data的形状: (638977, 20)
# 处理进度: 519/591 (87.82%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (439, 9)
# 股票代码 301236 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1889, 9)
# 添加数据以后形状： (1889, 23)
# 添加label以后数据形状: (1889, 25)
# 删除指定行、列后数据形状:  (1786, 20)
# 当前all_data的形状: (640763, 20)
# 处理进度: 521/591 (88.16%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (539, 9)
# 添加数据以后形状： (539, 23)
# 添加label以后数据形状: (539, 25)
# 删除指定行、列后数据形状:  (436, 20)
# 当前all_data的形状: (641199, 20)
# 处理进度: 522/591 (88.32%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1914, 9)
# 添加数据以后形状： (1914, 23)
# 添加label以后数据形状: (1914, 25)
# 删除指定行、列后数据形状:  (1811, 20)
# 当前all_data的形状: (643010, 20)
# 处理进度: 523/591 (88.49%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1958, 9)
# 添加数据以后形状： (1958, 23)
# 添加label以后数据形状: (1958, 25)
# 删除指定行、列后数据形状:  (1855, 20)
# 当前all_data的形状: (644865, 20)
# 处理进度: 524/591 (88.66%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (430, 9)
# 股票代码 301102 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1959, 9)
# 添加数据以后形状： (1959, 23)
# 添加label以后数据形状: (1959, 25)
# 删除指定行、列后数据形状:  (1856, 20)
# 当前all_data的形状: (646721, 20)
# 处理进度: 526/591 (89.00%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1509, 9)
# 添加数据以后形状： (1509, 23)
# 添加label以后数据形状: (1509, 25)
# 删除指定行、列后数据形状:  (1406, 20)
# 当前all_data的形状: (648127, 20)
# 处理进度: 527/591 (89.17%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1161, 9)
# 添加数据以后形状： (1161, 23)
# 添加label以后数据形状: (1161, 25)
# 删除指定行、列后数据形状:  (1058, 20)
# 当前all_data的形状: (649185, 20)
# 处理进度: 528/591 (89.34%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1964, 9)
# 添加数据以后形状： (1964, 23)
# 添加label以后数据形状: (1964, 25)
# 删除指定行、列后数据形状:  (1861, 20)
# 当前all_data的形状: (651046, 20)
# 处理进度: 529/591 (89.51%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1126, 9)
# 添加数据以后形状： (1126, 23)
# 添加label以后数据形状: (1126, 25)
# 删除指定行、列后数据形状:  (1023, 20)
# 当前all_data的形状: (652069, 20)
# 处理进度: 530/591 (89.68%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (221, 9)
# 股票代码 301260 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (54, 9)
# 股票代码 301517 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1755, 9)
# 添加数据以后形状： (1755, 23)
# 添加label以后数据形状: (1755, 25)
# 删除指定行、列后数据形状:  (1652, 20)
# 当前all_data的形状: (653721, 20)
# 处理进度: 533/591 (90.19%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1797, 9)
# 添加数据以后形状： (1797, 23)
# 添加label以后数据形状: (1797, 25)
# 删除指定行、列后数据形状:  (1694, 20)
# 当前all_data的形状: (655415, 20)
# 处理进度: 534/591 (90.36%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (797, 9)
# 添加数据以后形状： (797, 23)
# 添加label以后数据形状: (797, 25)
# 删除指定行、列后数据形状:  (694, 20)
# 当前all_data的形状: (656109, 20)
# 处理进度: 535/591 (90.52%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (599, 9)
# 添加数据以后形状： (599, 23)
# 添加label以后数据形状: (599, 25)
# 删除指定行、列后数据形状:  (496, 20)
# 当前all_data的形状: (656605, 20)
# 处理进度: 536/591 (90.69%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1764, 9)
# 添加数据以后形状： (1764, 23)
# 添加label以后数据形状: (1764, 25)
# 删除指定行、列后数据形状:  (1661, 20)
# 当前all_data的形状: (658266, 20)
# 处理进度: 537/591 (90.86%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1889, 9)
# 添加数据以后形状： (1889, 23)
# 添加label以后数据形状: (1889, 25)
# 删除指定行、列后数据形状:  (1786, 20)
# 当前all_data的形状: (660052, 20)
# 处理进度: 538/591 (91.03%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (955, 9)
# 添加数据以后形状： (955, 23)
# 添加label以后数据形状: (955, 25)
# 删除指定行、列后数据形状:  (852, 20)
# 当前all_data的形状: (660904, 20)
# 处理进度: 539/591 (91.20%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 23)
# 添加label以后数据形状: (1968, 25)
# 删除指定行、列后数据形状:  (1865, 20)
# 当前all_data的形状: (662769, 20)
# 处理进度: 540/591 (91.37%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 23)
# 添加label以后数据形状: (1968, 25)
# 删除指定行、列后数据形状:  (1865, 20)
# 当前all_data的形状: (664634, 20)
# 处理进度: 541/591 (91.54%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (424, 9)
# 股票代码 301268 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1948, 9)
# 添加数据以后形状： (1948, 23)
# 添加label以后数据形状: (1948, 25)
# 删除指定行、列后数据形状:  (1845, 20)
# 当前all_data的形状: (666479, 20)
# 处理进度: 543/591 (91.88%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1967, 9)
# 添加数据以后形状： (1967, 23)
# 添加label以后数据形状: (1967, 25)
# 删除指定行、列后数据形状:  (1864, 20)
# 当前all_data的形状: (668343, 20)
# 处理进度: 544/591 (92.05%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (750, 9)
# 添加数据以后形状： (750, 23)
# 添加label以后数据形状: (750, 25)
# 删除指定行、列后数据形状:  (647, 20)
# 当前all_data的形状: (668990, 20)
# 处理进度: 545/591 (92.22%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1841, 9)
# 添加数据以后形状： (1841, 23)
# 添加label以后数据形状: (1841, 25)
# 删除指定行、列后数据形状:  (1738, 20)
# 当前all_data的形状: (670728, 20)
# 处理进度: 546/591 (92.39%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (342, 9)
# 股票代码 301308 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1949, 9)
# 添加数据以后形状： (1949, 23)
# 添加label以后数据形状: (1949, 25)
# 删除指定行、列后数据形状:  (1846, 20)
# 当前all_data的形状: (672574, 20)
# 处理进度: 548/591 (92.72%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1947, 9)
# 添加数据以后形状： (1947, 23)
# 添加label以后数据形状: (1947, 25)
# 删除指定行、列后数据形状:  (1844, 20)
# 当前all_data的形状: (674418, 20)
# 处理进度: 549/591 (92.89%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (115, 9)
# 股票代码 301456 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (815, 9)
# 添加数据以后形状： (815, 23)
# 添加label以后数据形状: (815, 25)
# 删除指定行、列后数据形状:  (712, 20)
# 当前all_data的形状: (675130, 20)
# 处理进度: 551/591 (93.23%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1087, 9)
# 添加数据以后形状： (1087, 23)
# 添加label以后数据形状: (1087, 25)
# 删除指定行、列后数据形状:  (984, 20)
# 当前all_data的形状: (676114, 20)
# 处理进度: 552/591 (93.40%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (497, 9)
# 股票代码 301177 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1948, 9)
# 添加数据以后形状： (1948, 23)
# 添加label以后数据形状: (1948, 25)
# 删除指定行、列后数据形状:  (1845, 20)
# 当前all_data的形状: (677959, 20)
# 处理进度: 554/591 (93.74%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (887, 9)
# 添加数据以后形状： (887, 23)
# 添加label以后数据形状: (887, 25)
# 删除指定行、列后数据形状:  (784, 20)
# 当前all_data的形状: (678743, 20)
# 处理进度: 555/591 (93.91%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1498, 9)
# 添加数据以后形状： (1498, 23)
# 添加label以后数据形状: (1498, 25)
# 删除指定行、列后数据形状:  (1395, 20)
# 当前all_data的形状: (680138, 20)
# 处理进度: 556/591 (94.08%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (58, 9)
# 股票代码 301559 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (4, 9)
# 股票代码 301526 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1856, 9)
# 添加数据以后形状： (1856, 23)
# 添加label以后数据形状: (1856, 25)
# 删除指定行、列后数据形状:  (1753, 20)
# 当前all_data的形状: (681891, 20)
# 处理进度: 559/591 (94.59%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (16, 9)
# 股票代码 301516 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (87, 9)
# 股票代码 301421 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1928, 9)
# 添加数据以后形状： (1928, 23)
# 添加label以后数据形状: (1928, 25)
# 删除指定行、列后数据形状:  (1825, 20)
# 当前all_data的形状: (683716, 20)
# 处理进度: 562/591 (95.09%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (577, 9)
# 添加数据以后形状： (577, 23)
# 添加label以后数据形状: (577, 25)
# 删除指定行、列后数据形状:  (474, 20)
# 当前all_data的形状: (684190, 20)
# 处理进度: 563/591 (95.26%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (579, 9)
# 添加数据以后形状： (579, 23)
# 添加label以后数据形状: (579, 25)
# 删除指定行、列后数据形状:  (476, 20)
# 当前all_data的形状: (684666, 20)
# 处理进度: 564/591 (95.43%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (155, 9)
# 股票代码 301382 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1605, 9)
# 添加数据以后形状： (1605, 23)
# 添加label以后数据形状: (1605, 25)
# 删除指定行、列后数据形状:  (1502, 20)
# 当前all_data的形状: (686168, 20)
# 处理进度: 566/591 (95.77%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1958, 9)
# 添加数据以后形状： (1958, 23)
# 添加label以后数据形状: (1958, 25)
# 删除指定行、列后数据形状:  (1855, 20)
# 当前all_data的形状: (688023, 20)
# 处理进度: 567/591 (95.94%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (265, 9)
# 股票代码 301311 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1945, 9)
# 添加数据以后形状： (1945, 23)
# 添加label以后数据形状: (1945, 25)
# 删除指定行、列后数据形状:  (1842, 20)
# 当前all_data的形状: (689865, 20)
# 处理进度: 569/591 (96.28%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (300, 9)
# 股票代码 301363 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1864, 9)
# 添加数据以后形状： (1864, 23)
# 添加label以后数据形状: (1864, 25)
# 删除指定行、列后数据形状:  (1761, 20)
# 当前all_data的形状: (691626, 20)
# 处理进度: 571/591 (96.62%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1420, 9)
# 添加数据以后形状： (1420, 23)
# 添加label以后数据形状: (1420, 25)
# 删除指定行、列后数据形状:  (1317, 20)
# 当前all_data的形状: (692943, 20)
# 处理进度: 572/591 (96.79%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1939, 9)
# 添加数据以后形状： (1939, 23)
# 添加label以后数据形状: (1939, 25)
# 删除指定行、列后数据形状:  (1836, 20)
# 当前all_data的形状: (694779, 20)
# 处理进度: 573/591 (96.95%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1602, 9)
# 添加数据以后形状： (1602, 23)
# 添加label以后数据形状: (1602, 25)
# 删除指定行、列后数据形状:  (1499, 20)
# 当前all_data的形状: (696278, 20)
# 处理进度: 574/591 (97.12%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (138, 9)
# 股票代码 301383 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1593, 9)
# 添加数据以后形状： (1593, 23)
# 添加label以后数据形状: (1593, 25)
# 删除指定行、列后数据形状:  (1490, 20)
# 当前all_data的形状: (697768, 20)
# 处理进度: 576/591 (97.46%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (815, 9)
# 添加数据以后形状： (815, 23)
# 添加label以后数据形状: (815, 25)
# 删除指定行、列后数据形状:  (712, 20)
# 当前all_data的形状: (698480, 20)
# 处理进度: 577/591 (97.63%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1959, 9)
# 添加数据以后形状： (1959, 23)
# 添加label以后数据形状: (1959, 25)
# 删除指定行、列后数据形状:  (1856, 20)
# 当前all_data的形状: (700336, 20)
# 处理进度: 578/591 (97.80%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1683, 9)
# 添加数据以后形状： (1683, 23)
# 添加label以后数据形状: (1683, 25)
# 删除指定行、列后数据形状:  (1580, 20)
# 当前all_data的形状: (701916, 20)
# 处理进度: 579/591 (97.97%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (61, 9)
# 股票代码 301558 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1819, 9)
# 添加数据以后形状： (1819, 23)
# 添加label以后数据形状: (1819, 25)
# 删除指定行、列后数据形状:  (1716, 20)
# 当前all_data的形状: (703632, 20)
# 处理进度: 581/591 (98.31%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (125, 9)
# 股票代码 301291 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (663, 9)
# 添加数据以后形状： (663, 23)
# 添加label以后数据形状: (663, 25)
# 删除指定行、列后数据形状:  (560, 20)
# 当前all_data的形状: (704192, 20)
# 处理进度: 583/591 (98.65%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (752, 9)
# 添加数据以后形状： (752, 23)
# 添加label以后数据形状: (752, 25)
# 删除指定行、列后数据形状:  (649, 20)
# 当前all_data的形状: (704841, 20)
# 处理进度: 584/591 (98.82%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (286, 9)
# 股票代码 301367 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (539, 9)
# 添加数据以后形状： (539, 23)
# 添加label以后数据形状: (539, 25)
# 删除指定行、列后数据形状:  (436, 20)
# 当前all_data的形状: (705277, 20)
# 处理进度: 586/591 (99.15%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (380, 9)
# 股票代码 301286 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (862, 9)
# 添加数据以后形状： (862, 23)
# 添加label以后数据形状: (862, 25)
# 删除指定行、列后数据形状:  (759, 20)
# 当前all_data的形状: (706036, 20)
# 处理进度: 588/591 (99.49%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1954, 9)
# 添加数据以后形状： (1954, 23)
# 添加label以后数据形状: (1954, 25)
# 删除指定行、列后数据形状:  (1851, 20)
# 当前all_data的形状: (707887, 20)
# 处理进度: 589/591 (99.66%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1958, 9)
# 添加数据以后形状： (1958, 23)
# 添加label以后数据形状: (1958, 25)
# 删除指定行、列后数据形状:  (1855, 20)
# 当前all_data的形状: (709742, 20)
# 处理进度: 590/591 (99.83%)
# 合并数据保存完毕。
