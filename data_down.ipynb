# %%
# from google.colab import drive # 挂载谷歌云盘
# drive.mount('/content/drive')
# !nvidia-smi # 显示显卡信息
# ''' 符号%代表一直生效，！代表执行完立马结束，不会生效，所以进入目录用% '''
# %cd /content/drive/MyDrive/timeSerise
# ''' 支持的 常用命令1.ls  2.wget  3.gdoint(int(int(int(w))))n  4.mkdir  5.pwd '''
# !ls
# !pip install pyti
# !pip install akshare

# %%
from data_provider.data_creat import *
import akshare as ak
from datetime import datetime
import random

# %%
class Args:
    '''股票数据获取'''
    fuquan = 'hfq'# 设置复权方式,adjust=空选择的不复权，qfq是前复权，应该用hfq后复权来进行量化分析
    period = 'daily' # 拉取时间周期{'daily', 'weekly', 'monthly'}
    start_date = '20151201'  # 20151201   20221021  下载数据的开始日期,1就是公司上市时间
    end_date = '20231230'  # '20231220' 下载数据的结束日期,如果1则到最后一天,如果-1是昨天.
    label_n = 5 # 预测未来连续多少天的收益率
    root_path = './dataset/Stock/'
    
    # 预测目标y是否替换成1或者0
    label_ch = False  # 如果是True ，预测n天以后上涨大于变量zhangfu为1，小于为0
    zhangfu = 0.10  # 预测涨幅大于等于3%的为1，小于3%的为0

    # 是否合并全部股票数据
    all = True # 是否合并全部股票数据
    data_addzero = 21 # 当all = True时，用于训练的数据集分割，前面补0的长度 应该是seq_len + pred_len 长度
    
    # 数据修剪
    start = 103 # 删除前24行（start=25），因为macd算不出来
    end = 0 # (end = label_n if all else 0)删除最后部分需要预测天数label_n的数据，算出来是0.如果单只股票预测，那么不需要删除
    # final_data_feat =  ['index', 'Volume','Tom_Chg'] # 删除不需要列的标签
    final_data_feat =  ['index', 'Volume','Tom_Chg','Open','Low','High'] # 删除不需要列的标签
    down_scaler = False # 是否对下载数据进行归一化

# 创建参数对象
args = Args()

# 创建股票数据列表
stock_down = ak.stock_cy_a_spot_em() # 创业板实时数据
stock_list = stock_down[~stock_down['名称'].str.contains("退|ST") & (stock_down['流通市值'] <= 1e11) & (stock_down['总市值'] >= 45e8)] # 去除退市和ST股票
file_name_cy = 'Stock_list_cy.csv'# 保存数据，编码格式为utf-8
stock_list.to_csv(args.root_path + file_name_cy,index=False,encoding='utf-8-sig')

# 读取股票列表
stock_list = pd.read_csv(args.root_path + file_name_cy) # 读取股票列表
# 将股票代码的数字转换为字符串列表
stock_list = [str(code) for code in stock_list['代码'].tolist()]
# 对列表随机排序
random.shuffle(stock_list)

# stock_list = ['000158','300798'] # 自定义股票列表

# %%
from sklearn.preprocessing import StandardScaler

all_data_raw = pd.DataFrame()  # 初始化一个空的 DataFrame 用于存储原始数据
all_data_scaled = pd.DataFrame()  # 初始化一个空的 DataFrame 用于存储标准化后的数据
processed_count = 0  # 初始化计数器
total_count = len(stock_list)  # 获取总股票数量
scaler = StandardScaler()

for i in stock_list[:]:
    NUM = i
    try:
        # 下载原始数据
        raw_data = download_data(NUM, args)
        # 更新已处理股票数量计数器
        processed_count += 1
        # 检查数据长度，如果小于300则跳过此次循环
        if raw_data.shape[0] < 500:
            print(f"股票代码 {NUM} 的数据长度小于300,跳过此次循环。")
            continue
        
        # 拼接数据，添加各种参数
        ad_data = add_data(raw_data, args)
        # 添加预测标签
        # ad_data = add_label(ad_data, args)
        # 删除无效数据
        final_data_raw = sub_data(ad_data.copy(), args)
        final_data_scaled = final_data_raw.copy()
        
        # 未处理数据的前20行替换为0
        if args.data_addzero and not all_data_raw.empty:
            final_data_raw = add_zeros_to_data(final_data_raw, num_rows=args.data_addzero)

        # 标准化处理
        if args.down_scaler:
            non_time_columns = final_data_scaled.columns[1:-1]  # 假设时间列是第一列
            final_data_scaled[non_time_columns] = scaler.fit_transform(final_data_scaled[non_time_columns])
            # 标准化处理的数据的前20行替换为0
            if args.data_addzero and not all_data_scaled.empty:
                final_data_scaled = add_zeros_to_data(final_data_scaled, num_rows=args.data_addzero)
        
        # 如果 all 为 False, 则为每个股票单独保存数据
        if not args.all:
            file_name_raw_individual = f"raw_stock_cy_{NUM}.csv"
            final_data_raw.to_csv(args.root_path + file_name_raw_individual, index=False)

            if args.down_scaler:
                file_name_scaled_individual = f"scaled_stock_cy_{NUM}.csv"
                final_data_scaled.to_csv(args.root_path + file_name_scaled_individual, index=False)
                print(f"股票代码 {NUM} 的数据保存到 {file_name_raw_individual} ，形状: {final_data_raw.shape}")
        else:
            # 拼接未处理的数据
            all_data_raw = pd.concat([all_data_raw, final_data_raw], ignore_index=True)
            if args.down_scaler:
                # 拼接经过标准化的数据
                all_data_scaled = pd.concat([all_data_scaled, final_data_scaled], ignore_index=True)
            print(f"当前all_data的形状: {all_data_raw.shape}")

    except Exception as e:
        print(f"处理股票代码 {NUM} 时出现错误: {e}")
        continue

    # 计算并打印处理进度
    progress = processed_count / total_count
    print(f"处理进度: {processed_count}/{total_count} ({progress:.2%})")

# 如果 all 为 True, 则保存合并后的数据
if args.all:
    time = datetime.now().strftime("%Y_%m_%d_%H_%M_%S")
    file_name_raw = "stock_cy_all_raw.csv"
    all_data_raw.to_csv(args.root_path + time + file_name_raw, index=False)
    if args.down_scaler:
        file_name_scaled = "stock_cy_all_scaled.csv"
        all_data_scaled.to_csv(args.root_path + time + file_name_scaled, index=False)
    print("合并数据保存完毕。")
else:
    print("单独数据保存完毕。")
# Out:
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (853, 9)
# 添加数据以后形状： (853, 21)
# 删除指定行、列后数据形状:  (750, 17)
# 当前all_data的形状: (750, 17)
# 处理进度: 1/591 (0.17%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 21)
# 删除指定行、列后数据形状:  (1865, 17)
# 当前all_data的形状: (2615, 17)
# 处理进度: 2/591 (0.34%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1797, 9)
# 添加数据以后形状： (1797, 21)
# 删除指定行、列后数据形状:  (1694, 17)
# 当前all_data的形状: (4309, 17)
# 处理进度: 3/591 (0.51%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1959, 9)
# 添加数据以后形状： (1959, 21)
# 删除指定行、列后数据形状:  (1856, 17)
# 当前all_data的形状: (6165, 17)
# 处理进度: 4/591 (0.68%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1105, 9)
# 添加数据以后形状： (1105, 21)
# 删除指定行、列后数据形状:  (1002, 17)
# 当前all_data的形状: (7167, 17)
# 处理进度: 5/591 (0.85%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (380, 9)
# 股票代码 301286 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (456, 9)
# 股票代码 301207 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (299, 9)
# 股票代码 301316 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1, 9)
# 股票代码 301566 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1856, 9)
# 添加数据以后形状： (1856, 21)
# 删除指定行、列后数据形状:  (1753, 17)
# 当前all_data的形状: (8920, 17)
# 处理进度: 10/591 (1.69%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1959, 9)
# 添加数据以后形状： (1959, 21)
# 删除指定行、列后数据形状:  (1856, 17)
# 当前all_data的形状: (10776, 17)
# 处理进度: 11/591 (1.86%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1608, 9)
# 添加数据以后形状： (1608, 21)
# 删除指定行、列后数据形状:  (1505, 17)
# 当前all_data的形状: (12281, 17)
# 处理进度: 12/591 (2.03%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1746, 9)
# 添加数据以后形状： (1746, 21)
# 删除指定行、列后数据形状:  (1643, 17)
# 当前all_data的形状: (13924, 17)
# 处理进度: 13/591 (2.20%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1148, 9)
# 添加数据以后形状： (1148, 21)
# 删除指定行、列后数据形状:  (1045, 17)
# 当前all_data的形状: (14969, 17)
# 处理进度: 14/591 (2.37%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1890, 9)
# 添加数据以后形状： (1890, 21)
# 删除指定行、列后数据形状:  (1787, 17)
# 当前all_data的形状: (16756, 17)
# 处理进度: 15/591 (2.54%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 21)
# 删除指定行、列后数据形状:  (1865, 17)
# 当前all_data的形状: (18621, 17)
# 处理进度: 16/591 (2.71%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1566, 9)
# 添加数据以后形状： (1566, 21)
# 删除指定行、列后数据形状:  (1463, 17)
# 当前all_data的形状: (20084, 17)
# 处理进度: 17/591 (2.88%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1846, 9)
# 添加数据以后形状： (1846, 21)
# 删除指定行、列后数据形状:  (1743, 17)
# 当前all_data的形状: (21827, 17)
# 处理进度: 18/591 (3.05%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1147, 9)
# 添加数据以后形状： (1147, 21)
# 删除指定行、列后数据形状:  (1044, 17)
# 当前all_data的形状: (22871, 17)
# 处理进度: 19/591 (3.21%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (117, 9)
# 股票代码 301370 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1865, 9)
# 添加数据以后形状： (1865, 21)
# 删除指定行、列后数据形状:  (1762, 17)
# 当前all_data的形状: (24633, 17)
# 处理进度: 21/591 (3.55%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1033, 9)
# 添加数据以后形状： (1033, 21)
# 删除指定行、列后数据形状:  (930, 17)
# 当前all_data的形状: (25563, 17)
# 处理进度: 22/591 (3.72%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1023, 9)
# 添加数据以后形状： (1023, 21)
# 删除指定行、列后数据形状:  (920, 17)
# 当前all_data的形状: (26483, 17)
# 处理进度: 23/591 (3.89%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1743, 9)
# 添加数据以后形状： (1743, 21)
# 删除指定行、列后数据形状:  (1640, 17)
# 当前all_data的形状: (28123, 17)
# 处理进度: 24/591 (4.06%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 21)
# 删除指定行、列后数据形状:  (1865, 17)
# 当前all_data的形状: (29988, 17)
# 处理进度: 25/591 (4.23%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 21)
# 删除指定行、列后数据形状:  (1865, 17)
# 当前all_data的形状: (31853, 17)
# 处理进度: 26/591 (4.40%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1489, 9)
# 添加数据以后形状： (1489, 21)
# 删除指定行、列后数据形状:  (1386, 17)
# 当前all_data的形状: (33239, 17)
# 处理进度: 27/591 (4.57%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1567, 9)
# 添加数据以后形状： (1567, 21)
# 删除指定行、列后数据形状:  (1464, 17)
# 当前all_data的形状: (34703, 17)
# 处理进度: 28/591 (4.74%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1942, 9)
# 添加数据以后形状： (1942, 21)
# 删除指定行、列后数据形状:  (1839, 17)
# 当前all_data的形状: (36542, 17)
# 处理进度: 29/591 (4.91%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1435, 9)
# 添加数据以后形状： (1435, 21)
# 删除指定行、列后数据形状:  (1332, 17)
# 当前all_data的形状: (37874, 17)
# 处理进度: 30/591 (5.08%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (840, 9)
# 添加数据以后形状： (840, 21)
# 删除指定行、列后数据形状:  (737, 17)
# 当前all_data的形状: (38611, 17)
# 处理进度: 31/591 (5.25%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (502, 9)
# 添加数据以后形状： (502, 21)
# 删除指定行、列后数据形状:  (399, 17)
# 当前all_data的形状: (39010, 17)
# 处理进度: 32/591 (5.41%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (728, 9)
# 添加数据以后形状： (728, 21)
# 删除指定行、列后数据形状:  (625, 17)
# 当前all_data的形状: (39635, 17)
# 处理进度: 33/591 (5.58%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1905, 9)
# 添加数据以后形状： (1905, 21)
# 删除指定行、列后数据形状:  (1802, 17)
# 当前all_data的形状: (41437, 17)
# 处理进度: 34/591 (5.75%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (783, 9)
# 添加数据以后形状： (783, 21)
# 删除指定行、列后数据形状:  (680, 17)
# 当前all_data的形状: (42117, 17)
# 处理进度: 35/591 (5.92%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (590, 9)
# 添加数据以后形状： (590, 21)
# 删除指定行、列后数据形状:  (487, 17)
# 当前all_data的形状: (42604, 17)
# 处理进度: 36/591 (6.09%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1944, 9)
# 添加数据以后形状： (1944, 21)
# 删除指定行、列后数据形状:  (1841, 17)
# 当前all_data的形状: (44445, 17)
# 处理进度: 37/591 (6.26%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (282, 9)
# 股票代码 301267 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1710, 9)
# 添加数据以后形状： (1710, 21)
# 删除指定行、列后数据形状:  (1607, 17)
# 当前all_data的形状: (46052, 17)
# 处理进度: 39/591 (6.60%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1950, 9)
# 添加数据以后形状： (1950, 21)
# 删除指定行、列后数据形状:  (1847, 17)
# 当前all_data的形状: (47899, 17)
# 处理进度: 40/591 (6.77%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1124, 9)
# 添加数据以后形状： (1124, 21)
# 删除指定行、列后数据形状:  (1021, 17)
# 当前all_data的形状: (48920, 17)
# 处理进度: 41/591 (6.94%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1660, 9)
# 添加数据以后形状： (1660, 21)
# 删除指定行、列后数据形状:  (1557, 17)
# 当前all_data的形状: (50477, 17)
# 处理进度: 42/591 (7.11%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1087, 9)
# 添加数据以后形状： (1087, 21)
# 删除指定行、列后数据形状:  (984, 17)
# 当前all_data的形状: (51461, 17)
# 处理进度: 43/591 (7.28%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (220, 9)
# 股票代码 301358 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (254, 9)
# 股票代码 301368 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1614, 9)
# 添加数据以后形状： (1614, 21)
# 删除指定行、列后数据形状:  (1511, 17)
# 当前all_data的形状: (52972, 17)
# 处理进度: 46/591 (7.78%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1905, 9)
# 添加数据以后形状： (1905, 21)
# 删除指定行、列后数据形状:  (1802, 17)
# 当前all_data的形状: (54774, 17)
# 处理进度: 47/591 (7.95%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1844, 9)
# 添加数据以后形状： (1844, 21)
# 删除指定行、列后数据形状:  (1741, 17)
# 当前all_data的形状: (56515, 17)
# 处理进度: 48/591 (8.12%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1907, 9)
# 添加数据以后形状： (1907, 21)
# 删除指定行、列后数据形状:  (1804, 17)
# 当前all_data的形状: (58319, 17)
# 处理进度: 49/591 (8.29%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1944, 9)
# 添加数据以后形状： (1944, 21)
# 删除指定行、列后数据形状:  (1841, 17)
# 当前all_data的形状: (60160, 17)
# 处理进度: 50/591 (8.46%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 21)
# 删除指定行、列后数据形状:  (1865, 17)
# 当前all_data的形状: (62025, 17)
# 处理进度: 51/591 (8.63%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (658, 9)
# 添加数据以后形状： (658, 21)
# 删除指定行、列后数据形状:  (555, 17)
# 当前all_data的形状: (62580, 17)
# 处理进度: 52/591 (8.80%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1889, 9)
# 添加数据以后形状： (1889, 21)
# 删除指定行、列后数据形状:  (1786, 17)
# 当前all_data的形状: (64366, 17)
# 处理进度: 53/591 (8.97%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1498, 9)
# 添加数据以后形状： (1498, 21)
# 删除指定行、列后数据形状:  (1395, 17)
# 当前all_data的形状: (65761, 17)
# 处理进度: 54/591 (9.14%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1891, 9)
# 添加数据以后形状： (1891, 21)
# 删除指定行、列后数据形状:  (1788, 17)
# 当前all_data的形状: (67549, 17)
# 处理进度: 55/591 (9.31%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1864, 9)
# 添加数据以后形状： (1864, 21)
# 删除指定行、列后数据形状:  (1761, 17)
# 当前all_data的形状: (69310, 17)
# 处理进度: 56/591 (9.48%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (342, 9)
# 股票代码 301308 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (650, 9)
# 添加数据以后形状： (650, 21)
# 删除指定行、列后数据形状:  (547, 17)
# 当前all_data的形状: (69857, 17)
# 处理进度: 58/591 (9.81%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1899, 9)
# 添加数据以后形状： (1899, 21)
# 删除指定行、列后数据形状:  (1796, 17)
# 当前all_data的形状: (71653, 17)
# 处理进度: 59/591 (9.98%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1967, 9)
# 添加数据以后形状： (1967, 21)
# 删除指定行、列后数据形状:  (1864, 17)
# 当前all_data的形状: (73517, 17)
# 处理进度: 60/591 (10.15%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1764, 9)
# 添加数据以后形状： (1764, 21)
# 删除指定行、列后数据形状:  (1661, 17)
# 当前all_data的形状: (75178, 17)
# 处理进度: 61/591 (10.32%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1882, 9)
# 添加数据以后形状： (1882, 21)
# 删除指定行、列后数据形状:  (1779, 17)
# 当前all_data的形状: (76957, 17)
# 处理进度: 62/591 (10.49%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (173, 9)
# 股票代码 301387 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (16, 9)
# 股票代码 301516 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1966, 9)
# 添加数据以后形状： (1966, 21)
# 删除指定行、列后数据形状:  (1863, 17)
# 当前all_data的形状: (78820, 17)
# 处理进度: 65/591 (11.00%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1691, 9)
# 添加数据以后形状： (1691, 21)
# 删除指定行、列后数据形状:  (1588, 17)
# 当前all_data的形状: (80408, 17)
# 处理进度: 66/591 (11.17%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1964, 9)
# 添加数据以后形状： (1964, 21)
# 删除指定行、列后数据形状:  (1861, 17)
# 当前all_data的形状: (82269, 17)
# 处理进度: 67/591 (11.34%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (972, 9)
# 添加数据以后形状： (972, 21)
# 删除指定行、列后数据形状:  (869, 17)
# 当前all_data的形状: (83138, 17)
# 处理进度: 68/591 (11.51%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1958, 9)
# 添加数据以后形状： (1958, 21)
# 删除指定行、列后数据形状:  (1855, 17)
# 当前all_data的形状: (84993, 17)
# 处理进度: 69/591 (11.68%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1430, 9)
# 添加数据以后形状： (1430, 21)
# 删除指定行、列后数据形状:  (1327, 17)
# 当前all_data的形状: (86320, 17)
# 处理进度: 70/591 (11.84%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1868, 9)
# 添加数据以后形状： (1868, 21)
# 删除指定行、列后数据形状:  (1765, 17)
# 当前all_data的形状: (88085, 17)
# 处理进度: 71/591 (12.01%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (746, 9)
# 添加数据以后形状： (746, 21)
# 删除指定行、列后数据形状:  (643, 17)
# 当前all_data的形状: (88728, 17)
# 处理进度: 72/591 (12.18%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (120, 9)
# 股票代码 301486 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (607, 9)
# 添加数据以后形状： (607, 21)
# 删除指定行、列后数据形状:  (504, 17)
# 当前all_data的形状: (89232, 17)
# 处理进度: 74/591 (12.52%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (143, 9)
# 股票代码 301310 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1878, 9)
# 添加数据以后形状： (1878, 21)
# 删除指定行、列后数据形状:  (1775, 17)
# 当前all_data的形状: (91007, 17)
# 处理进度: 76/591 (12.86%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (835, 9)
# 添加数据以后形状： (835, 21)
# 删除指定行、列后数据形状:  (732, 17)
# 当前all_data的形状: (91739, 17)
# 处理进度: 77/591 (13.03%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (610, 9)
# 添加数据以后形状： (610, 21)
# 删除指定行、列后数据形状:  (507, 17)
# 当前all_data的形状: (92246, 17)
# 处理进度: 78/591 (13.20%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 21)
# 删除指定行、列后数据形状:  (1865, 17)
# 当前all_data的形状: (94111, 17)
# 处理进度: 79/591 (13.37%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1458, 9)
# 添加数据以后形状： (1458, 21)
# 删除指定行、列后数据形状:  (1355, 17)
# 当前all_data的形状: (95466, 17)
# 处理进度: 80/591 (13.54%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (429, 9)
# 股票代码 301263 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1967, 9)
# 添加数据以后形状： (1967, 21)
# 删除指定行、列后数据形状:  (1864, 17)
# 当前all_data的形状: (97330, 17)
# 处理进度: 82/591 (13.87%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1964, 9)
# 添加数据以后形状： (1964, 21)
# 删除指定行、列后数据形状:  (1861, 17)
# 当前all_data的形状: (99191, 17)
# 处理进度: 83/591 (14.04%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (334, 9)
# 股票代码 301330 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1963, 9)
# 添加数据以后形状： (1963, 21)
# 删除指定行、列后数据形状:  (1860, 17)
# 当前all_data的形状: (101051, 17)
# 处理进度: 85/591 (14.38%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (985, 9)
# 添加数据以后形状： (985, 21)
# 删除指定行、列后数据形状:  (882, 17)
# 当前all_data的形状: (101933, 17)
# 处理进度: 86/591 (14.55%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1819, 9)
# 添加数据以后形状： (1819, 21)
# 删除指定行、列后数据形状:  (1716, 17)
# 当前all_data的形状: (103649, 17)
# 处理进度: 87/591 (14.72%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (539, 9)
# 添加数据以后形状： (539, 21)
# 删除指定行、列后数据形状:  (436, 17)
# 当前all_data的形状: (104085, 17)
# 处理进度: 88/591 (14.89%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (605, 9)
# 添加数据以后形状： (605, 21)
# 删除指定行、列后数据形状:  (502, 17)
# 当前all_data的形状: (104587, 17)
# 处理进度: 89/591 (15.06%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1637, 9)
# 添加数据以后形状： (1637, 21)
# 删除指定行、列后数据形状:  (1534, 17)
# 当前all_data的形状: (106121, 17)
# 处理进度: 90/591 (15.23%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1165, 9)
# 添加数据以后形状： (1165, 21)
# 删除指定行、列后数据形状:  (1062, 17)
# 当前all_data的形状: (107183, 17)
# 处理进度: 91/591 (15.40%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (494, 9)
# 股票代码 301096 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (21, 9)
# 股票代码 301508 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1958, 9)
# 添加数据以后形状： (1958, 21)
# 删除指定行、列后数据形状:  (1855, 17)
# 当前all_data的形状: (109038, 17)
# 处理进度: 94/591 (15.91%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1870, 9)
# 添加数据以后形状： (1870, 21)
# 删除指定行、列后数据形状:  (1767, 17)
# 当前all_data的形状: (110805, 17)
# 处理进度: 95/591 (16.07%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1812, 9)
# 添加数据以后形状： (1812, 21)
# 删除指定行、列后数据形状:  (1709, 17)
# 当前all_data的形状: (112514, 17)
# 处理进度: 96/591 (16.24%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1862, 9)
# 添加数据以后形状： (1862, 21)
# 删除指定行、列后数据形状:  (1759, 17)
# 当前all_data的形状: (114273, 17)
# 处理进度: 97/591 (16.41%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1874, 9)
# 添加数据以后形状： (1874, 21)
# 删除指定行、列后数据形状:  (1771, 17)
# 当前all_data的形状: (116044, 17)
# 处理进度: 98/591 (16.58%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (424, 9)
# 股票代码 301268 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1954, 9)
# 添加数据以后形状： (1954, 21)
# 删除指定行、列后数据形状:  (1851, 17)
# 当前all_data的形状: (117895, 17)
# 处理进度: 100/591 (16.92%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (798, 9)
# 添加数据以后形状： (798, 21)
# 删除指定行、列后数据形状:  (695, 17)
# 当前all_data的形状: (118590, 17)
# 处理进度: 101/591 (17.09%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (300, 9)
# 股票代码 301363 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1729, 9)
# 添加数据以后形状： (1729, 21)
# 删除指定行、列后数据形状:  (1626, 17)
# 当前all_data的形状: (120216, 17)
# 处理进度: 103/591 (17.43%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1741, 9)
# 添加数据以后形状： (1741, 21)
# 删除指定行、列后数据形状:  (1638, 17)
# 当前all_data的形状: (121854, 17)
# 处理进度: 104/591 (17.60%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1745, 9)
# 添加数据以后形状： (1745, 21)
# 删除指定行、列后数据形状:  (1642, 17)
# 当前all_data的形状: (123496, 17)
# 处理进度: 105/591 (17.77%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1937, 9)
# 添加数据以后形状： (1937, 21)
# 删除指定行、列后数据形状:  (1834, 17)
# 当前all_data的形状: (125330, 17)
# 处理进度: 106/591 (17.94%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1684, 9)
# 添加数据以后形状： (1684, 21)
# 删除指定行、列后数据形状:  (1581, 17)
# 当前all_data的形状: (126911, 17)
# 处理进度: 107/591 (18.10%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (365, 9)
# 股票代码 301239 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1900, 9)
# 添加数据以后形状： (1900, 21)
# 删除指定行、列后数据形状:  (1797, 17)
# 当前all_data的形状: (128708, 17)
# 处理进度: 109/591 (18.44%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1186, 9)
# 添加数据以后形状： (1186, 21)
# 删除指定行、列后数据形状:  (1083, 17)
# 当前all_data的形状: (129791, 17)
# 处理进度: 110/591 (18.61%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1881, 9)
# 添加数据以后形状： (1881, 21)
# 删除指定行、列后数据形状:  (1778, 17)
# 当前all_data的形状: (131569, 17)
# 处理进度: 111/591 (18.78%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (194, 9)
# 股票代码 301439 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1509, 9)
# 添加数据以后形状： (1509, 21)
# 删除指定行、列后数据形状:  (1406, 17)
# 当前all_data的形状: (132975, 17)
# 处理进度: 113/591 (19.12%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1939, 9)
# 添加数据以后形状： (1939, 21)
# 删除指定行、列后数据形状:  (1836, 17)
# 当前all_data的形状: (134811, 17)
# 处理进度: 114/591 (19.29%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1965, 9)
# 添加数据以后形状： (1965, 21)
# 删除指定行、列后数据形状:  (1862, 17)
# 当前all_data的形状: (136673, 17)
# 处理进度: 115/591 (19.46%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1963, 9)
# 添加数据以后形状： (1963, 21)
# 删除指定行、列后数据形状:  (1860, 17)
# 当前all_data的形状: (138533, 17)
# 处理进度: 116/591 (19.63%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1947, 9)
# 添加数据以后形状： (1947, 21)
# 删除指定行、列后数据形状:  (1844, 17)
# 当前all_data的形状: (140377, 17)
# 处理进度: 117/591 (19.80%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1809, 9)
# 添加数据以后形状： (1809, 21)
# 删除指定行、列后数据形状:  (1706, 17)
# 当前all_data的形状: (142083, 17)
# 处理进度: 118/591 (19.97%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (398, 9)
# 股票代码 301153 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (243, 9)
# 股票代码 301297 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1894, 9)
# 添加数据以后形状： (1894, 21)
# 删除指定行、列后数据形状:  (1791, 17)
# 当前all_data的形状: (143874, 17)
# 处理进度: 121/591 (20.47%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1961, 9)
# 添加数据以后形状： (1961, 21)
# 删除指定行、列后数据形状:  (1858, 17)
# 当前all_data的形状: (145732, 17)
# 处理进度: 122/591 (20.64%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1841, 9)
# 添加数据以后形状： (1841, 21)
# 删除指定行、列后数据形状:  (1738, 17)
# 当前all_data的形状: (147470, 17)
# 处理进度: 123/591 (20.81%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1910, 9)
# 添加数据以后形状： (1910, 21)
# 删除指定行、列后数据形状:  (1807, 17)
# 当前all_data的形状: (149277, 17)
# 处理进度: 124/591 (20.98%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (500, 9)
# 添加数据以后形状： (500, 21)
# 删除指定行、列后数据形状:  (397, 17)
# 当前all_data的形状: (149674, 17)
# 处理进度: 125/591 (21.15%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1958, 9)
# 添加数据以后形状： (1958, 21)
# 删除指定行、列后数据形状:  (1855, 17)
# 当前all_data的形状: (151529, 17)
# 处理进度: 126/591 (21.32%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 21)
# 删除指定行、列后数据形状:  (1865, 17)
# 当前all_data的形状: (153394, 17)
# 处理进度: 127/591 (21.49%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (287, 9)
# 股票代码 301389 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1602, 9)
# 添加数据以后形状： (1602, 21)
# 删除指定行、列后数据形状:  (1499, 17)
# 当前all_data的形状: (154893, 17)
# 处理进度: 129/591 (21.83%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (462, 9)
# 股票代码 301206 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1488, 9)
# 添加数据以后形状： (1488, 21)
# 删除指定行、列后数据形状:  (1385, 17)
# 当前all_data的形状: (156278, 17)
# 处理进度: 131/591 (22.17%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1830, 9)
# 添加数据以后形状： (1830, 21)
# 删除指定行、列后数据形状:  (1727, 17)
# 当前all_data的形状: (158005, 17)
# 处理进度: 132/591 (22.34%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1880, 9)
# 添加数据以后形状： (1880, 21)
# 删除指定行、列后数据形状:  (1777, 17)
# 当前all_data的形状: (159782, 17)
# 处理进度: 133/591 (22.50%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1931, 9)
# 添加数据以后形状： (1931, 21)
# 删除指定行、列后数据形状:  (1828, 17)
# 当前all_data的形状: (161610, 17)
# 处理进度: 134/591 (22.67%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1195, 9)
# 添加数据以后形状： (1195, 21)
# 删除指定行、列后数据形状:  (1092, 17)
# 当前all_data的形状: (162702, 17)
# 处理进度: 135/591 (22.84%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (450, 9)
# 股票代码 301200 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1755, 9)
# 添加数据以后形状： (1755, 21)
# 删除指定行、列后数据形状:  (1652, 17)
# 当前all_data的形状: (164354, 17)
# 处理进度: 137/591 (23.18%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1935, 9)
# 添加数据以后形状： (1935, 21)
# 删除指定行、列后数据形状:  (1832, 17)
# 当前all_data的形状: (166186, 17)
# 处理进度: 138/591 (23.35%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1963, 9)
# 添加数据以后形状： (1963, 21)
# 删除指定行、列后数据形状:  (1860, 17)
# 当前all_data的形状: (168046, 17)
# 处理进度: 139/591 (23.52%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 21)
# 删除指定行、列后数据形状:  (1865, 17)
# 当前all_data的形状: (169911, 17)
# 处理进度: 140/591 (23.69%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (734, 9)
# 添加数据以后形状： (734, 21)
# 删除指定行、列后数据形状:  (631, 17)
# 当前all_data的形状: (170542, 17)
# 处理进度: 141/591 (23.86%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1889, 9)
# 添加数据以后形状： (1889, 21)
# 删除指定行、列后数据形状:  (1786, 17)
# 当前all_data的形状: (172328, 17)
# 处理进度: 142/591 (24.03%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1961, 9)
# 添加数据以后形状： (1961, 21)
# 删除指定行、列后数据形状:  (1858, 17)
# 当前all_data的形状: (174186, 17)
# 处理进度: 143/591 (24.20%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 21)
# 删除指定行、列后数据形状:  (1865, 17)
# 当前all_data的形状: (176051, 17)
# 处理进度: 144/591 (24.37%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1893, 9)
# 添加数据以后形状： (1893, 21)
# 删除指定行、列后数据形状:  (1790, 17)
# 当前all_data的形状: (177841, 17)
# 处理进度: 145/591 (24.53%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1841, 9)
# 添加数据以后形状： (1841, 21)
# 删除指定行、列后数据形状:  (1738, 17)
# 当前all_data的形状: (179579, 17)
# 处理进度: 146/591 (24.70%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1898, 9)
# 添加数据以后形状： (1898, 21)
# 删除指定行、列后数据形状:  (1795, 17)
# 当前all_data的形状: (181374, 17)
# 处理进度: 147/591 (24.87%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1901, 9)
# 添加数据以后形状： (1901, 21)
# 删除指定行、列后数据形状:  (1798, 17)
# 当前all_data的形状: (183172, 17)
# 处理进度: 148/591 (25.04%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (169, 9)
# 股票代码 301307 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (965, 9)
# 添加数据以后形状： (965, 21)
# 删除指定行、列后数据形状:  (862, 17)
# 当前all_data的形状: (184034, 17)
# 处理进度: 150/591 (25.38%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1958, 9)
# 添加数据以后形状： (1958, 21)
# 删除指定行、列后数据形状:  (1855, 17)
# 当前all_data的形状: (185889, 17)
# 处理进度: 151/591 (25.55%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (362, 9)
# 股票代码 301175 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1967, 9)
# 添加数据以后形状： (1967, 21)
# 删除指定行、列后数据形状:  (1864, 17)
# 当前all_data的形状: (187753, 17)
# 处理进度: 153/591 (25.89%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1960, 9)
# 添加数据以后形状： (1960, 21)
# 删除指定行、列后数据形状:  (1857, 17)
# 当前all_data的形状: (189610, 17)
# 处理进度: 154/591 (26.06%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1568, 9)
# 添加数据以后形状： (1568, 21)
# 删除指定行、列后数据形状:  (1465, 17)
# 当前all_data的形状: (191075, 17)
# 处理进度: 155/591 (26.23%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 21)
# 删除指定行、列后数据形状:  (1865, 17)
# 当前all_data的形状: (192940, 17)
# 处理进度: 156/591 (26.40%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1330, 9)
# 添加数据以后形状： (1330, 21)
# 删除指定行、列后数据形状:  (1227, 17)
# 当前all_data的形状: (194167, 17)
# 处理进度: 157/591 (26.57%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1958, 9)
# 添加数据以后形状： (1958, 21)
# 删除指定行、列后数据形状:  (1855, 17)
# 当前all_data的形状: (196022, 17)
# 处理进度: 158/591 (26.73%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1896, 9)
# 添加数据以后形状： (1896, 21)
# 删除指定行、列后数据形状:  (1793, 17)
# 当前all_data的形状: (197815, 17)
# 处理进度: 159/591 (26.90%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (559, 9)
# 添加数据以后形状： (559, 21)
# 删除指定行、列后数据形状:  (456, 17)
# 当前all_data的形状: (198271, 17)
# 处理进度: 160/591 (27.07%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1939, 9)
# 添加数据以后形状： (1939, 21)
# 删除指定行、列后数据形状:  (1836, 17)
# 当前all_data的形状: (200107, 17)
# 处理进度: 161/591 (27.24%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1599, 9)
# 添加数据以后形状： (1599, 21)
# 删除指定行、列后数据形状:  (1496, 17)
# 当前all_data的形状: (201603, 17)
# 处理进度: 162/591 (27.41%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1906, 9)
# 添加数据以后形状： (1906, 21)
# 删除指定行、列后数据形状:  (1803, 17)
# 当前all_data的形状: (203406, 17)
# 处理进度: 163/591 (27.58%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1960, 9)
# 添加数据以后形状： (1960, 21)
# 删除指定行、列后数据形状:  (1857, 17)
# 当前all_data的形状: (205263, 17)
# 处理进度: 164/591 (27.75%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (577, 9)
# 添加数据以后形状： (577, 21)
# 删除指定行、列后数据形状:  (474, 17)
# 当前all_data的形状: (205737, 17)
# 处理进度: 165/591 (27.92%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (117, 9)
# 股票代码 301381 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1958, 9)
# 添加数据以后形状： (1958, 21)
# 删除指定行、列后数据形状:  (1855, 17)
# 当前all_data的形状: (207592, 17)
# 处理进度: 167/591 (28.26%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (246, 9)
# 股票代码 301301 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (345, 9)
# 股票代码 301333 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (568, 9)
# 添加数据以后形状： (568, 21)
# 删除指定行、列后数据形状:  (465, 17)
# 当前all_data的形状: (208057, 17)
# 处理进度: 170/591 (28.76%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (437, 9)
# 股票代码 301219 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (998, 9)
# 添加数据以后形状： (998, 21)
# 删除指定行、列后数据形状:  (895, 17)
# 当前all_data的形状: (208952, 17)
# 处理进度: 172/591 (29.10%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (91, 9)
# 股票代码 301511 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (541, 9)
# 添加数据以后形状： (541, 21)
# 删除指定行、列后数据形状:  (438, 17)
# 当前all_data的形状: (209390, 17)
# 处理进度: 174/591 (29.44%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (158, 9)
# 股票代码 301325 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1914, 9)
# 添加数据以后形状： (1914, 21)
# 删除指定行、列后数据形状:  (1811, 17)
# 当前all_data的形状: (211201, 17)
# 处理进度: 176/591 (29.78%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1789, 9)
# 添加数据以后形状： (1789, 21)
# 删除指定行、列后数据形状:  (1686, 17)
# 当前all_data的形状: (212887, 17)
# 处理进度: 177/591 (29.95%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 21)
# 删除指定行、列后数据形状:  (1865, 17)
# 当前all_data的形状: (214752, 17)
# 处理进度: 178/591 (30.12%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1948, 9)
# 添加数据以后形状： (1948, 21)
# 删除指定行、列后数据形状:  (1845, 17)
# 当前all_data的形状: (216597, 17)
# 处理进度: 179/591 (30.29%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (392, 9)
# 股票代码 301191 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1960, 9)
# 添加数据以后形状： (1960, 21)
# 删除指定行、列后数据形状:  (1857, 17)
# 当前all_data的形状: (218454, 17)
# 处理进度: 181/591 (30.63%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1956, 9)
# 添加数据以后形状： (1956, 21)
# 删除指定行、列后数据形状:  (1853, 17)
# 当前all_data的形状: (220307, 17)
# 处理进度: 182/591 (30.80%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (123, 9)
# 股票代码 301488 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (434, 9)
# 股票代码 301103 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1798, 9)
# 添加数据以后形状： (1798, 21)
# 删除指定行、列后数据形状:  (1695, 17)
# 当前all_data的形状: (222002, 17)
# 处理进度: 185/591 (31.30%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1460, 9)
# 添加数据以后形状： (1460, 21)
# 删除指定行、列后数据形状:  (1357, 17)
# 当前all_data的形状: (223359, 17)
# 处理进度: 186/591 (31.47%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 21)
# 删除指定行、列后数据形状:  (1865, 17)
# 当前all_data的形状: (225224, 17)
# 处理进度: 187/591 (31.64%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1939, 9)
# 添加数据以后形状： (1939, 21)
# 删除指定行、列后数据形状:  (1836, 17)
# 当前all_data的形状: (227060, 17)
# 处理进度: 188/591 (31.81%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1954, 9)
# 添加数据以后形状： (1954, 21)
# 删除指定行、列后数据形状:  (1851, 17)
# 当前all_data的形状: (228911, 17)
# 处理进度: 189/591 (31.98%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1543, 9)
# 添加数据以后形状： (1543, 21)
# 删除指定行、列后数据形状:  (1440, 17)
# 当前all_data的形状: (230351, 17)
# 处理进度: 190/591 (32.15%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1953, 9)
# 添加数据以后形状： (1953, 21)
# 删除指定行、列后数据形状:  (1850, 17)
# 当前all_data的形状: (232201, 17)
# 处理进度: 191/591 (32.32%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1961, 9)
# 添加数据以后形状： (1961, 21)
# 删除指定行、列后数据形状:  (1858, 17)
# 当前all_data的形状: (234059, 17)
# 处理进度: 192/591 (32.49%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (815, 9)
# 添加数据以后形状： (815, 21)
# 删除指定行、列后数据形状:  (712, 17)
# 当前all_data的形状: (234771, 17)
# 处理进度: 193/591 (32.66%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1523, 9)
# 添加数据以后形状： (1523, 21)
# 删除指定行、列后数据形状:  (1420, 17)
# 当前all_data的形状: (236191, 17)
# 处理进度: 194/591 (32.83%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (117, 9)
# 股票代码 301393 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 21)
# 删除指定行、列后数据形状:  (1865, 17)
# 当前all_data的形状: (238056, 17)
# 处理进度: 196/591 (33.16%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1810, 9)
# 添加数据以后形状： (1810, 21)
# 删除指定行、列后数据形状:  (1707, 17)
# 当前all_data的形状: (239763, 17)
# 处理进度: 197/591 (33.33%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (815, 9)
# 添加数据以后形状： (815, 21)
# 删除指定行、列后数据形状:  (712, 17)
# 当前all_data的形状: (240475, 17)
# 处理进度: 198/591 (33.50%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (272, 9)
# 股票代码 301165 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1773, 9)
# 添加数据以后形状： (1773, 21)
# 删除指定行、列后数据形状:  (1670, 17)
# 当前all_data的形状: (242145, 17)
# 处理进度: 200/591 (33.84%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (881, 9)
# 添加数据以后形状： (881, 21)
# 删除指定行、列后数据形状:  (778, 17)
# 当前all_data的形状: (242923, 17)
# 处理进度: 201/591 (34.01%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (660, 9)
# 添加数据以后形状： (660, 21)
# 删除指定行、列后数据形状:  (557, 17)
# 当前all_data的形状: (243480, 17)
# 处理进度: 202/591 (34.18%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (318, 9)
# 股票代码 301328 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1546, 9)
# 添加数据以后形状： (1546, 21)
# 删除指定行、列后数据形状:  (1443, 17)
# 当前all_data的形状: (244923, 17)
# 处理进度: 204/591 (34.52%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (492, 9)
# 股票代码 301221 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1752, 9)
# 添加数据以后形状： (1752, 21)
# 删除指定行、列后数据形状:  (1649, 17)
# 当前all_data的形状: (246572, 17)
# 处理进度: 206/591 (34.86%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (512, 9)
# 添加数据以后形状： (512, 21)
# 删除指定行、列后数据形状:  (409, 17)
# 当前all_data的形状: (246981, 17)
# 处理进度: 207/591 (35.03%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1946, 9)
# 添加数据以后形状： (1946, 21)
# 删除指定行、列后数据形状:  (1843, 17)
# 当前all_data的形状: (248824, 17)
# 处理进度: 208/591 (35.19%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1161, 9)
# 添加数据以后形状： (1161, 21)
# 删除指定行、列后数据形状:  (1058, 17)
# 当前all_data的形状: (249882, 17)
# 处理进度: 209/591 (35.36%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (815, 9)
# 添加数据以后形状： (815, 21)
# 删除指定行、列后数据形状:  (712, 17)
# 当前all_data的形状: (250594, 17)
# 处理进度: 210/591 (35.53%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1580, 9)
# 添加数据以后形状： (1580, 21)
# 删除指定行、列后数据形状:  (1477, 17)
# 当前all_data的形状: (252071, 17)
# 处理进度: 211/591 (35.70%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1722, 9)
# 添加数据以后形状： (1722, 21)
# 删除指定行、列后数据形状:  (1619, 17)
# 当前all_data的形状: (253690, 17)
# 处理进度: 212/591 (35.87%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1949, 9)
# 添加数据以后形状： (1949, 21)
# 删除指定行、列后数据形状:  (1846, 17)
# 当前all_data的形状: (255536, 17)
# 处理进度: 213/591 (36.04%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (644, 9)
# 添加数据以后形状： (644, 21)
# 删除指定行、列后数据形状:  (541, 17)
# 当前all_data的形状: (256077, 17)
# 处理进度: 214/591 (36.21%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 21)
# 删除指定行、列后数据形状:  (1865, 17)
# 当前all_data的形状: (257942, 17)
# 处理进度: 215/591 (36.38%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (534, 9)
# 添加数据以后形状： (534, 21)
# 删除指定行、列后数据形状:  (431, 17)
# 当前all_data的形状: (258373, 17)
# 处理进度: 216/591 (36.55%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1953, 9)
# 添加数据以后形状： (1953, 21)
# 删除指定行、列后数据形状:  (1850, 17)
# 当前all_data的形状: (260223, 17)
# 处理进度: 217/591 (36.72%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (955, 9)
# 添加数据以后形状： (955, 21)
# 删除指定行、列后数据形状:  (852, 17)
# 当前all_data的形状: (261075, 17)
# 处理进度: 218/591 (36.89%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1190, 9)
# 添加数据以后形状： (1190, 21)
# 删除指定行、列后数据形状:  (1087, 17)
# 当前all_data的形状: (262162, 17)
# 处理进度: 219/591 (37.06%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (54, 9)
# 股票代码 301517 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1779, 9)
# 添加数据以后形状： (1779, 21)
# 删除指定行、列后数据形状:  (1676, 17)
# 当前all_data的形状: (263838, 17)
# 处理进度: 221/591 (37.39%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1680, 9)
# 添加数据以后形状： (1680, 21)
# 删除指定行、列后数据形状:  (1577, 17)
# 当前all_data的形状: (265415, 17)
# 处理进度: 222/591 (37.56%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (679, 9)
# 添加数据以后形状： (679, 21)
# 删除指定行、列后数据形状:  (576, 17)
# 当前all_data的形状: (265991, 17)
# 处理进度: 223/591 (37.73%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1939, 9)
# 添加数据以后形状： (1939, 21)
# 删除指定行、列后数据形状:  (1836, 17)
# 当前all_data的形状: (267827, 17)
# 处理进度: 224/591 (37.90%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (652, 9)
# 添加数据以后形状： (652, 21)
# 删除指定行、列后数据形状:  (549, 17)
# 当前all_data的形状: (268376, 17)
# 处理进度: 225/591 (38.07%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (58, 9)
# 股票代码 301559 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1152, 9)
# 添加数据以后形状： (1152, 21)
# 删除指定行、列后数据形状:  (1049, 17)
# 当前all_data的形状: (269425, 17)
# 处理进度: 227/591 (38.41%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (213, 9)
# 股票代码 301303 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1962, 9)
# 添加数据以后形状： (1962, 21)
# 删除指定行、列后数据形状:  (1859, 17)
# 当前all_data的形状: (271284, 17)
# 处理进度: 229/591 (38.75%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1127, 9)
# 添加数据以后形状： (1127, 21)
# 删除指定行、列后数据形状:  (1024, 17)
# 当前all_data的形状: (272308, 17)
# 处理进度: 230/591 (38.92%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1958, 9)
# 添加数据以后形状： (1958, 21)
# 删除指定行、列后数据形状:  (1855, 17)
# 当前all_data的形状: (274163, 17)
# 处理进度: 231/591 (39.09%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1755, 9)
# 添加数据以后形状： (1755, 21)
# 删除指定行、列后数据形状:  (1652, 17)
# 当前all_data的形状: (275815, 17)
# 处理进度: 232/591 (39.26%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (658, 9)
# 添加数据以后形状： (658, 21)
# 删除指定行、列后数据形状:  (555, 17)
# 当前all_data的形状: (276370, 17)
# 处理进度: 233/591 (39.42%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 21)
# 删除指定行、列后数据形状:  (1865, 17)
# 当前all_data的形状: (278235, 17)
# 处理进度: 234/591 (39.59%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (571, 9)
# 添加数据以后形状： (571, 21)
# 删除指定行、列后数据形状:  (468, 17)
# 当前all_data的形状: (278703, 17)
# 处理进度: 235/591 (39.76%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1948, 9)
# 添加数据以后形状： (1948, 21)
# 删除指定行、列后数据形状:  (1845, 17)
# 当前all_data的形状: (280548, 17)
# 处理进度: 236/591 (39.93%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (342, 9)
# 股票代码 301095 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (693, 9)
# 添加数据以后形状： (693, 21)
# 删除指定行、列后数据形状:  (590, 17)
# 当前all_data的形状: (281138, 17)
# 处理进度: 238/591 (40.27%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (271, 9)
# 股票代码 301377 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1710, 9)
# 添加数据以后形状： (1710, 21)
# 删除指定行、列后数据形状:  (1607, 17)
# 当前all_data的形状: (282745, 17)
# 处理进度: 240/591 (40.61%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1956, 9)
# 添加数据以后形状： (1956, 21)
# 删除指定行、列后数据形状:  (1853, 17)
# 当前all_data的形状: (284598, 17)
# 处理进度: 241/591 (40.78%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (312, 9)
# 股票代码 301327 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1873, 9)
# 添加数据以后形状： (1873, 21)
# 删除指定行、列后数据形状:  (1770, 17)
# 当前all_data的形状: (286368, 17)
# 处理进度: 243/591 (41.12%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (87, 9)
# 股票代码 301421 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1863, 9)
# 添加数据以后形状： (1863, 21)
# 删除指定行、列后数据形状:  (1760, 17)
# 当前all_data的形状: (288128, 17)
# 处理进度: 245/591 (41.46%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (131, 9)
# 股票代码 301262 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1955, 9)
# 添加数据以后形状： (1955, 21)
# 删除指定行、列后数据形状:  (1852, 17)
# 当前all_data的形状: (289980, 17)
# 处理进度: 247/591 (41.79%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1938, 9)
# 添加数据以后形状： (1938, 21)
# 删除指定行、列后数据形状:  (1835, 17)
# 当前all_data的形状: (291815, 17)
# 处理进度: 248/591 (41.96%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1961, 9)
# 添加数据以后形状： (1961, 21)
# 删除指定行、列后数据形状:  (1858, 17)
# 当前all_data的形状: (293673, 17)
# 处理进度: 249/591 (42.13%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1747, 9)
# 添加数据以后形状： (1747, 21)
# 删除指定行、列后数据形状:  (1644, 17)
# 当前all_data的形状: (295317, 17)
# 处理进度: 250/591 (42.30%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (347, 9)
# 股票代码 301269 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1196, 9)
# 添加数据以后形状： (1196, 21)
# 删除指定行、列后数据形状:  (1093, 17)
# 当前all_data的形状: (296410, 17)
# 处理进度: 252/591 (42.64%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1960, 9)
# 添加数据以后形状： (1960, 21)
# 删除指定行、列后数据形状:  (1857, 17)
# 当前all_data的形状: (298267, 17)
# 处理进度: 253/591 (42.81%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1955, 9)
# 添加数据以后形状： (1955, 21)
# 删除指定行、列后数据形状:  (1852, 17)
# 当前all_data的形状: (300119, 17)
# 处理进度: 254/591 (42.98%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1948, 9)
# 添加数据以后形状： (1948, 21)
# 删除指定行、列后数据形状:  (1845, 17)
# 当前all_data的形状: (301964, 17)
# 处理进度: 255/591 (43.15%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1019, 9)
# 添加数据以后形状： (1019, 21)
# 删除指定行、列后数据形状:  (916, 17)
# 当前all_data的形状: (302880, 17)
# 处理进度: 256/591 (43.32%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (467, 9)
# 股票代码 301217 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1890, 9)
# 添加数据以后形状： (1890, 21)
# 删除指定行、列后数据形状:  (1787, 17)
# 当前all_data的形状: (304667, 17)
# 处理进度: 258/591 (43.65%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (674, 9)
# 添加数据以后形状： (674, 21)
# 删除指定行、列后数据形状:  (571, 17)
# 当前all_data的形状: (305238, 17)
# 处理进度: 259/591 (43.82%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1903, 9)
# 添加数据以后形状： (1903, 21)
# 删除指定行、列后数据形状:  (1800, 17)
# 当前all_data的形状: (307038, 17)
# 处理进度: 260/591 (43.99%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1770, 9)
# 添加数据以后形状： (1770, 21)
# 删除指定行、列后数据形状:  (1667, 17)
# 当前all_data的形状: (308705, 17)
# 处理进度: 261/591 (44.16%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1658, 9)
# 添加数据以后形状： (1658, 21)
# 删除指定行、列后数据形状:  (1555, 17)
# 当前all_data的形状: (310260, 17)
# 处理进度: 262/591 (44.33%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1700, 9)
# 添加数据以后形状： (1700, 21)
# 删除指定行、列后数据形状:  (1597, 17)
# 当前all_data的形状: (311857, 17)
# 处理进度: 263/591 (44.50%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (656, 9)
# 添加数据以后形状： (656, 21)
# 删除指定行、列后数据形状:  (553, 17)
# 当前all_data的形状: (312410, 17)
# 处理进度: 264/591 (44.67%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (549, 9)
# 添加数据以后形状： (549, 21)
# 删除指定行、列后数据形状:  (446, 17)
# 当前all_data的形状: (312856, 17)
# 处理进度: 265/591 (44.84%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1967, 9)
# 添加数据以后形状： (1967, 21)
# 删除指定行、列后数据形状:  (1864, 17)
# 当前all_data的形状: (314720, 17)
# 处理进度: 266/591 (45.01%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1862, 9)
# 添加数据以后形状： (1862, 21)
# 删除指定行、列后数据形状:  (1759, 17)
# 当前all_data的形状: (316479, 17)
# 处理进度: 267/591 (45.18%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (486, 9)
# 股票代码 301127 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 21)
# 删除指定行、列后数据形状:  (1865, 17)
# 当前all_data的形状: (318344, 17)
# 处理进度: 269/591 (45.52%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1486, 9)
# 添加数据以后形状： (1486, 21)
# 删除指定行、列后数据形状:  (1383, 17)
# 当前all_data的形状: (319727, 17)
# 处理进度: 270/591 (45.69%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1764, 9)
# 添加数据以后形状： (1764, 21)
# 删除指定行、列后数据形状:  (1661, 17)
# 当前all_data的形状: (321388, 17)
# 处理进度: 271/591 (45.85%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1934, 9)
# 添加数据以后形状： (1934, 21)
# 删除指定行、列后数据形状:  (1831, 17)
# 当前all_data的形状: (323219, 17)
# 处理进度: 272/591 (46.02%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1693, 9)
# 添加数据以后形状： (1693, 21)
# 删除指定行、列后数据形状:  (1590, 17)
# 当前all_data的形状: (324809, 17)
# 处理进度: 273/591 (46.19%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (77, 9)
# 股票代码 301251 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (97, 9)
# 股票代码 301487 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1965, 9)
# 添加数据以后形状： (1965, 21)
# 删除指定行、列后数据形状:  (1862, 17)
# 当前all_data的形状: (326671, 17)
# 处理进度: 276/591 (46.70%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1966, 9)
# 添加数据以后形状： (1966, 21)
# 删除指定行、列后数据形状:  (1863, 17)
# 当前all_data的形状: (328534, 17)
# 处理进度: 277/591 (46.87%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (926, 9)
# 添加数据以后形状： (926, 21)
# 删除指定行、列后数据形状:  (823, 17)
# 当前all_data的形状: (329357, 17)
# 处理进度: 278/591 (47.04%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1623, 9)
# 添加数据以后形状： (1623, 21)
# 删除指定行、列后数据形状:  (1520, 17)
# 当前all_data的形状: (330877, 17)
# 处理进度: 279/591 (47.21%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (613, 9)
# 添加数据以后形状： (613, 21)
# 删除指定行、列后数据形状:  (510, 17)
# 当前all_data的形状: (331387, 17)
# 处理进度: 280/591 (47.38%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (946, 9)
# 添加数据以后形状： (946, 21)
# 删除指定行、列后数据形状:  (843, 17)
# 当前all_data的形状: (332230, 17)
# 处理进度: 281/591 (47.55%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1646, 9)
# 添加数据以后形状： (1646, 21)
# 删除指定行、列后数据形状:  (1543, 17)
# 当前all_data的形状: (333773, 17)
# 处理进度: 282/591 (47.72%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (557, 9)
# 添加数据以后形状： (557, 21)
# 删除指定行、列后数据形状:  (454, 17)
# 当前all_data的形状: (334227, 17)
# 处理进度: 283/591 (47.88%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1884, 9)
# 添加数据以后形状： (1884, 21)
# 删除指定行、列后数据形状:  (1781, 17)
# 当前all_data的形状: (336008, 17)
# 处理进度: 284/591 (48.05%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 21)
# 删除指定行、列后数据形状:  (1865, 17)
# 当前all_data的形状: (337873, 17)
# 处理进度: 285/591 (48.22%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1766, 9)
# 添加数据以后形状： (1766, 21)
# 删除指定行、列后数据形状:  (1663, 17)
# 当前all_data的形状: (339536, 17)
# 处理进度: 286/591 (48.39%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (444, 9)
# 股票代码 301215 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1512, 9)
# 添加数据以后形状： (1512, 21)
# 删除指定行、列后数据形状:  (1409, 17)
# 当前all_data的形状: (340945, 17)
# 处理进度: 288/591 (48.73%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (265, 9)
# 股票代码 301311 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1887, 9)
# 添加数据以后形状： (1887, 21)
# 删除指定行、列后数据形状:  (1784, 17)
# 当前all_data的形状: (342729, 17)
# 处理进度: 290/591 (49.07%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1763, 9)
# 添加数据以后形状： (1763, 21)
# 删除指定行、列后数据形状:  (1660, 17)
# 当前all_data的形状: (344389, 17)
# 处理进度: 291/591 (49.24%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1629, 9)
# 添加数据以后形状： (1629, 21)
# 删除指定行、列后数据形状:  (1526, 17)
# 当前all_data的形状: (345915, 17)
# 处理进度: 292/591 (49.41%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (103, 9)
# 股票代码 301371 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1132, 9)
# 添加数据以后形状： (1132, 21)
# 删除指定行、列后数据形状:  (1029, 17)
# 当前all_data的形状: (346944, 17)
# 处理进度: 294/591 (49.75%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1960, 9)
# 添加数据以后形状： (1960, 21)
# 删除指定行、列后数据形状:  (1857, 17)
# 当前all_data的形状: (348801, 17)
# 处理进度: 295/591 (49.92%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1825, 9)
# 添加数据以后形状： (1825, 21)
# 删除指定行、列后数据形状:  (1722, 17)
# 当前all_data的形状: (350523, 17)
# 处理进度: 296/591 (50.08%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1850, 9)
# 添加数据以后形状： (1850, 21)
# 删除指定行、列后数据形状:  (1747, 17)
# 当前all_data的形状: (352270, 17)
# 处理进度: 297/591 (50.25%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1560, 9)
# 添加数据以后形状： (1560, 21)
# 删除指定行、列后数据形状:  (1457, 17)
# 当前all_data的形状: (353727, 17)
# 处理进度: 298/591 (50.42%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1665, 9)
# 添加数据以后形状： (1665, 21)
# 删除指定行、列后数据形状:  (1562, 17)
# 当前all_data的形状: (355289, 17)
# 处理进度: 299/591 (50.59%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1967, 9)
# 添加数据以后形状： (1967, 21)
# 删除指定行、列后数据形状:  (1864, 17)
# 当前all_data的形状: (357153, 17)
# 处理进度: 300/591 (50.76%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (497, 9)
# 股票代码 301177 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1563, 9)
# 添加数据以后形状： (1563, 21)
# 删除指定行、列后数据形状:  (1460, 17)
# 当前all_data的形状: (358613, 17)
# 处理进度: 302/591 (51.10%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1957, 9)
# 添加数据以后形状： (1957, 21)
# 删除指定行、列后数据形状:  (1854, 17)
# 当前all_data的形状: (360467, 17)
# 处理进度: 303/591 (51.27%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1730, 9)
# 添加数据以后形状： (1730, 21)
# 删除指定行、列后数据形状:  (1627, 17)
# 当前all_data的形状: (362094, 17)
# 处理进度: 304/591 (51.44%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 21)
# 删除指定行、列后数据形状:  (1865, 17)
# 当前all_data的形状: (363959, 17)
# 处理进度: 305/591 (51.61%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1723, 9)
# 添加数据以后形状： (1723, 21)
# 删除指定行、列后数据形状:  (1620, 17)
# 当前all_data的形状: (365579, 17)
# 处理进度: 306/591 (51.78%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1946, 9)
# 添加数据以后形状： (1946, 21)
# 删除指定行、列后数据形状:  (1843, 17)
# 当前all_data的形状: (367422, 17)
# 处理进度: 307/591 (51.95%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1965, 9)
# 添加数据以后形状： (1965, 21)
# 删除指定行、列后数据形状:  (1862, 17)
# 当前all_data的形状: (369284, 17)
# 处理进度: 308/591 (52.12%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1963, 9)
# 添加数据以后形状： (1963, 21)
# 删除指定行、列后数据形状:  (1860, 17)
# 当前all_data的形状: (371144, 17)
# 处理进度: 309/591 (52.28%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1853, 9)
# 添加数据以后形状： (1853, 21)
# 删除指定行、列后数据形状:  (1750, 17)
# 当前all_data的形状: (372894, 17)
# 处理进度: 310/591 (52.45%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (752, 9)
# 添加数据以后形状： (752, 21)
# 删除指定行、列后数据形状:  (649, 17)
# 当前all_data的形状: (373543, 17)
# 处理进度: 311/591 (52.62%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1684, 9)
# 添加数据以后形状： (1684, 21)
# 删除指定行、列后数据形状:  (1581, 17)
# 当前all_data的形状: (375124, 17)
# 处理进度: 312/591 (52.79%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1653, 9)
# 添加数据以后形状： (1653, 21)
# 删除指定行、列后数据形状:  (1550, 17)
# 当前all_data的形状: (376674, 17)
# 处理进度: 313/591 (52.96%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1710, 9)
# 添加数据以后形状： (1710, 21)
# 删除指定行、列后数据形状:  (1607, 17)
# 当前all_data的形状: (378281, 17)
# 处理进度: 314/591 (53.13%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1803, 9)
# 添加数据以后形状： (1803, 21)
# 删除指定行、列后数据形状:  (1700, 17)
# 当前all_data的形状: (379981, 17)
# 处理进度: 315/591 (53.30%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (155, 9)
# 股票代码 301382 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (332, 9)
# 股票代码 301171 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1928, 9)
# 添加数据以后形状： (1928, 21)
# 删除指定行、列后数据形状:  (1825, 17)
# 当前all_data的形状: (381806, 17)
# 处理进度: 318/591 (53.81%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (496, 9)
# 股票代码 301101 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1003, 9)
# 添加数据以后形状： (1003, 21)
# 删除指定行、列后数据形状:  (900, 17)
# 当前all_data的形状: (382706, 17)
# 处理进度: 320/591 (54.15%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1420, 9)
# 添加数据以后形状： (1420, 21)
# 删除指定行、列后数据形状:  (1317, 17)
# 当前all_data的形状: (384023, 17)
# 处理进度: 321/591 (54.31%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (307, 9)
# 股票代码 301366 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (653, 9)
# 添加数据以后形状： (653, 21)
# 删除指定行、列后数据形状:  (550, 17)
# 当前all_data的形状: (384573, 17)
# 处理进度: 323/591 (54.65%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1918, 9)
# 添加数据以后形状： (1918, 21)
# 删除指定行、列后数据形状:  (1815, 17)
# 当前all_data的形状: (386388, 17)
# 处理进度: 324/591 (54.82%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (629, 9)
# 添加数据以后形状： (629, 21)
# 删除指定行、列后数据形状:  (526, 17)
# 当前all_data的形状: (386914, 17)
# 处理进度: 325/591 (54.99%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 21)
# 删除指定行、列后数据形状:  (1865, 17)
# 当前all_data的形状: (388779, 17)
# 处理进度: 326/591 (55.16%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 21)
# 删除指定行、列后数据形状:  (1865, 17)
# 当前all_data的形状: (390644, 17)
# 处理进度: 327/591 (55.33%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1963, 9)
# 添加数据以后形状： (1963, 21)
# 删除指定行、列后数据形状:  (1860, 17)
# 当前all_data的形状: (392504, 17)
# 处理进度: 328/591 (55.50%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1538, 9)
# 添加数据以后形状： (1538, 21)
# 删除指定行、列后数据形状:  (1435, 17)
# 当前all_data的形状: (393939, 17)
# 处理进度: 329/591 (55.67%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1539, 9)
# 添加数据以后形状： (1539, 21)
# 删除指定行、列后数据形状:  (1436, 17)
# 当前all_data的形状: (395375, 17)
# 处理进度: 330/591 (55.84%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (660, 9)
# 添加数据以后形状： (660, 21)
# 删除指定行、列后数据形状:  (557, 17)
# 当前all_data的形状: (395932, 17)
# 处理进度: 331/591 (56.01%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (115, 9)
# 股票代码 301456 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1963, 9)
# 添加数据以后形状： (1963, 21)
# 删除指定行、列后数据形状:  (1860, 17)
# 当前all_data的形状: (397792, 17)
# 处理进度: 333/591 (56.35%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (429, 9)
# 股票代码 301216 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1791, 9)
# 添加数据以后形状： (1791, 21)
# 删除指定行、列后数据形状:  (1688, 17)
# 当前all_data的形状: (399480, 17)
# 处理进度: 335/591 (56.68%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1824, 9)
# 添加数据以后形状： (1824, 21)
# 删除指定行、列后数据形状:  (1721, 17)
# 当前all_data的形状: (401201, 17)
# 处理进度: 336/591 (56.85%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1591, 9)
# 添加数据以后形状： (1591, 21)
# 删除指定行、列后数据形状:  (1488, 17)
# 当前all_data的形状: (402689, 17)
# 处理进度: 337/591 (57.02%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (286, 9)
# 股票代码 301367 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (206, 9)
# 股票代码 301408 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1681, 9)
# 添加数据以后形状： (1681, 21)
# 删除指定行、列后数据形状:  (1578, 17)
# 当前all_data的形状: (404267, 17)
# 处理进度: 340/591 (57.53%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (579, 9)
# 添加数据以后形状： (579, 21)
# 删除指定行、列后数据形状:  (476, 17)
# 当前all_data的形状: (404743, 17)
# 处理进度: 341/591 (57.70%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1903, 9)
# 添加数据以后形状： (1903, 21)
# 删除指定行、列后数据形状:  (1800, 17)
# 当前all_data的形状: (406543, 17)
# 处理进度: 342/591 (57.87%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1541, 9)
# 添加数据以后形状： (1541, 21)
# 删除指定行、列后数据形状:  (1438, 17)
# 当前all_data的形状: (407981, 17)
# 处理进度: 343/591 (58.04%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (408, 9)
# 股票代码 301162 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1833, 9)
# 添加数据以后形状： (1833, 21)
# 删除指定行、列后数据形状:  (1730, 17)
# 当前all_data的形状: (409711, 17)
# 处理进度: 345/591 (58.38%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1821, 9)
# 添加数据以后形状： (1821, 21)
# 删除指定行、列后数据形状:  (1718, 17)
# 当前all_data的形状: (411429, 17)
# 处理进度: 346/591 (58.54%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1848, 9)
# 添加数据以后形状： (1848, 21)
# 删除指定行、列后数据形状:  (1745, 17)
# 当前all_data的形状: (413174, 17)
# 处理进度: 347/591 (58.71%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1961, 9)
# 添加数据以后形状： (1961, 21)
# 删除指定行、列后数据形状:  (1858, 17)
# 当前all_data的形状: (415032, 17)
# 处理进度: 348/591 (58.88%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (862, 9)
# 添加数据以后形状： (862, 21)
# 删除指定行、列后数据形状:  (759, 17)
# 当前all_data的形状: (415791, 17)
# 处理进度: 349/591 (59.05%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (599, 9)
# 添加数据以后形状： (599, 21)
# 删除指定行、列后数据形状:  (496, 17)
# 当前all_data的形状: (416287, 17)
# 处理进度: 350/591 (59.22%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (78, 9)
# 股票代码 301507 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1923, 9)
# 添加数据以后形状： (1923, 21)
# 删除指定行、列后数据形状:  (1820, 17)
# 当前all_data的形状: (418107, 17)
# 处理进度: 352/591 (59.56%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 21)
# 删除指定行、列后数据形状:  (1865, 17)
# 当前all_data的形状: (419972, 17)
# 处理进度: 353/591 (59.73%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1958, 9)
# 添加数据以后形状： (1958, 21)
# 删除指定行、列后数据形状:  (1855, 17)
# 当前all_data的形状: (421827, 17)
# 处理进度: 354/591 (59.90%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1404, 9)
# 添加数据以后形状： (1404, 21)
# 删除指定行、列后数据形状:  (1301, 17)
# 当前all_data的形状: (423128, 17)
# 处理进度: 355/591 (60.07%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (815, 9)
# 添加数据以后形状： (815, 21)
# 删除指定行、列后数据形状:  (712, 17)
# 当前all_data的形状: (423840, 17)
# 处理进度: 356/591 (60.24%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (264, 9)
# 股票代码 301391 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (847, 9)
# 添加数据以后形状： (847, 21)
# 删除指定行、列后数据形状:  (744, 17)
# 当前all_data的形状: (424584, 17)
# 处理进度: 358/591 (60.58%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1834, 9)
# 添加数据以后形状： (1834, 21)
# 删除指定行、列后数据形状:  (1731, 17)
# 当前all_data的形状: (426315, 17)
# 处理进度: 359/591 (60.74%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1949, 9)
# 添加数据以后形状： (1949, 21)
# 删除指定行、列后数据形状:  (1846, 17)
# 当前all_data的形状: (428161, 17)
# 处理进度: 360/591 (60.91%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1683, 9)
# 添加数据以后形状： (1683, 21)
# 删除指定行、列后数据形状:  (1580, 17)
# 当前all_data的形状: (429741, 17)
# 处理进度: 361/591 (61.08%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (838, 9)
# 添加数据以后形状： (838, 21)
# 删除指定行、列后数据形状:  (735, 17)
# 当前all_data的形状: (430476, 17)
# 处理进度: 362/591 (61.25%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (316, 9)
# 股票代码 301205 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1591, 9)
# 添加数据以后形状： (1591, 21)
# 删除指定行、列后数据形状:  (1488, 17)
# 当前all_data的形状: (431964, 17)
# 处理进度: 364/591 (61.59%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (837, 9)
# 添加数据以后形状： (837, 21)
# 删除指定行、列后数据形状:  (734, 17)
# 当前all_data的形状: (432698, 17)
# 处理进度: 365/591 (61.76%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (410, 9)
# 股票代码 301109 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1880, 9)
# 添加数据以后形状： (1880, 21)
# 删除指定行、列后数据形状:  (1777, 17)
# 当前all_data的形状: (434475, 17)
# 处理进度: 367/591 (62.10%)
# ...
# 原始数据形状： (1168, 9)
# 添加数据以后形状： (1168, 21)
# 删除指定行、列后数据形状:  (1065, 17)
# 当前all_data的形状: (559126, 17)
# 处理进度: 476/591 (80.54%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1962, 9)
# 添加数据以后形状： (1962, 21)
# 删除指定行、列后数据形状:  (1859, 17)
# 当前all_data的形状: (560985, 17)
# 处理进度: 477/591 (80.71%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1956, 9)
# 添加数据以后形状： (1956, 21)
# 删除指定行、列后数据形状:  (1853, 17)
# 当前all_data的形状: (562838, 17)
# 处理进度: 478/591 (80.88%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1963, 9)
# 添加数据以后形状： (1963, 21)
# 删除指定行、列后数据形状:  (1860, 17)
# 当前all_data的形状: (564698, 17)
# 处理进度: 479/591 (81.05%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1641, 9)
# 添加数据以后形状： (1641, 21)
# 删除指定行、列后数据形状:  (1538, 17)
# 当前all_data的形状: (566236, 17)
# 处理进度: 480/591 (81.22%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 21)
# 删除指定行、列后数据形状:  (1865, 17)
# 当前all_data的形状: (568101, 17)
# 处理进度: 481/591 (81.39%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1959, 9)
# 添加数据以后形状： (1959, 21)
# 删除指定行、列后数据形状:  (1856, 17)
# 当前all_data的形状: (569957, 17)
# 处理进度: 482/591 (81.56%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (533, 9)
# 添加数据以后形状： (533, 21)
# 删除指定行、列后数据形状:  (430, 17)
# 当前all_data的形状: (570387, 17)
# 处理进度: 483/591 (81.73%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (773, 9)
# 添加数据以后形状： (773, 21)
# 删除指定行、列后数据形状:  (670, 17)
# 当前all_data的形状: (571057, 17)
# 处理进度: 484/591 (81.90%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1279, 9)
# 添加数据以后形状： (1279, 21)
# 删除指定行、列后数据形状:  (1176, 17)
# 当前all_data的形状: (572233, 17)
# 处理进度: 485/591 (82.06%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 21)
# 删除指定行、列后数据形状:  (1865, 17)
# 当前all_data的形状: (574098, 17)
# 处理进度: 486/591 (82.23%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (891, 9)
# 添加数据以后形状： (891, 21)
# 删除指定行、列后数据形状:  (788, 17)
# 当前all_data的形状: (574886, 17)
# 处理进度: 487/591 (82.40%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1869, 9)
# 添加数据以后形状： (1869, 21)
# 删除指定行、列后数据形状:  (1766, 17)
# 当前all_data的形状: (576652, 17)
# 处理进度: 488/591 (82.57%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1889, 9)
# 添加数据以后形状： (1889, 21)
# 删除指定行、列后数据形状:  (1786, 17)
# 当前all_data的形状: (578438, 17)
# 处理进度: 489/591 (82.74%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1003, 9)
# 添加数据以后形状： (1003, 21)
# 删除指定行、列后数据形状:  (900, 17)
# 当前all_data的形状: (579338, 17)
# 处理进度: 490/591 (82.91%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1954, 9)
# 添加数据以后形状： (1954, 21)
# 删除指定行、列后数据形状:  (1851, 17)
# 当前all_data的形状: (581189, 17)
# 处理进度: 491/591 (83.08%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 21)
# 删除指定行、列后数据形状:  (1865, 17)
# 当前all_data的形状: (583054, 17)
# 处理进度: 492/591 (83.25%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (997, 9)
# 添加数据以后形状： (997, 21)
# 删除指定行、列后数据形状:  (894, 17)
# 当前all_data的形状: (583948, 17)
# 处理进度: 493/591 (83.42%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1940, 9)
# 添加数据以后形状： (1940, 21)
# 删除指定行、列后数据形状:  (1837, 17)
# 当前all_data的形状: (585785, 17)
# 处理进度: 494/591 (83.59%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (557, 9)
# 添加数据以后形状： (557, 21)
# 删除指定行、列后数据形状:  (454, 17)
# 当前all_data的形状: (586239, 17)
# 处理进度: 495/591 (83.76%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1840, 9)
# 添加数据以后形状： (1840, 21)
# 删除指定行、列后数据形状:  (1737, 17)
# 当前all_data的形状: (587976, 17)
# 处理进度: 496/591 (83.93%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1965, 9)
# 添加数据以后形状： (1965, 21)
# 删除指定行、列后数据形状:  (1862, 17)
# 当前all_data的形状: (589838, 17)
# 处理进度: 497/591 (84.09%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1605, 9)
# 添加数据以后形状： (1605, 21)
# 删除指定行、列后数据形状:  (1502, 17)
# 当前all_data的形状: (591340, 17)
# 处理进度: 498/591 (84.26%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1935, 9)
# 添加数据以后形状： (1935, 21)
# 删除指定行、列后数据形状:  (1832, 17)
# 当前all_data的形状: (593172, 17)
# 处理进度: 499/591 (84.43%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1651, 9)
# 添加数据以后形状： (1651, 21)
# 删除指定行、列后数据形状:  (1548, 17)
# 当前all_data的形状: (594720, 17)
# 处理进度: 500/591 (84.60%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (593, 9)
# 添加数据以后形状： (593, 21)
# 删除指定行、列后数据形状:  (490, 17)
# 当前all_data的形状: (595210, 17)
# 处理进度: 501/591 (84.77%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1914, 9)
# 添加数据以后形状： (1914, 21)
# 删除指定行、列后数据形状:  (1811, 17)
# 当前all_data的形状: (597021, 17)
# 处理进度: 502/591 (84.94%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1783, 9)
# 添加数据以后形状： (1783, 21)
# 删除指定行、列后数据形状:  (1680, 17)
# 当前all_data的形状: (598701, 17)
# 处理进度: 503/591 (85.11%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1516, 9)
# 添加数据以后形状： (1516, 21)
# 删除指定行、列后数据形状:  (1413, 17)
# 当前all_data的形状: (600114, 17)
# 处理进度: 504/591 (85.28%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1478, 9)
# 添加数据以后形状： (1478, 21)
# 删除指定行、列后数据形状:  (1375, 17)
# 当前all_data的形状: (601489, 17)
# 处理进度: 505/591 (85.45%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1708, 9)
# 添加数据以后形状： (1708, 21)
# 删除指定行、列后数据形状:  (1605, 17)
# 当前all_data的形状: (603094, 17)
# 处理进度: 506/591 (85.62%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1725, 9)
# 添加数据以后形状： (1725, 21)
# 删除指定行、列后数据形状:  (1622, 17)
# 当前all_data的形状: (604716, 17)
# 处理进度: 507/591 (85.79%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 21)
# 删除指定行、列后数据形状:  (1865, 17)
# 当前all_data的形状: (606581, 17)
# 处理进度: 508/591 (85.96%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (82, 9)
# 股票代码 301525 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1562, 9)
# 添加数据以后形状： (1562, 21)
# 删除指定行、列后数据形状:  (1459, 17)
# 当前all_data的形状: (608040, 17)
# 处理进度: 510/591 (86.29%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1013, 9)
# 添加数据以后形状： (1013, 21)
# 删除指定行、列后数据形状:  (910, 17)
# 当前all_data的形状: (608950, 17)
# 处理进度: 511/591 (86.46%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1343, 9)
# 添加数据以后形状： (1343, 21)
# 删除指定行、列后数据形状:  (1240, 17)
# 当前all_data的形状: (610190, 17)
# 处理进度: 512/591 (86.63%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (61, 9)
# 股票代码 301558 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1538, 9)
# 添加数据以后形状： (1538, 21)
# 删除指定行、列后数据形状:  (1435, 17)
# 当前all_data的形状: (611625, 17)
# 处理进度: 514/591 (86.97%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1399, 9)
# 添加数据以后形状： (1399, 21)
# 删除指定行、列后数据形状:  (1296, 17)
# 当前all_data的形状: (612921, 17)
# 处理进度: 515/591 (87.14%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 21)
# 删除指定行、列后数据形状:  (1865, 17)
# 当前all_data的形状: (614786, 17)
# 处理进度: 516/591 (87.31%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1549, 9)
# 添加数据以后形状： (1549, 21)
# 删除指定行、列后数据形状:  (1446, 17)
# 当前all_data的形状: (616232, 17)
# 处理进度: 517/591 (87.48%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1764, 9)
# 添加数据以后形状： (1764, 21)
# 删除指定行、列后数据形状:  (1661, 17)
# 当前all_data的形状: (617893, 17)
# 处理进度: 518/591 (87.65%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (887, 9)
# 添加数据以后形状： (887, 21)
# 删除指定行、列后数据形状:  (784, 17)
# 当前all_data的形状: (618677, 17)
# 处理进度: 519/591 (87.82%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1948, 9)
# 添加数据以后形状： (1948, 21)
# 删除指定行、列后数据形状:  (1845, 17)
# 当前all_data的形状: (620522, 17)
# 处理进度: 520/591 (87.99%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 21)
# 删除指定行、列后数据形状:  (1865, 17)
# 当前all_data的形状: (622387, 17)
# 处理进度: 521/591 (88.16%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1501, 9)
# 添加数据以后形状： (1501, 21)
# 删除指定行、列后数据形状:  (1398, 17)
# 当前all_data的形状: (623785, 17)
# 处理进度: 522/591 (88.32%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1884, 9)
# 添加数据以后形状： (1884, 21)
# 删除指定行、列后数据形状:  (1781, 17)
# 当前all_data的形状: (625566, 17)
# 处理进度: 523/591 (88.49%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1035, 9)
# 添加数据以后形状： (1035, 21)
# 删除指定行、列后数据形状:  (932, 17)
# 当前all_data的形状: (626498, 17)
# 处理进度: 524/591 (88.66%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1497, 9)
# 添加数据以后形状： (1497, 21)
# 删除指定行、列后数据形状:  (1394, 17)
# 当前all_data的形状: (627892, 17)
# 处理进度: 525/591 (88.83%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (475, 9)
# 股票代码 301117 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1945, 9)
# 添加数据以后形状： (1945, 21)
# 删除指定行、列后数据形状:  (1842, 17)
# 当前all_data的形状: (629734, 17)
# 处理进度: 527/591 (89.17%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1952, 9)
# 添加数据以后形状： (1952, 21)
# 删除指定行、列后数据形状:  (1849, 17)
# 当前all_data的形状: (631583, 17)
# 处理进度: 528/591 (89.34%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1139, 9)
# 添加数据以后形状： (1139, 21)
# 删除指定行、列后数据形状:  (1036, 17)
# 当前all_data的形状: (632619, 17)
# 处理进度: 529/591 (89.51%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (96, 9)
# 股票代码 301348 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1958, 9)
# 添加数据以后形状： (1958, 21)
# 删除指定行、列后数据形状:  (1855, 17)
# 当前all_data的形状: (634474, 17)
# 处理进度: 531/591 (89.85%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 21)
# 删除指定行、列后数据形状:  (1865, 17)
# 当前all_data的形状: (636339, 17)
# 处理进度: 532/591 (90.02%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (815, 9)
# 添加数据以后形状： (815, 21)
# 删除指定行、列后数据形状:  (712, 17)
# 当前all_data的形状: (637051, 17)
# 处理进度: 533/591 (90.19%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1652, 9)
# 添加数据以后形状： (1652, 21)
# 删除指定行、列后数据形状:  (1549, 17)
# 当前all_data的形状: (638600, 17)
# 处理进度: 534/591 (90.36%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1853, 9)
# 添加数据以后形状： (1853, 21)
# 删除指定行、列后数据形状:  (1750, 17)
# 当前all_data的形状: (640350, 17)
# 处理进度: 535/591 (90.52%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1444, 9)
# 添加数据以后形状： (1444, 21)
# 删除指定行、列后数据形状:  (1341, 17)
# 当前all_data的形状: (641691, 17)
# 处理进度: 536/591 (90.69%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (663, 9)
# 添加数据以后形状： (663, 21)
# 删除指定行、列后数据形状:  (560, 17)
# 当前all_data的形状: (642251, 17)
# 处理进度: 537/591 (90.86%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1553, 9)
# 添加数据以后形状： (1553, 21)
# 删除指定行、列后数据形状:  (1450, 17)
# 当前all_data的形状: (643701, 17)
# 处理进度: 538/591 (91.03%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1126, 9)
# 添加数据以后形状： (1126, 21)
# 删除指定行、列后数据形状:  (1023, 17)
# 当前all_data的形状: (644724, 17)
# 处理进度: 539/591 (91.20%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1909, 9)
# 添加数据以后形状： (1909, 21)
# 删除指定行、列后数据形状:  (1806, 17)
# 当前all_data的形状: (646530, 17)
# 处理进度: 540/591 (91.37%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 21)
# 删除指定行、列后数据形状:  (1865, 17)
# 当前all_data的形状: (648395, 17)
# 处理进度: 541/591 (91.54%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1844, 9)
# 添加数据以后形状： (1844, 21)
# 删除指定行、列后数据形状:  (1741, 17)
# 当前all_data的形状: (650136, 17)
# 处理进度: 542/591 (91.71%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1038, 9)
# 添加数据以后形状： (1038, 21)
# 删除指定行、列后数据形状:  (935, 17)
# 当前all_data的形状: (651071, 17)
# 处理进度: 543/591 (91.88%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1791, 9)
# 添加数据以后形状： (1791, 21)
# 删除指定行、列后数据形状:  (1688, 17)
# 当前all_data的形状: (652759, 17)
# 处理进度: 544/591 (92.05%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 21)
# 删除指定行、列后数据形状:  (1865, 17)
# 当前all_data的形状: (654624, 17)
# 处理进度: 545/591 (92.22%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (138, 9)
# 股票代码 301383 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1874, 9)
# 添加数据以后形状： (1874, 21)
# 删除指定行、列后数据形状:  (1771, 17)
# 当前all_data的形状: (656395, 17)
# 处理进度: 547/591 (92.55%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (518, 9)
# 添加数据以后形状： (518, 21)
# 删除指定行、列后数据形状:  (415, 17)
# 当前all_data的形状: (656810, 17)
# 处理进度: 548/591 (92.72%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1551, 9)
# 添加数据以后形状： (1551, 21)
# 删除指定行、列后数据形状:  (1448, 17)
# 当前all_data的形状: (658258, 17)
# 处理进度: 549/591 (92.89%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 21)
# 删除指定行、列后数据形状:  (1865, 17)
# 当前all_data的形状: (660123, 17)
# 处理进度: 550/591 (93.06%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 21)
# 删除指定行、列后数据形状:  (1865, 17)
# 当前all_data的形状: (661988, 17)
# 处理进度: 551/591 (93.23%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1939, 9)
# 添加数据以后形状： (1939, 21)
# 删除指定行、列后数据形状:  (1836, 17)
# 当前all_data的形状: (663824, 17)
# 处理进度: 552/591 (93.40%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1920, 9)
# 添加数据以后形状： (1920, 21)
# 删除指定行、列后数据形状:  (1817, 17)
# 当前all_data的形状: (665641, 17)
# 处理进度: 553/591 (93.57%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1764, 9)
# 添加数据以后形状： (1764, 21)
# 删除指定行、列后数据形状:  (1661, 17)
# 当前all_data的形状: (667302, 17)
# 处理进度: 554/591 (93.74%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1793, 9)
# 添加数据以后形状： (1793, 21)
# 删除指定行、列后数据形状:  (1690, 17)
# 当前all_data的形状: (668992, 17)
# 处理进度: 555/591 (93.91%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1948, 9)
# 添加数据以后形状： (1948, 21)
# 删除指定行、列后数据形状:  (1845, 17)
# 当前all_data的形状: (670837, 17)
# 处理进度: 556/591 (94.08%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (802, 9)
# 添加数据以后形状： (802, 21)
# 删除指定行、列后数据形状:  (699, 17)
# 当前all_data的形状: (671536, 17)
# 处理进度: 557/591 (94.25%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1791, 9)
# 添加数据以后形状： (1791, 21)
# 删除指定行、列后数据形状:  (1688, 17)
# 当前all_data的形状: (673224, 17)
# 处理进度: 558/591 (94.42%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1954, 9)
# 添加数据以后形状： (1954, 21)
# 删除指定行、列后数据形状:  (1851, 17)
# 当前all_data的形状: (675075, 17)
# 处理进度: 559/591 (94.59%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 21)
# 删除指定行、列后数据形状:  (1865, 17)
# 当前all_data的形状: (676940, 17)
# 处理进度: 560/591 (94.75%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1726, 9)
# 添加数据以后形状： (1726, 21)
# 删除指定行、列后数据形状:  (1623, 17)
# 当前all_data的形状: (678563, 17)
# 处理进度: 561/591 (94.92%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (125, 9)
# 股票代码 301291 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 21)
# 删除指定行、列后数据形状:  (1865, 17)
# 当前all_data的形状: (680428, 17)
# 处理进度: 563/591 (95.26%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1910, 9)
# 添加数据以后形状： (1910, 21)
# 删除指定行、列后数据形状:  (1807, 17)
# 当前all_data的形状: (682235, 17)
# 处理进度: 564/591 (95.43%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (377, 9)
# 股票代码 301238 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (652, 9)
# 添加数据以后形状： (652, 21)
# 删除指定行、列后数据形状:  (549, 17)
# 当前all_data的形状: (682784, 17)
# 处理进度: 566/591 (95.77%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1491, 9)
# 添加数据以后形状： (1491, 21)
# 删除指定行、列后数据形状:  (1388, 17)
# 当前all_data的形状: (684172, 17)
# 处理进度: 567/591 (95.94%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1699, 9)
# 添加数据以后形状： (1699, 21)
# 删除指定行、列后数据形状:  (1596, 17)
# 当前all_data的形状: (685768, 17)
# 处理进度: 568/591 (96.11%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1945, 9)
# 添加数据以后形状： (1945, 21)
# 删除指定行、列后数据形状:  (1842, 17)
# 当前all_data的形状: (687610, 17)
# 处理进度: 569/591 (96.28%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (530, 9)
# 添加数据以后形状： (530, 21)
# 删除指定行、列后数据形状:  (427, 17)
# 当前all_data的形状: (688037, 17)
# 处理进度: 570/591 (96.45%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (101, 9)
# 股票代码 301509 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (522, 9)
# 添加数据以后形状： (522, 21)
# 删除指定行、列后数据形状:  (419, 17)
# 当前all_data的形状: (688456, 17)
# 处理进度: 572/591 (96.79%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (430, 9)
# 股票代码 301102 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (346, 9)
# 股票代码 301195 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (439, 9)
# 股票代码 301236 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 21)
# 删除指定行、列后数据形状:  (1865, 17)
# 当前all_data的形状: (690321, 17)
# 处理进度: 576/591 (97.46%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (729, 9)
# 添加数据以后形状： (729, 21)
# 删除指定行、列后数据形状:  (626, 17)
# 当前all_data的形状: (690947, 17)
# 处理进度: 577/591 (97.63%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1914, 9)
# 添加数据以后形状： (1914, 21)
# 删除指定行、列后数据形状:  (1811, 17)
# 当前all_data的形状: (692758, 17)
# 处理进度: 578/591 (97.80%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1957, 9)
# 添加数据以后形状： (1957, 21)
# 删除指定行、列后数据形状:  (1854, 17)
# 当前all_data的形状: (694612, 17)
# 处理进度: 579/591 (97.97%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1870, 9)
# 添加数据以后形状： (1870, 21)
# 删除指定行、列后数据形状:  (1767, 17)
# 当前all_data的形状: (696379, 17)
# 处理进度: 580/591 (98.14%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1959, 9)
# 添加数据以后形状： (1959, 21)
# 删除指定行、列后数据形状:  (1856, 17)
# 当前all_data的形状: (698235, 17)
# 处理进度: 581/591 (98.31%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1002, 9)
# 添加数据以后形状： (1002, 21)
# 删除指定行、列后数据形状:  (899, 17)
# 当前all_data的形状: (699134, 17)
# 处理进度: 582/591 (98.48%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1819, 9)
# 添加数据以后形状： (1819, 21)
# 删除指定行、列后数据形状:  (1716, 17)
# 当前all_data的形状: (700850, 17)
# 处理进度: 583/591 (98.65%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 21)
# 删除指定行、列后数据形状:  (1865, 17)
# 当前all_data的形状: (702715, 17)
# 处理进度: 584/591 (98.82%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (839, 9)
# 添加数据以后形状： (839, 21)
# 删除指定行、列后数据形状:  (736, 17)
# 当前all_data的形状: (703451, 17)
# 处理进度: 585/591 (98.98%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1593, 9)
# 添加数据以后形状： (1593, 21)
# 删除指定行、列后数据形状:  (1490, 17)
# 当前all_data的形状: (704941, 17)
# 处理进度: 586/591 (99.15%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1893, 9)
# 添加数据以后形状： (1893, 21)
# 删除指定行、列后数据形状:  (1790, 17)
# 当前all_data的形状: (706731, 17)
# 处理进度: 587/591 (99.32%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (850, 9)
# 添加数据以后形状： (850, 21)
# 删除指定行、列后数据形状:  (747, 17)
# 当前all_data的形状: (707478, 17)
# 处理进度: 588/591 (99.49%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1707, 9)
# 添加数据以后形状： (1707, 21)
# 删除指定行、列后数据形状:  (1604, 17)
# 当前all_data的形状: (709082, 17)
# 处理进度: 589/591 (99.66%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (701, 9)
# 添加数据以后形状： (701, 21)
# 删除指定行、列后数据形状:  (598, 17)
# 当前all_data的形状: (709680, 17)
# 处理进度: 590/591 (99.83%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1963, 9)
# 添加数据以后形状： (1963, 21)
# 删除指定行、列后数据形状:  (1860, 17)
# 当前all_data的形状: (711540, 17)
# 处理进度: 591/591 (100.00%)
# 合并数据保存完毕。
