# %%
# from google.colab import drive # 挂载谷歌云盘
# drive.mount('/content/drive')
# !nvidia-smi # 显示显卡信息
# ''' 符号%代表一直生效，！代表执行完立马结束，不会生效，所以进入目录用% '''
# %cd /content/drive/MyDrive/timeSerise
# ''' 支持的 常用命令1.ls  2.wget  3.gdoint(int(int(int(w))))n  4.mkdir  5.pwd '''
# !ls
# !pip install pyti
# !pip install akshare

# %%
from data_provider.data_creat import *
import akshare as ak
from datetime import datetime
import random

# %%
class Args:
    '''股票数据获取'''
    fuquan = 'hfq'# 设置复权方式,adjust=空选择的不复权，qfq是前复权，应该用hfq后复权来进行量化分析
    period = 'daily' # 拉取时间周期{'daily', 'weekly', 'monthly'}
    start_date = '20151201'  # 20151201   20221021  下载数据的开始日期,1就是公司上市时间
    end_date = '20231230'  # '20231220' 下载数据的结束日期,如果1则到最后一天,如果-1是昨天.
    label_n = 5 # 预测未来连续多少天的收益率
    root_path = './dataset/Stock/'
    
    # 预测目标y是否替换成1或者0
    label_ch = False  # 如果是True ，预测n天以后上涨大于变量zhangfu为1，小于为0
    zhangfu = 0.10  # 预测涨幅大于等于3%的为1，小于3%的为0

    # 是否合并全部股票数据
    all = True # 是否合并全部股票数据
    data_addzero = 21 # 当all = True时，用于训练的数据集分割，前面补0的长度 应该是seq_len + pred_len 长度
    
    # 数据修剪
    start = 103 # 删除前24行（start=25），因为macd算不出来
    end = 0 # (end = label_n if all else 0)删除最后部分需要预测天数label_n的数据，算出来是0.如果单只股票预测，那么不需要删除
    # final_data_feat =  ['index', 'Volume','Tom_Chg'] # 删除不需要列的标签
    final_data_feat =  ['index', 'Volume','Tom_Chg','Open','Low','High'] # 删除不需要列的标签
    down_scaler = True # 是否对下载数据进行归一化

# 创建参数对象
args = Args()

# 创建股票数据列表
stock_down = ak.stock_cy_a_spot_em() # 创业板实时数据
stock_list = stock_down[~stock_down['名称'].str.contains("退|ST") & (stock_down['流通市值'] <= 1e11) & (stock_down['总市值'] >= 45e8)] # 去除退市和ST股票
file_name_cy = 'Stock_list_cy.csv'# 保存数据，编码格式为utf-8
stock_list.to_csv(args.root_path + file_name_cy,index=False,encoding='utf-8-sig')

# 读取股票列表
stock_list = pd.read_csv(args.root_path + file_name_cy) # 读取股票列表
# 将股票代码的数字转换为字符串列表
stock_list = [str(code) for code in stock_list['代码'].tolist()]
# 对列表随机排序
random.shuffle(stock_list)

# stock_list = ['000158','300798'] # 自定义股票列表

# %%
from sklearn.preprocessing import StandardScaler

all_data_raw = pd.DataFrame()  # 初始化一个空的 DataFrame 用于存储原始数据
all_data_scaled = pd.DataFrame()  # 初始化一个空的 DataFrame 用于存储标准化后的数据
processed_count = 0  # 初始化计数器
total_count = len(stock_list)  # 获取总股票数量
scaler = StandardScaler()

for i in stock_list[:]:
    NUM = i
    try:
        # 下载原始数据
        raw_data = download_data(NUM, args)
        # 更新已处理股票数量计数器
        processed_count += 1
        # 检查数据长度，如果小于300则跳过此次循环
        if raw_data.shape[0] < 500:
            print(f"股票代码 {NUM} 的数据长度小于300,跳过此次循环。")
            continue
        
        # 拼接数据，添加各种参数
        ad_data = add_data(raw_data, args)
        # 添加预测标签
        # ad_data = add_label(ad_data, args)
        # 删除无效数据
        final_data_raw = sub_data(ad_data.copy(), args)
        final_data_scaled = final_data_raw.copy()
        
        # 未处理数据的前20行替换为0
        if args.data_addzero and not all_data_raw.empty:
            final_data_raw = add_zeros_to_data(final_data_raw, num_rows=args.data_addzero)

        # 标准化处理
        if args.down_scaler:
            non_time_columns = final_data_scaled.columns[1:-1]  # 假设时间列是第一列
            final_data_scaled[non_time_columns] = scaler.fit_transform(final_data_scaled[non_time_columns])
            # 标准化处理的数据的前20行替换为0
            if args.data_addzero and not all_data_scaled.empty:
                final_data_scaled = add_zeros_to_data(final_data_scaled, num_rows=args.data_addzero)
        
        # 如果 all 为 False, 则为每个股票单独保存数据
        if not args.all:
            file_name_raw_individual = f"raw_stock_cy_{NUM}.csv"
            final_data_raw.to_csv(args.root_path + file_name_raw_individual, index=False)

            if args.down_scaler:
                file_name_scaled_individual = f"scaled_stock_cy_{NUM}.csv"
                final_data_scaled.to_csv(args.root_path + file_name_scaled_individual, index=False)
                print(f"股票代码 {NUM} 的数据保存到 {file_name_raw_individual} ，形状: {final_data_raw.shape}")
        else:
            # 拼接未处理的数据
            all_data_raw = pd.concat([all_data_raw, final_data_raw], ignore_index=True)
            if args.down_scaler:
                # 拼接经过标准化的数据
                all_data_scaled = pd.concat([all_data_scaled, final_data_scaled], ignore_index=True)
            print(f"当前all_data的形状: {all_data_raw.shape}")

    except Exception as e:
        print(f"处理股票代码 {NUM} 时出现错误: {e}")
        continue

    # 计算并打印处理进度
    progress = processed_count / total_count
    print(f"处理进度: {processed_count}/{total_count} ({progress:.2%})")

# 如果 all 为 True, 则保存合并后的数据
if args.all:
    time = datetime.now().strftime("%Y_%m_%d_%H_%M_%S")
    file_name_raw = "stock_cy_all_raw.csv"
    all_data_raw.to_csv(args.root_path + time + file_name_raw, index=False)
    if args.down_scaler:
        file_name_scaled = "stock_cy_all_scaled.csv"
        all_data_scaled.to_csv(args.root_path + time + file_name_scaled, index=False)
    print("合并数据保存完毕。")
else:
    print("单独数据保存完毕。")
# Out:
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (853, 9)
# 添加数据以后形状： (853, 21)
# 删除指定行、列后数据形状:  (750, 17)
# 当前all_data的形状: (750, 17)
# 处理进度: 1/591 (0.17%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 21)
# 删除指定行、列后数据形状:  (1865, 17)
# 当前all_data的形状: (2615, 17)
# 处理进度: 2/591 (0.34%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1797, 9)
# 添加数据以后形状： (1797, 21)
# 删除指定行、列后数据形状:  (1694, 17)
# 当前all_data的形状: (4309, 17)
# 处理进度: 3/591 (0.51%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1959, 9)
# 添加数据以后形状： (1959, 21)
# 删除指定行、列后数据形状:  (1856, 17)
# 当前all_data的形状: (6165, 17)
# 处理进度: 4/591 (0.68%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1105, 9)
# 添加数据以后形状： (1105, 21)
# 删除指定行、列后数据形状:  (1002, 17)
# 当前all_data的形状: (7167, 17)
# 处理进度: 5/591 (0.85%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (380, 9)
# 股票代码 301286 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (456, 9)
# 股票代码 301207 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (299, 9)
# 股票代码 301316 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1, 9)
# 股票代码 301566 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1856, 9)
# 添加数据以后形状： (1856, 21)
# 删除指定行、列后数据形状:  (1753, 17)
# 当前all_data的形状: (8920, 17)
# 处理进度: 10/591 (1.69%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1959, 9)
# 添加数据以后形状： (1959, 21)
# 删除指定行、列后数据形状:  (1856, 17)
# 当前all_data的形状: (10776, 17)
# 处理进度: 11/591 (1.86%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1608, 9)
# 添加数据以后形状： (1608, 21)
# 删除指定行、列后数据形状:  (1505, 17)
# 当前all_data的形状: (12281, 17)
# 处理进度: 12/591 (2.03%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1746, 9)
# 添加数据以后形状： (1746, 21)
# 删除指定行、列后数据形状:  (1643, 17)
# 当前all_data的形状: (13924, 17)
# 处理进度: 13/591 (2.20%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1148, 9)
# 添加数据以后形状： (1148, 21)
# 删除指定行、列后数据形状:  (1045, 17)
# 当前all_data的形状: (14969, 17)
# 处理进度: 14/591 (2.37%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1890, 9)
# 添加数据以后形状： (1890, 21)
# 删除指定行、列后数据形状:  (1787, 17)
# 当前all_data的形状: (16756, 17)
# 处理进度: 15/591 (2.54%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 21)
# 删除指定行、列后数据形状:  (1865, 17)
# 当前all_data的形状: (18621, 17)
# 处理进度: 16/591 (2.71%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1566, 9)
# 添加数据以后形状： (1566, 21)
# 删除指定行、列后数据形状:  (1463, 17)
# 当前all_data的形状: (20084, 17)
# 处理进度: 17/591 (2.88%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1846, 9)
# 添加数据以后形状： (1846, 21)
# 删除指定行、列后数据形状:  (1743, 17)
# 当前all_data的形状: (21827, 17)
# 处理进度: 18/591 (3.05%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1147, 9)
# 添加数据以后形状： (1147, 21)
# 删除指定行、列后数据形状:  (1044, 17)
# 当前all_data的形状: (22871, 17)
# 处理进度: 19/591 (3.21%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (117, 9)
# 股票代码 301370 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1865, 9)
# 添加数据以后形状： (1865, 21)
# 删除指定行、列后数据形状:  (1762, 17)
# 当前all_data的形状: (24633, 17)
# 处理进度: 21/591 (3.55%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1033, 9)
# 添加数据以后形状： (1033, 21)
# 删除指定行、列后数据形状:  (930, 17)
# 当前all_data的形状: (25563, 17)
# 处理进度: 22/591 (3.72%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1023, 9)
# 添加数据以后形状： (1023, 21)
# 删除指定行、列后数据形状:  (920, 17)
# 当前all_data的形状: (26483, 17)
# 处理进度: 23/591 (3.89%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1743, 9)
# 添加数据以后形状： (1743, 21)
# 删除指定行、列后数据形状:  (1640, 17)
# 当前all_data的形状: (28123, 17)
# 处理进度: 24/591 (4.06%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 21)
# 删除指定行、列后数据形状:  (1865, 17)
# 当前all_data的形状: (29988, 17)
# 处理进度: 25/591 (4.23%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1968, 9)
# 添加数据以后形状： (1968, 21)
# 删除指定行、列后数据形状:  (1865, 17)
# 当前all_data的形状: (31853, 17)
# 处理进度: 26/591 (4.40%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1489, 9)
# 添加数据以后形状： (1489, 21)
# 删除指定行、列后数据形状:  (1386, 17)
# 当前all_data的形状: (33239, 17)
# 处理进度: 27/591 (4.57%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1567, 9)
# 添加数据以后形状： (1567, 21)
# 删除指定行、列后数据形状:  (1464, 17)
# 当前all_data的形状: (34703, 17)
# 处理进度: 28/591 (4.74%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1942, 9)
# 添加数据以后形状： (1942, 21)
# 删除指定行、列后数据形状:  (1839, 17)
# 当前all_data的形状: (36542, 17)
# 处理进度: 29/591 (4.91%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1435, 9)
# 添加数据以后形状： (1435, 21)
# 删除指定行、列后数据形状:  (1332, 17)
# 当前all_data的形状: (37874, 17)
# 处理进度: 30/591 (5.08%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (840, 9)
# 添加数据以后形状： (840, 21)
# 删除指定行、列后数据形状:  (737, 17)
# 当前all_data的形状: (38611, 17)
# 处理进度: 31/591 (5.25%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (502, 9)
# 添加数据以后形状： (502, 21)
# 删除指定行、列后数据形状:  (399, 17)
# 当前all_data的形状: (39010, 17)
# 处理进度: 32/591 (5.41%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (728, 9)
# 添加数据以后形状： (728, 21)
# 删除指定行、列后数据形状:  (625, 17)
# 当前all_data的形状: (39635, 17)
# 处理进度: 33/591 (5.58%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1905, 9)
# 添加数据以后形状： (1905, 21)
# 删除指定行、列后数据形状:  (1802, 17)
# 当前all_data的形状: (41437, 17)
# 处理进度: 34/591 (5.75%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (783, 9)
# 添加数据以后形状： (783, 21)
# 删除指定行、列后数据形状:  (680, 17)
# 当前all_data的形状: (42117, 17)
# 处理进度: 35/591 (5.92%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (590, 9)
# 添加数据以后形状： (590, 21)
# 删除指定行、列后数据形状:  (487, 17)
# 当前all_data的形状: (42604, 17)
# 处理进度: 36/591 (6.09%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1944, 9)
# 添加数据以后形状： (1944, 21)
# 删除指定行、列后数据形状:  (1841, 17)
# 当前all_data的形状: (44445, 17)
# 处理进度: 37/591 (6.26%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (282, 9)
# 股票代码 301267 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1710, 9)
# 添加数据以后形状： (1710, 21)
# 删除指定行、列后数据形状:  (1607, 17)
# 当前all_data的形状: (46052, 17)
# 处理进度: 39/591 (6.60%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1950, 9)
# 添加数据以后形状： (1950, 21)
# 删除指定行、列后数据形状:  (1847, 17)
# 当前all_data的形状: (47899, 17)
# 处理进度: 40/591 (6.77%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1124, 9)
# 添加数据以后形状： (1124, 21)
# 删除指定行、列后数据形状:  (1021, 17)
# 当前all_data的形状: (48920, 17)
# 处理进度: 41/591 (6.94%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1660, 9)
# 添加数据以后形状： (1660, 21)
# 删除指定行、列后数据形状:  (1557, 17)
# 当前all_data的形状: (50477, 17)
# 处理进度: 42/591 (7.11%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1087, 9)
# 添加数据以后形状： (1087, 21)
# 删除指定行、列后数据形状:  (984, 17)
# 当前all_data的形状: (51461, 17)
# 处理进度: 43/591 (7.28%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (220, 9)
# 股票代码 301358 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (254, 9)
# 股票代码 301368 的数据长度小于300,跳过此次循环。
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1614, 9)
# 添加数据以后形状： (1614, 21)
# 删除指定行、列后数据形状:  (1511, 17)
# 当前all_data的形状: (52972, 17)
# 处理进度: 46/591 (7.78%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1905, 9)
# 添加数据以后形状： (1905, 21)
# 删除指定行、列后数据形状:  (1802, 17)
# 当前all_data的形状: (54774, 17)
# 处理进度: 47/591 (7.95%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1844, 9)
# 添加数据以后形状： (1844, 21)
# 删除指定行、列后数据形状:  (1741, 17)
# 当前all_data的形状: (56515, 17)
# 处理进度: 48/591 (8.12%)
# 获取数据时间为： 20151201 - 20231230
# 原始数据形状： (1907, 9)
